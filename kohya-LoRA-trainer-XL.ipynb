# %% [markdown]
# [![visitor][visitor-badge]][visitor-stats]
# [![ko-fi][ko-fi-badge]][ko-fi-link]
#
# # **Kohya LoRA Trainer XL (ALPHA)**
# A Colab Notebook For LoRA Training (Fine-tuning Method)
#
# [visitor-badge]: https://api.visitorbadge.io/api/visitors?path=Kohya%20LoRA%20Fine-tuning&label=Visitors&labelColor=%2334495E&countColor=%231ABC9C&style=flat&labelStyle=none
# [visitor-stats]: https://visitorbadge.io/status?path=Kohya%20LoRA%20Fine-tuning
# [ko-fi-badge]: https://img.shields.io/badge/Support%20me%20on%20Ko--fi-F16061?logo=ko-fi&logoColor=white&style=flat
# [ko-fi-link]: https://ko-fi.com/linaqruf

# %% [markdown]
# # **I. Prepare Environment**

# %%
# @title ## **1.1. Install Kohya Trainer**
import os
import zipfile
import shutil
import time
import torch
from subprocess import getoutput
from IPython.utils import capture
from google.colab import drive

# %store -r

# root_dir
root_dir          = "/content"
drive_dir         = os.path.join(root_dir, "drive/MyDrive")
deps_dir          = os.path.join(root_dir, "deps")
repo_dir          = os.path.join(root_dir, "kohya-trainer")
training_dir      = os.path.join(root_dir, "LoRA")
pretrained_model  = os.path.join(root_dir, "pretrained_model")
vae_dir           = os.path.join(root_dir, "vae")
lora_dir          = os.path.join(root_dir, "network_weight")
repositories_dir  = os.path.join(root_dir, "repositories")
config_dir        = os.path.join(training_dir, "config")
tools_dir         = os.path.join(repo_dir, "tools")
finetune_dir      = os.path.join(repo_dir, "finetune")
accelerate_config = os.path.join(repo_dir, "accelerate_config/config.yaml")

for store in ["root_dir", "repo_dir", "training_dir", "pretrained_model", "vae_dir", "repositories_dir", "accelerate_config", "tools_dir", "finetune_dir", "config_dir"]:
    with capture.capture_output() as cap:
        # %store {store}
        del cap

repo_dict = {
    "qaneel/kohya-trainer (forked repo, stable, optimized for colab use)" : "https://github.com/qaneel/kohya-trainer",
    "kohya-ss/sd-scripts (original repo, latest update)"                    : "https://github.com/kohya-ss/sd-scripts",
}

repository        = "qaneel/kohya-trainer (forked repo, stable, optimized for colab use)" #@param ["qaneel/kohya-trainer (forked repo, stable, optimized for colab use)", "kohya-ss/sd-scripts (original repo, latest update)"] {allow-input: true}
repo_url          = repo_dict[repository]
branch            = "main"  # @param {type: "string"}
output_to_drive   = True  # @param {type: "boolean"}

def clone_repo(url, dir, branch):
    if not os.path.exists(dir):
       # !git clone -b {branch} {url} {dir}

def ubuntu_deps(url, dst):
    os.makedirs(dst, exist_ok=True)
    filename = os.path.basename(url)
    # !wget -q --show-progress {url}
    with zipfile.ZipFile(filename, "r") as deps:
        deps.extractall(dst)
    # !dpkg -i {dst}/*
    os.remove(filename)
    shutil.rmtree(dst)

def mount_drive(dir):
    output_dir      = os.path.join(training_dir, "output")

    if output_to_drive:
        if not os.path.exists(drive_dir):
            drive.mount(os.path.dirname(drive_dir))
        output_dir  = os.path.join(drive_dir, "kohya-trainer/output")

    return output_dir

def setup_directories():
    global output_dir

    output_dir      = mount_drive(drive_dir)

    for dir in [training_dir, config_dir, pretrained_model, vae_dir, repositories_dir, output_dir]:
        os.makedirs(dir, exist_ok=True)

def install_repository():
    global infinite_image_browser_dir

    infinite_image_browser_url  = "https://github.com/zanllp/sd-webui-infinite-image-browsing.git"
    infinite_image_browser_dir  = os.path.join(repositories_dir, "sd-webui-infinite-image-browsing")
    infinite_image_browser_deps = os.path.join(infinite_image_browser_dir, "requirements.txt")

    clone_repo(infinite_image_browser_url, infinite_image_browser_dir, "main")

    # !pip install -q --upgrade -r {infinite_image_browser_deps}

def install_dependencies():
    requirements_file = os.path.join(repo_dir, "requirements.txt")
    model_util        = os.path.join(repo_dir, "library/model_util.py")
    gpu_info          = getoutput('nvidia-smi')
    t4_xformers_wheel = "https://github.com/Linaqruf/colab-xformers/releases/download/0.0.20/xformers-0.0.20+1d635e1.d20230519-cp310-cp310-linux_x86_64.whl"
    ram_patch_url = "https://huggingface.co/Linaqruf/fast-repo/resolve/main/ram_patch.zip"

    # !apt update -yqq
    # !apt install aria2 lz4 libunwind8-dev -yqq
    ubuntu_deps(ram_patch_url, deps_dir)
    # !pip install -q --upgrade -r {requirements_file}

    if '2.0.1+cu118' in torch.__version__:
        if 'T4' in gpu_info:
            # !pip install -q {t4_xformers_wheel}
        else:
            # !pip install -q xformers==0.0.20
    else:
        # !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
        # !pip install -q xformers==0.0.19 triton==2.0.0 -U

    from accelerate.utils import write_basic_config

    if not os.path.exists(accelerate_config):
        write_basic_config(save_location=accelerate_config)

def prepare_environment():
    os.environ["LD_PRELOAD"] = "libtcmalloc.so"
    os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
    os.environ["SAFETENSORS_FAST_GPU"] = "1"
    os.environ["PYTHONWARNINGS"] = "ignore"

def main():
    os.chdir(root_dir)
    clone_repo(repo_url, repo_dir, branch)
    os.chdir(repo_dir)
    setup_directories()
    install_repository()
    install_dependencies()
    prepare_environment()

main()

# %%
# @title ## **1.2. Download SDXL**
import os
import re
import json
import glob
import gdown
import requests
import subprocess
from IPython.utils import capture
from urllib.parse import urlparse, unquote
from pathlib import Path

# %store -r

os.chdir(root_dir)

# @markdown Place your Huggingface Read Token Here

HUGGINGFACE_TOKEN = ""#@param {type: "string"}
SDXL_MODEL_URL = "" #@param {type: "string"}
SDXL_VAE_URL = "" #@param {type: "string"}

def get_supported_extensions():
    return tuple([".ckpt", ".safetensors", ".pt", ".pth"])

def get_filename(url, quiet=True):
    extensions = get_supported_extensions()

    if url.startswith(drive_dir) or url.endswith(tuple(extensions)):
        filename = os.path.basename(url)
    else:
        response = requests.get(url, stream=True)
        response.raise_for_status()

        if 'content-disposition' in response.headers:
            content_disposition = response.headers['content-disposition']
            filename = re.findall('filename="?([^"]+)"?', content_disposition)[0]
        else:
            url_path = urlparse(url).path
            filename = unquote(os.path.basename(url_path))

    if filename.endswith(tuple(get_supported_extensions())):
        return filename
    else:
        return None

def get_most_recent_file(directory):
    files = glob.glob(os.path.join(directory, "*"))
    if not files:
        return None
    most_recent_file = max(files, key=os.path.getmtime)
    basename = os.path.basename(most_recent_file)

    return most_recent_file

def parse_args(config):
    args = []

    for k, v in config.items():
        if k.startswith("_"):
            args.append(f"{v}")
        elif isinstance(v, str) and v is not None:
            args.append(f'--{k}={v}')
        elif isinstance(v, bool) and v:
            args.append(f"--{k}")
        elif isinstance(v, float) and not isinstance(v, bool):
            args.append(f"--{k}={v}")
        elif isinstance(v, int) and not isinstance(v, bool):
            args.append(f"--{k}={v}")

    return args

def aria2_download(dir, filename, url):
    hf_token    = "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" if not HUGGINGFACE_TOKEN else HUGGINGFACE_TOKEN
    user_header = f"Authorization: Bearer {hf_token}"

    aria2_config = {
        "console-log-level"         : "error",
        "summary-interval"          : 10,
        "header"                    : user_header if "huggingface.co" in url else None,
        "continue"                  : True,
        "max-connection-per-server" : 16,
        "min-split-size"            : "1M",
        "split"                     : 16,
        "dir"                       : dir,
        "out"                       : filename,
        "_url"                      : url,
    }
    aria2_args = parse_args(aria2_config)
    subprocess.run(["aria2c", *aria2_args])

def gdown_download(url, dst, filepath):
    if "/uc?id/" in url:
        return gdown.download(url, filepath, quiet=False)
    elif "/file/d/" in url:
        return gdown.download(url=url, output=filepath, quiet=False, fuzzy=True)
    elif "/drive/folders/" in url:
        os.chdir(dst)
        return gdown.download_folder(url, quiet=True, use_cookies=False)

def download(url, dst):
    filename = get_filename(url, quiet=False)
    filepath = os.path.join(dst, filename)

    if "drive.google.com" in url:
        gdown = gdown_download(url, dst, filepath)
    elif url.startswith("/content/drive/MyDrive/"):
        # Path(filepath).write_bytes(Path(url).read_bytes())
        return url
    else:
        if "huggingface.co" in url:
            if "/blob/" in url:
                url = url.replace("/blob/", "/resolve/")
        aria2_download(dst, filename, url)

def get_filepath(url, dst):
    extensions = get_supported_extensions()
    filename = get_filename(url)

    if not filename.endswith(extensions):
        most_recent_file = get_most_recent_file(dst)
        filename = os.path.basename(most_recent_file)

    filepath = os.path.join(dst, filename)

    return filepath

def main():
    global model_path, vae_path

    model_path = vae_path = None

    download_targets = {
        "model" : (SDXL_MODEL_URL, pretrained_model),
        "vae"   : (SDXL_VAE_URL, vae_dir),
    }
    selected_files = {}

    for target, (url, dst) in download_targets.items():
        if url and f"PASTE {target.upper()} URL OR GDRIVE PATH HERE" not in url:
            downloader = download(url, dst)
            selected_files[target] = get_filepath(url, dst)

            if target == "model":
                model_path = selected_files["model"] if not downloader else downloader
            elif target == "vae":
                vae_path = selected_files["vae"] if not downloader else downloader

    for category, path in {
        "model": model_path,
        "vae": vae_path,
    }.items():
        if path is not None and os.path.exists(path):
            print(f"Selected {category}: {path}")

main()

# %%
# @title ## **1.3. Directory Config**
# @markdown Specify the location of your training data in the following cell. A folder with the same name as your input will be created.
import os

# %store -r

train_data_dir = "/content/LoRA/train_data"  # @param {'type' : 'string'}
# %store train_data_dir

os.makedirs(train_data_dir, exist_ok=True)
print(f"Your train data directory : {train_data_dir}")

# %%
# @title ## **1.4. Image Browser**
import os
import json
import random
import portpicker
from IPython.utils import capture
from IPython.display import clear_output
from threading import Thread
from imjoy_elfinder.app import main
from google.colab.output import serve_kernel_port_as_iframe, serve_kernel_port_as_window

# %store -r

# @markdown This cell allows you to view and manage your images in real-time. You can use it to:
# @markdown - Prepare your dataset before training
# @markdown - Monitor the sample outputs during training.

root_dir      = "/content"
browser_type  = "sd-webui-infinite-image-browsing" #@param ["imjoy-elfinder", "sd-webui-infinite-image-browsing"]
window_height = 550 #@param {type:"slider", min:0, max:1000, step:1}

main_app          = os.path.join(infinite_image_browser_dir, "app.py")
config_file       = os.path.join(infinite_image_browser_dir, "config.json")
port              = portpicker.pick_unused_port()

config = {
    "outdir_txt2img_samples": train_data_dir,
}

def write_file(filename, config):
    with open(filename, 'w',) as f:
        json.dump(config, f, indent=4)

def run_app():
    # !python {main_app} --port={port} --sd_webui_config={config_file} > /dev/null 2>&1

def launch():
    os.chdir(root_dir)

    thread = Thread(target=main, args=[[f"--root-dir={root_dir}",
                                        f"--port={port}",
                                        f"--thumbnail"]])

    if browser_type == "sd-webui-infinite-image-browsing":
        os.chdir(train_data_dir)
        write_file(config_file, config)

        thread = Thread(target=run_app)

    thread.start()

    serve_kernel_port_as_iframe(port, width='100%', height=window_height, cache_in_notebook=False)

    clear_output(wait=True)

launch()

# %% [markdown]
# # **II. Data Gathering**
#
# You have three options for collecting your dataset:
#
# 1. Upload it to Colab's local files.
# 2. Use the `Simple Booru Scraper` to download images in bulk from Danbooru.
# 3. Locate your dataset in Google Drive.

# %%
# @title ## **2.1. Unzip Dataset**

import os
import shutil
from pathlib import Path

#@title ## Unzip Dataset
# @markdown If your dataset is in a `zip` file and has been uploaded to a location, use this section to extract it. The dataset will be downloaded and automatically extracted to `train_data_dir` if `unzip_to` is empty.
zipfile_url  = "" #@param {type:"string"}
zipfile_name = "zipfile.zip"
unzip_to     = "" #@param {type:"string"}

hf_token     = "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"
user_header  = f'"Authorization: Bearer {hf_token}"'

if unzip_to:
    os.makedirs(unzip_to, exist_ok=True)
else:
    unzip_to = train_data_dir

def download_dataset(url):
    if url.startswith("/content"):
        return url
    elif "drive.google.com" in url:
        os.chdir(root_dir)
        # !gdown --fuzzy {url}
        return f"{root_dir}/{zipfile_name}"
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {root_dir} -o {zipfile_name} {url}
        return f"{root_dir}/{zipfile_name}"
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {root_dir} -o {zipfile_name} {url}
        return f"{root_dir}/{zipfile_name}"

def extract_dataset(zip_file, output_path):
    # !unzip -j -o {zip_file} -d "{output_path}"

def remove_files(train_dir, files_to_move):
    for filename in os.listdir(train_dir):
        file_path = os.path.join(train_dir, filename)
        if filename in files_to_move:
            if not os.path.exists(file_path):
                shutil.move(file_path, training_dir)
            else:
                os.remove(file_path)

zip_file = download_dataset(zipfile_url)
extract_dataset(zip_file, unzip_to)
os.remove(zip_file)

files_to_move = (
    "meta_cap.json",
    "meta_cap_dd.json",
    "meta_lat.json",
    "meta_clean.json",
)

remove_files(train_data_dir, files_to_move)

# %%
#@title ## **2.2. Scrape Dataset**
import os
import html
from IPython.utils import capture
# %store -r

os.chdir(root_dir)
#@markdown Use `gallery-dl` to scrape images from an imageboard site. To specify `prompt(s)`, separate them with commas (e.g., `hito_komoru, touhou`).
booru = "Danbooru" #@param ["Danbooru", "Gelbooru", "Safebooru"]
prompt = "mika_pikazo" #@param {type: "string"}

#@markdown Alternatively, you can provide a `custom_url` instead of using a predefined site.
custom_url = "" #@param {type: "string"}

#@markdown Use the `sub_folder` option to organize the downloaded images into separate folders based on their concept or category.
sub_folder = "" #@param {type: "string"}

user_agent = "gdl/1.24.5"

#@markdown You can limit the number of images to download by using the `--range` option followed by the desired range (e.g., `1-200`).
range = "1-200" #@param {type: "string"}

write_tags = False #@param {type: "boolean"}

additional_arguments = "--filename /O --no-part"

tags = prompt.split(',')
tags = '+'.join(tags)

replacement_dict = {" ": "", "(": "%28", ")": "%29", ":": "%3a"}
tags = ''.join(replacement_dict.get(c, c) for c in tags)

if sub_folder == "":
    image_dir = train_data_dir
elif sub_folder.startswith("/content"):
    image_dir = sub_folder
else:
    image_dir = os.path.join(train_data_dir, sub_folder)
    os.makedirs(image_dir, exist_ok=True)

if booru == "Danbooru":
    url = "https://danbooru.donmai.us/posts?tags={}".format(tags)
elif booru == "Gelbooru":
    url = "https://gelbooru.com/index.php?page=post&s=list&tags={}".format(tags)
else:
    url = "https://safebooru.org/index.php?page=post&s=list&tags={}".format(tags)

valid_url = custom_url if custom_url else url

def scrape(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

def pre_process_tags(directory):
    for item in os.listdir(directory):
        item_path = os.path.join(directory, item)
        if os.path.isfile(item_path) and item.endswith(".txt"):
            old_path = item_path
            new_file_name = os.path.splitext(os.path.splitext(item)[0])[0] + ".txt"
            new_path = os.path.join(directory, new_file_name)

            os.rename(old_path, new_path)

            with open(new_path, "r") as f:
                contents = f.read()

            contents = html.unescape(contents)
            contents = contents.replace("_", " ")
            contents = ", ".join(contents.split("\n"))

            with open(new_path, "w") as f:
                f.write(contents)

        elif os.path.isdir(item_path):
            pre_process_tags(item_path)

get_url_config = {
    "_valid_url" : valid_url,
    "get-urls" : True,
    "range" : range if range else None,
    "user-agent" : user_agent
}

scrape_config = {
    "_valid_url" : valid_url,
    "directory" : image_dir,
    "write-tags" : write_tags,
    "range" : range if range else None,
    "user-agent" : user_agent
}

get_url_args = scrape(get_url_config)
scrape_args = scrape(scrape_config)
scraper_text = os.path.join(root_dir, "scrape_this.txt")

if write_tags:
    # !gallery-dl {scrape_args} {additional_arguments}
    pre_process_tags(train_data_dir)
else:
    with capture.capture_output() as cap:
        # !gallery-dl {get_url_args} {additional_arguments}
    with open(scraper_text, "w") as f:
        f.write(cap.stdout)

    os.chdir(image_dir)
    # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -i {scraper_text}

# %% [markdown]
# # **III. Data Preprocessing**

# %%
# @title ## **3.1. Data Cleaning**
import os
import random
import concurrent.futures
from tqdm import tqdm
from PIL import Image

# %store -r

os.chdir(root_dir)

test = os.listdir(train_data_dir)
#@markdown This section removes unsupported media types such as `.mp4`, `.webm`, and `.gif`, as well as any unnecessary files.
#@markdown To convert a transparent dataset with an alpha channel (RGBA) to RGB and give it a white background, set the `convert` parameter to `True`.
convert = False  # @param {type:"boolean"}
#@markdown Alternatively, you can give the background a `random_color` instead of white by checking the corresponding option.
random_color = False  # @param {type:"boolean"}
recursive = False

batch_size = 32
supported_types = [
    ".png",
    ".jpg",
    ".jpeg",
    ".webp",
    ".bmp",
    ".caption",
    ".npz",
    ".txt",
    ".json",
]

background_colors = [
    (255, 255, 255),
    (0, 0, 0),
    (255, 0, 0),
    (0, 255, 0),
    (0, 0, 255),
    (255, 255, 0),
    (255, 0, 255),
    (0, 255, 255),
]

def clean_directory(directory):
    for item in os.listdir(directory):
        file_path = os.path.join(directory, item)
        if os.path.isfile(file_path):
            file_ext = os.path.splitext(item)[1]
            if file_ext not in supported_types:
                print(f"Deleting file {item} from {directory}")
                os.remove(file_path)
        elif os.path.isdir(file_path) and recursive:
            clean_directory(file_path)

def process_image(image_path):
    img = Image.open(image_path)
    img_dir, image_name = os.path.split(image_path)

    if img.mode in ("RGBA", "LA"):
        if random_color:
            background_color = random.choice(background_colors)
        else:
            background_color = (255, 255, 255)
        bg = Image.new("RGB", img.size, background_color)
        bg.paste(img, mask=img.split()[-1])

        if image_name.endswith(".webp"):
            bg = bg.convert("RGB")
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            bg.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            bg.save(image_path, "PNG")
            print(f" Converted image: {image_name}")
    else:
        if image_name.endswith(".webp"):
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            img.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            img.save(image_path, "PNG")

def find_images(directory):
    images = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".png") or file.endswith(".webp"):
                images.append(os.path.join(root, file))
    return images

clean_directory(train_data_dir)
images = find_images(train_data_dir)
num_batches = len(images) // batch_size + 1

if convert:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        for i in tqdm(range(num_batches)):
            start = i * batch_size
            end = start + batch_size
            batch = images[start:end]
            executor.map(process_image, batch)

    print("All images have been converted")

# %% [markdown]
# ## **3.2. Data Captioning**
#
# - For general images, use BLIP captioning.
# - For anime and manga-style images, use Waifu Diffusion 1.4 Tagger V2.

# %%
#@title ### **3.2.1. BLIP Captioning**
#@markdown BLIP is a pre-training framework for unified vision-language understanding and generation, which achieves state-of-the-art results on a wide range of vision-language tasks. It can be used as a tool for image captioning, for example, `astronaut riding a horse in space`.
import os

os.chdir(finetune_dir)

beam_search = True #@param {type:'boolean'}
min_length = 5 #@param {type:"slider", min:0, max:100, step:5.0}
max_length = 75 #@param {type:"slider", min:0, max:100, step:5.0}

config = {
    "_train_data_dir"   : train_data_dir,
    "batch_size"        : 8,
    "beam_search"       : beam_search,
    "min_length"        : min_length,
    "max_length"        : max_length,
    "debug"             : True,
    "caption_extension" : ".caption",
    "max_data_loader_n_workers" : 2,
    "recursive"         : True
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python make_captions.py {args}"

os.chdir(finetune_dir)
# !{final_args}
# Out:
# load images from /content/LoRA/train_data
# found 187 images.
# loading BLIP caption: https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# Downloading (…)solve/main/vocab.txt: 100% 232k/232k [00:00<00:00, 3.19MB/s]
# Downloading (…)okenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 271kB/s]
# Downloading (…)lve/main/config.json: 100% 570/570 [00:00<00:00, 4.75MB/s]
# 100% 1.66G/1.66G [00:13<00:00, 136MB/s]
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# BLIP loaded
#   0% 0/24 [00:00<?, ?it/s]/content/LoRA/train_data/0041e2c3383bfc5ef794bd9be7b5e70c.jpg a group of anime characters with different outfits
# /content/LoRA/train_data/00cf3b92f7b438bd216c3c68137061c1.jpg a group of anime characters standing next to each other
# /content/LoRA/train_data/0127bdacdc2575b3389f34017e816bdc.jpg a poster with a girl in a blue dress
# /content/LoRA/train_data/01e8e5e6dcb2563fd1632bc33d6fc3e5.jpg a girl with blue hair and red and blue hair
# /content/LoRA/train_data/02021a8067adda8ed384bc0c80d77b73.png a woman in a school uniform standing next to a wall
# /content/LoRA/train_data/027c1d95d00ecbbeee99aaaa8de03859.jpg a anime girl with pink hair and a bow tie
# /content/LoRA/train_data/0320d717c5f2ae89e2e9d9b0879fd158.jpg a woman with a gun and a flower in her hand
# /content/LoRA/train_data/058efb9dae3f90be00c9a31d4e7948d2.jpg a magazine cover with a group of anime characters
#   4% 1/24 [00:10<04:01, 10.48s/it]/content/LoRA/train_data/07d79de8bcca0cc1ce7ad207db65ac43.png a woman with long hair and a black top
# /content/LoRA/train_data/0d0e0fd732db60540af627a04579f980.png a woman with blue hair and glasses holding a cell phone
# /content/LoRA/train_data/0d5bd960d4fafd88a438732f2585e675.jpg a drawing of a woman with a gun
# /content/LoRA/train_data/0dcfefee797f235f23121d6da8f00458.jpg a couple of anime characters standing next to each other
# /content/LoRA/train_data/0eada6eafb9bbcf34bee71990853370b.jpg two anime girls with long hair and blue hair
# /content/LoRA/train_data/0f7f5488cae8142fce388ba53a55f464.png a woman with long hair and a red background
# /content/LoRA/train_data/0fa53e7f207f6ddabb7d1817e0b40033.jpg a woman in a colorful dress is dancing
# /content/LoRA/train_data/13d3803aa685351316bc7970f5272bc1.jpg two anime characters fighting with each other
#   8% 2/24 [00:10<02:00,  5.48s/it]/content/LoRA/train_data/1aca689b23bdab8fefd9c2e251c6a335.jpg a girl with blue hair and a yellow nose ring
# /content/LoRA/train_data/1d991d0c6d07c86e0c66fc44c2b4b47b.png a man in a red and gold outfit
# /content/LoRA/train_data/1ed1e8776a31cd8ab388c2aeebd182d0.jpg a woman with glasses and a book in her hand
# /content/LoRA/train_data/1ee87a7b1fd75487325ac2ec9cabe43b.jpg a man in a blue outfit holding a sword
# /content/LoRA/train_data/1fb2fbd2b8c58e1043395bfcfa823f34.jpg a woman with a sword and a blue dress
# /content/LoRA/train_data/2031b8da3ae7aaa43049f9d40082c029.jpg a woman in a pink and white outfit
# /content/LoRA/train_data/22cb3da6c136ecacf3ec5b291e2f6292.jpg a woman with red hair and a white shirt
# /content/LoRA/train_data/27294e07cabdc5146ee2c2a379631a7d.png a poster with a group of anime characters
#  12% 3/24 [00:11<01:20,  3.81s/it]/content/LoRA/train_data/2bb49cc145e5f72b2ed6aab376bba1de.png a woman in a short skirt and a yellow and white shirt
# /content/LoRA/train_data/2dbebf3aabe238428948169aea8de41d.png a woman with long hair and a colorful outfit
# /content/LoRA/train_data/2f9f7e470bee034b51fbbe11ab475593.jpg a group of anime characters with blue hair
# /content/LoRA/train_data/304d02e03bae741922061dbe3e5589a6.png a woman in a bikini and a costume holding a surfboard
# /content/LoRA/train_data/324ec564e1d532f14f4cd3a6a3e6fca7.jpg a drawing of a woman in a checkered outfit
# /content/LoRA/train_data/36dc23269119c2db186313a2bdf34587.jpg a group of anime characters standing in front of a graffiti wall
# /content/LoRA/train_data/370b3a41fddb4cd15d9a5aa50881f277.jpg a woman with a bow and arrow in her hand
# /content/LoRA/train_data/38c43d0157ab2cab9a7b6bea0b6e82c7.jpg a anime character with a blue hair and a green eyes
#  17% 4/24 [00:11<00:59,  2.98s/it]/content/LoRA/train_data/39f48f9b62c5a4d3717df213af39f1ae.png a woman with long blonde hair and a black top
# /content/LoRA/train_data/3ea6107069638590363923b11e8d3843.jpg a girl in a blue and pink outfit is dancing
# /content/LoRA/train_data/3f3dd10944af7804f49ac0496045e40d.jpg a woman in a kimono outfit is holding a bag
# /content/LoRA/train_data/3fa220b52e10c388d4301bdce1b6aaa9.png two anime characters riding on horses with swords
# /content/LoRA/train_data/3fd4fc23e19ebddeb8bd16b39533389f.jpg a woman in a dress and a hat walking down a hallway
# /content/LoRA/train_data/4002ddcf968786f5e4d5c89e6a2b2a0d.png a girl in a dress and knee high socks
# /content/LoRA/train_data/4053ac33e99e277ea1584bbe03f94b23.png a group of anime girls standing next to each other
# /content/LoRA/train_data/40e82b9d6eb02ada8c04de4e2d54a21f.jpg a group of anime characters flying through the air
#  21% 5/24 [00:12<00:47,  2.49s/it]/content/LoRA/train_data/424fef1cd1f46f3b7bb3895e6c43711c.jpg two anime characters hugging each other
# /content/LoRA/train_data/425566c82b9c82ad9764bff05db11de1.jpg a man in a blue outfit holding a sword
# /content/LoRA/train_data/43bff1e0623a35dc507ea8b050758af9.png a woman in a red cape holding a sword
# /content/LoRA/train_data/4428f4c1b15c7ff07f0e8dc2859f0ecf.jpg a woman with long hair and a dress
# /content/LoRA/train_data/44a7e4dc9ca141ebfbeac39e9a672f43.png a woman with long hair and a dress
# /content/LoRA/train_data/4629d28d8cdaa00d57e57f2d56527a90.jpg a group of anime characters with colorful hair
# /content/LoRA/train_data/46b1ed71fab764147d387c6e11419655.jpg a man in armor with a sword and a blue background
# /content/LoRA/train_data/484b5989f66e4bb5b9eb80ab33d94910.png a girl with pink hair and blue eyes holding a blue object
#  25% 6/24 [00:12<00:38,  2.16s/it]/content/LoRA/train_data/4b1d3e6981255f05705a78417eca745f.jpg a girl in a blue dress is swimming
# /content/LoRA/train_data/4cbb60318303a883cb4f25fec4875cce.jpg a poster with a woman in a blue and pink dress
# /content/LoRA/train_data/5315a07d2578d1330b5792a96be989ec.jpg a girl in a pink dress and hat is holding a pink umbrella
# /content/LoRA/train_data/544176d4ce458b6e21d295b60d836e76.jpg a bunch of anime characters are grouped together
# /content/LoRA/train_data/54a4b89b7117b88462c7535bf8ef6eb2.jpg a group of anime girls with different colored hair
# /content/LoRA/train_data/55687762af38561396b107f261426f6a.jpg a couple of anime characters are fighting over a girl
# /content/LoRA/train_data/5675d1bb209c25313a225fdf5789c32f.jpg a woman with long white hair and a hat
# /content/LoRA/train_data/583064c7aab43002d1ab1f858196fbc1.jpg a group of anime girls with pink hair
#  29% 7/24 [00:13<00:32,  1.93s/it]/content/LoRA/train_data/5df840aa1db64471b94dab7700345840.jpg a woman in a long dress holding a book
# /content/LoRA/train_data/5e88945f24f53b2a2f3364323551d387.png a girl in a green dress and a bow tie
# /content/LoRA/train_data/6011db4d9f66f90271ddda8b0f0afa2f.jpg two anime characters are posing for a picture
# /content/LoRA/train_data/618a37360463bb4c10ab05f986404dea.jpg a group of anime girls standing next to each other
# /content/LoRA/train_data/61f655f3583c13440be9bdd5b330ab51.png a girl in a blue dress is swimming
# /content/LoRA/train_data/63d04311663c7e515c7c8fa7ba732157.png two anime characters are in a colorful picture
# /content/LoRA/train_data/6435a641cff43bc18eae967143fa1084.png a girl in a school uniform holding a baseball bat
# /content/LoRA/train_data/65581191f68ee220d37495cecbf416f8.jpg a girl with blue hair wearing a hat and scarf
#  33% 8/24 [00:13<00:27,  1.74s/it]/content/LoRA/train_data/65c677e206df1162c6a18c4be8893306.png a group of people with guns and helmets
# /content/LoRA/train_data/68ecd5f6e636e57ebf4688b798fea396.jpg a woman in a long coat and boots
# /content/LoRA/train_data/6bd2ba2c195f54976551e4b5c2ca059d.png a black and white drawing of a person with a frisbee
# /content/LoRA/train_data/6e3daf493d636f45e40007615d63fba3.png a woman in a blue and white outfit holding a sword
# /content/LoRA/train_data/6f456798b6a05ed9dff0113995fd2500.jpg a woman holding a gun and a man with a gun
# /content/LoRA/train_data/6fd0bee5a200ad04c4748f8e14767107.png a woman with blue eyes and a helmet on
# /content/LoRA/train_data/70625d7ea4e2781628b900e5f4e59dd7.png a couple of anime characters standing next to each other
# /content/LoRA/train_data/70c25a579467711d8450132cbefc3778.jpg two anime girls dressed in costumes and holding a bowl
#  38% 9/24 [00:14<00:24,  1.61s/it]/content/LoRA/train_data/7104537b5d5e12bb59d51c18ea99e480.jpg a poster with a girl with white hair and blue eyes
# /content/LoRA/train_data/736a3f419001c8e1581df83d2e716a11.jpg a girl with a flower crown on her head
# /content/LoRA/train_data/753262faba4cee5003f3a1a6f2ebfab1.png a woman with blue hair and a blue background
# /content/LoRA/train_data/753aabcd325c0868c2c0c5bc2f183924.png a woman with red hair and blue eyes
# /content/LoRA/train_data/756a532e3ba955a0b3154c2b6449c5a0.jpg a group of anime characters standing in front of a sky
# /content/LoRA/train_data/75a50489383bede30e23ffc916428027.jpg a woman in a blue dress holding a sword
# /content/LoRA/train_data/7683b8e941724a4c30ff267f2b1ef951.png a group of anime characters in the water
# /content/LoRA/train_data/77e4142775b240c8232e48d85c5efe7a.jpg a group of anime characters standing next to each other
#  42% 10/24 [00:14<00:20,  1.50s/it]/content/LoRA/train_data/78a064dc3b43b83f153d53c9870d3b13.png a woman in a green and red outfit
# /content/LoRA/train_data/7af385c43d78e6ba791ff3a6c3941007.jpg a woman in a dress and crown holding a cat
# /content/LoRA/train_data/8119d07e4640869aeed7eba34ae60fa8.jpg a woman with blue hair and a white dress
# /content/LoRA/train_data/81f30c9ff32935aebf548ead3809568d.png a girl with colorful hair and a smile
# /content/LoRA/train_data/8212989006b53b168a4a9edba6ca19c4.png two anime girls with long hair and blue eyes
# /content/LoRA/train_data/824427808daf4ab9eea18e92e5260416.jpg a woman with red hair and a tie
# /content/LoRA/train_data/82feb4fe786d2fc23b1f62781bc1b39e.jpg a woman in a red cape holding a sword
# /content/LoRA/train_data/832e77a79ca0663dcb6a1068b211b3c9.png a person in a suit and tie standing
#  46% 11/24 [00:15<00:18,  1.40s/it]/content/LoRA/train_data/86dfc914a20d91d16bf77dbc60d2c1b2.png a group of people in armor with guns
# /content/LoRA/train_data/879bf27990073895ec03eb5bed4f325a.png two anime characters laying on a bed together
# /content/LoRA/train_data/89d4baa10b5343800067e97601aaf51a.png a woman in a short skirt and jacket
# /content/LoRA/train_data/8a97f1306014ca0f6f930bc74e73e2a7.jpg two women in pink are hugging each other
# /content/LoRA/train_data/8b928f263d1c5ae378606a624192b287.jpg two anime characters are laying down together
# /content/LoRA/train_data/8bda5a4c86059e5380b964aa163b0937.jpg a woman flying through the air with a kite
# /content/LoRA/train_data/8c1a134f47342bfcc965ec65f9a78687.jpg a woman with a backpack and a backpack pointing up
# /content/LoRA/train_data/8d086ebc7681ec938e0b37c237c1062d.jpg a group of anime characters with different colored hair
#  50% 12/24 [00:15<00:15,  1.32s/it]/content/LoRA/train_data/8f11c26c9139f914b6a4f0a5e3a17dc1.png a woman standing in front of a large painting
# /content/LoRA/train_data/8f38596be8af5561daa7c597c88871f4.jpg a man in a blue and white outfit holding a sword
# /content/LoRA/train_data/907a3e1b1311d7f313b85a31311f1a02.jpg a girl with pink hair and a bow tie
# /content/LoRA/train_data/9127477e129d6232fff54c8c400f80c8.jpg a drawing of a woman with long hair
# /content/LoRA/train_data/925af30b43a86c2575655eb1707ebce7.jpg a girl with long hair and a pink dress
# /content/LoRA/train_data/9356a1c218a323f93b5f89bc5544b6bd.jpg a woman in a red and white dress holding a sword
# /content/LoRA/train_data/9719e00aebadc31933d8047afd7bb649.png a group of anime characters with guns
# /content/LoRA/train_data/97a8dd3153f8169b81329367ab9c659d.png a display case with a painting of a woman
#  54% 13/24 [00:16<00:13,  1.26s/it]/content/LoRA/train_data/98f98a504138db9a5e4406cb366b6a63.png a woman with blue hair and flowers in her hair
# /content/LoRA/train_data/9b801da3790150e87f921f3a657be815.jpg a girl with long hair and colorful hair
# /content/LoRA/train_data/9bb42810c649c7244ce339d4ecacb703.png a woman in a bikini top and shorts holding a skateboard
# /content/LoRA/train_data/9be57cc48c35681363b9851ac4bf7f0a.png a girl in a blue dress and black boots
# /content/LoRA/train_data/9c6cceb9201dc91a7cbe75c390ca58fc.jpg a woman standing in a city with a drink
# /content/LoRA/train_data/9cb07c83301ba709979412b22a5b7c38.jpg a anime girl with blue hair and a bow
# /content/LoRA/train_data/9fa0362559e289f7d6b9b4421fc3b886.png a girl in a bunny costume is posing
# /content/LoRA/train_data/9fff5bd7df4ef31be5cdf5bee66715af.jpg a woman with pink hair and a helmet on
#  58% 14/24 [00:16<00:12,  1.21s/it]/content/LoRA/train_data/a24ae92279eaf9df3deeda73558b5690.jpg a woman in a blue dress holding a sword
# /content/LoRA/train_data/a3327d459c8f4817c31367536ea3dd2a.png a group of anime characters posing together
# /content/LoRA/train_data/a3c0be3d19748487bfb8f2618e568031.jpg a video game with a bunch of characters on it
# /content/LoRA/train_data/a45083a42ab4216994f880929245eb44.png a group of anime characters with blue hair
# /content/LoRA/train_data/a4661ee8cfc95dc2631131eb2f565335.png a group of anime girls with pink hair
# /content/LoRA/train_data/a4b609313b12510626a84b4dc560879c.jpg a woman in a wheelchair with a green background
# /content/LoRA/train_data/a5641232f4f7d8259a620e8a0b191069.png a woman in a costume holding a large apple
# /content/LoRA/train_data/a718c2fac88051e63a467e0314da70d8.jpg a group of anime characters standing next to each other
#  62% 15/24 [00:17<00:10,  1.16s/it]/content/LoRA/train_data/a8100b48212af1d24a9c314ae7abb8e8.jpg a woman in a short skirt and a cat
# /content/LoRA/train_data/ab76bd7469f384cde314d5160bec1754.jpg a woman with blue hair and glasses holding a cell phone
# /content/LoRA/train_data/acb4a54c72075359c4c955e791950aba.jpg a woman with long hair and a black top
# /content/LoRA/train_data/ad9ec375a03e81ec2adb2e4365d96277.jpg a group of people in armor with guns
# /content/LoRA/train_data/ae20e76eb0b36f2e34a087351d97de08.png a woman with a gun in her hand
# /content/LoRA/train_data/b00c95c1388a9cb3dd49d19db5a3ea91.png a girl with a colorful hair and a tie
# /content/LoRA/train_data/b3a12f15f6d61bd4b334d7f371e617da.jpg a girl with a knife and fork in her hand
# /content/LoRA/train_data/b530666e376c1f03c3302965b4ba68bc.jpg a woman in a short skirt and jacket
#  67% 16/24 [00:17<00:08,  1.11s/it]/content/LoRA/train_data/b5744881e2767358c0666a540a2f4e76.jpg a woman in a red and gold outfit
# /content/LoRA/train_data/b602973346fa02c23b2525e4047dbc17.png a woman in a blue dress and a white shirt
# /content/LoRA/train_data/b880175655930d1c835ad9201ed4feca.png a woman with long hair and flowers in her hair
# /content/LoRA/train_data/b8dddb483a4087e7275b6a9d8299699c.png a woman with a gun and a bunch of flowers
# /content/LoRA/train_data/b9a5c5c6b7cb8779c06be175bbbe7a76.png a girl with a flower crown on her head
# /content/LoRA/train_data/b9ca6cb8cfb8235314b2222b3074b41e.jpg two anime girls are flying through the air
# /content/LoRA/train_data/baf8fe814cb59575f5f0be5e263a9bff.jpg a girl with glasses and a pink background
# /content/LoRA/train_data/bb2f0aa82c54173c2819693488735a81.png a person in a red suit holding a gun
#  71% 17/24 [00:18<00:07,  1.08s/it]/content/LoRA/train_data/bb46c25fe5e177f9122886d59f7f65fa.jpg a woman with a polka dot hat and a polka dot shirt
# /content/LoRA/train_data/c0030d779becd83c2ff38ff281daffc4.jpg a woman with long hair and a sword
# /content/LoRA/train_data/c0be7c64dc96bd1586fa2dcea74b2bef.png a woman flying through the air with a kite
# /content/LoRA/train_data/c34c3b06cd6e992c361c1b2552877476.jpg a woman in a dress with a sword
# /content/LoRA/train_data/c7951ffc55bf368f28ef74e9620ec752.png a woman with long hair holding a knife
# /content/LoRA/train_data/c7a724b7e36e6c78c11aa4dab959262d.png a man in a red cape holding a sword
# /content/LoRA/train_data/c8e7bfdde3abd197059fb2eff6585fb1.png a girl in a dress and a pink umbrella
# /content/LoRA/train_data/c90d4fbdff1f8b8c8a65ff22c4e596e8.jpg a anime character with a sword in his hand
#  75% 18/24 [00:18<00:06,  1.05s/it]/content/LoRA/train_data/ca6786c6a36ca493f2155e567523dbdf.jpg a girl with pink hair and a green jacket
# /content/LoRA/train_data/cab2f9e5fca51258f882c54354c28707.jpg a woman in a red and yellow dress holding a sword
# /content/LoRA/train_data/cd491b8257b558a02ad5ce2b03042605.jpg a drawing of a woman in a short dress
# /content/LoRA/train_data/cd781ea9d8968d9685250072449258c2.jpg a nintendo switch game with a group of women on horseback
# /content/LoRA/train_data/cdc88b0ec6e0a9c5549bfcd34725b59a.jpg a woman with long hair and a red background
# /content/LoRA/train_data/cf7e9795056c6cd24da9c6e5a1045315.jpg a group of anime characters with different outfits
# /content/LoRA/train_data/d0345fa6308705c2c20861a388612b76.jpg two anime characters laying on a bed together
# /content/LoRA/train_data/d196f13c2bed5fd9d0ed14cc543dac30.png a girl in a purple coat and purple boots
#  79% 19/24 [00:19<00:05,  1.02s/it]/content/LoRA/train_data/d2659cefafc9518f99a57c1234675ae9.jpg a group of anime characters with guns
# /content/LoRA/train_data/d3215e3bc2a3efb870a2a88615a53f78.png two anime girls with long hair and blue hair
# /content/LoRA/train_data/d36d4ac4fbbfde297ad1c534f94fdbd2.jpg a girl with a yellow nose ring and a tie
# /content/LoRA/train_data/d6fa66f07406b0d9484ba3d6a035af93.jpg a girl with glasses and a pink background
# /content/LoRA/train_data/d74fe4c78364a72f592f06fb4e68b730.jpg a group of people with guns and a blue background
# /content/LoRA/train_data/d7668b80cdb88d0d664da048159fd027.png a woman in a dress and a hat walking down a hallway
# /content/LoRA/train_data/d7b4df62f9ad72a08b637134fe012f67.jpg a girl with pink hair holding a guitar
# /content/LoRA/train_data/db06bdc261fb375f85313e73cc040dda.png a girl with a knife and fork in her hand
#  83% 20/24 [00:19<00:03,  1.00it/s]/content/LoRA/train_data/db90b0beaf0c454a2af2ba95da4829ec.jpg a woman in a purple dress and purple shoes
# /content/LoRA/train_data/df14ddd64446f9efb2189112a8775152.jpg a girl with long hair and a bow tie
# /content/LoRA/train_data/df7577668bdd388ba83baf2a6ef6b5b8.jpg a woman in a short skirt and jacket
# /content/LoRA/train_data/e2661e026b49d4775e35a114bce30424.jpg a girl with a phone in her hand
# /content/LoRA/train_data/e2712eae7c35a04f39400388cca07a9a.jpg a girl in a dress and a hat is running
# /content/LoRA/train_data/e35cbf3a7903ed5ae67007ed5883eb4d.jpg a group of anime girls in dresses and hats
# /content/LoRA/train_data/e42be3f555530d87bfa4e788bc608c88.jpg a person in a red suit holding a gun
# /content/LoRA/train_data/e677a382e51443d187a369e444604ddb.jpg a man in a red cape holding a sword
#  88% 21/24 [00:20<00:02,  1.03it/s]/content/LoRA/train_data/e779d72e28bbb722bd045ff3dc0aeebf.jpg a girl in a blue dress and a red and white background
# /content/LoRA/train_data/ecfa1c769facee1c3982bf6e45056934.jpg a group of anime characters with different outfits
# /content/LoRA/train_data/edc368afe207cfcdecb3460556a7fbca.jpg a man with a flower in his hand
# /content/LoRA/train_data/ee8bb7e3e67f5aa3e19a0a542382a941.png a woman with a flower crown on her head
# /content/LoRA/train_data/eec436fe4ca410a76b306c120c7ff16a.png a woman in a black dress and green boots
# /content/LoRA/train_data/ef90bcdfe0be9619ed0842f578ba8fed.png a woman with blue hair and a white dress
# /content/LoRA/train_data/f00eed348049c5a2a76eea705fa49f95.jpg a girl with long hair and a hat on
# /content/LoRA/train_data/f09c728694b9ef06a84bd3899616836a.jpg a girl with pink hair and blue eyes holding a blue object
#  92% 22/24 [00:20<00:01,  1.05it/s]/content/LoRA/train_data/f0ba3a702b0cf07b8f690ac9c28d1b22.png a girl with a yellow band around her neck
# /content/LoRA/train_data/f16ecdb16299fdb81698d606632cdaeb.png a bunch of anime characters with different colored eyes
# /content/LoRA/train_data/f4503a618ece845654fa91d4ae7cfe6e.jpg a woman in a blue and white outfit holding a sword
# /content/LoRA/train_data/f7844043e2e3682dbb0523bbddf2fa3c.jpg a group of anime characters with guns
# /content/LoRA/train_data/f7db6d3345cdcb7fdf059944965d0e99.jpg a drawing of a woman in a dress with a checkered pattern
# /content/LoRA/train_data/f90b0da10afc1b99055ca4bdbe0226d4.png a woman standing in front of a painting
# /content/LoRA/train_data/f97a087376b766ae0e4a692d855db230.jpg a group of anime characters standing on top of a hill
# /content/LoRA/train_data/fabefd87fc3cee5c6cfbbcb9badd7680.jpg a woman with a large breast and a large breast
# 100% 24/24 [00:21<00:00,  1.10it/s]
# /content/LoRA/train_data/fb83816f32844eb5d689ac8800673b1c.jpg a woman with a gun in her hand
# /content/LoRA/train_data/fc44d2725b55feca02fb57e055f664c2.jpg a woman with long hair and a hat on
# /content/LoRA/train_data/fd4936dd9648378471a74554bb184373.jpg a group of anime girls with different colored hair
# done!

# %%
#@title ### **3.2.2. Waifu Diffusion 1.4 Tagger V2**
import os
# %store -r

os.chdir(finetune_dir)

#@markdown [Waifu Diffusion 1.4 Tagger V2](https://huggingface.co/spaces/SmilingWolf/wd-v1-4-tags) is a Danbooru-styled image classification model developed by SmilingWolf. It can also be useful for general image tagging, for example, `1girl, solo, looking_at_viewer, short_hair, bangs, simple_background`.
model = "SmilingWolf/wd-v1-4-moat-tagger-v2" #@param ["SmilingWolf/wd-v1-4-moat-tagger-v2", "SmilingWolf/wd-v1-4-convnextv2-tagger-v2", "SmilingWolf/wd-v1-4-swinv2-tagger-v2", "SmilingWolf/wd-v1-4-convnext-tagger-v2", "SmilingWolf/wd-v1-4-vit-tagger-v2"]
#@markdown Separate `undesired_tags` with comma `(,)` if you want to remove multiple tags, e.g. `1girl,solo,smile`.
undesired_tags = "" #@param {type:'string'}
#@markdown Adjust `general_threshold` for pruning tags (less tags, less flexible). `character_threshold` is useful if you want to train with character tags, e.g. `hakurei reimu`.
general_threshold = 0.35 #@param {type:"slider", min:0, max:1, step:0.05}
character_threshold = 0.35 #@param {type:"slider", min:0, max:1, step:0.05}

config = {
    "_train_data_dir"           : train_data_dir,
    "batch_size"                : 8,
    "repo_id"                   : model,
    "recursive"                 : True,
    "remove_underscore"         : True,
    "general_threshold"         : general_threshold,
    "character_threshold"       : character_threshold,
    "caption_extension"         : ".txt",
    "max_data_loader_n_workers" : 2,
    "debug"                     : True,
    "undesired_tags"            : undesired_tags
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python tag_images_by_wd14_tagger.py {args}"

os.chdir(finetune_dir)
# !{final_args}
# Out:
# downloading wd14 tagger model from hf_hub. id: SmilingWolf/wd-v1-4-moat-tagger-v2
# Downloading keras_metadata.pb: 100% 587k/587k [00:00<00:00, 2.38MB/s]
# Downloading saved_model.pb: 100% 8.03M/8.03M [00:00<00:00, 15.5MB/s]
# Downloading (…)in/selected_tags.csv: 100% 254k/254k [00:00<00:00, 3.53MB/s]
# Downloading (…).data-00000-of-00001: 100% 327M/327M [00:06<00:00, 49.5MB/s]
# Downloading variables.index: 100% 37.6k/37.6k [00:00<00:00, 632kB/s]
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# found 187 images.
#   0% 0/24 [00:00<?, ?it/s]
# /content/LoRA/train_data/0041e2c3383bfc5ef794bd9be7b5e70c.jpg:
#   Character tags: gawr gura, mori calliope, ninomae ina'nis, watson amelia, takanashi kiara, ouro kronii, nanashi mumei, hakos baelz, ceres fauna, irys (hololive), tsukumo sana
#   General tags: long hair, looking at viewer, smile, short hair, bangs, blue eyes, multiple girls, skirt, blonde hair, brown hair, black hair, hair ornament, thighhighs, hat, dress, bow, navel, animal ears, twintails, brown eyes, jewelry, very long hair, blue hair, purple eyes, tail, full body, ponytail, pink hair, purple hair, braid, white hair, grey hair, red hair, multicolored hair, boots, green hair, wings, horns, alternate costume, pointy ears, midriff, virtual youtuber, miniskirt, black skirt, pink eyes, orange hair, streaked hair, wrist cuffs, maid headdress, gradient hair, thigh strap, 6+girls, heterochromia, white footwear, white skirt, feathers, single thighhigh, clenched hands, asymmetrical legwear, tentacle hair, mouse ears, antlers, mouse tail, braided bangs, mouse girl, monocle hair ornament, idol clothes, holomyth
#
# /content/LoRA/train_data/00cf3b92f7b438bd216c3c68137061c1.jpg:
#   Character tags:
#   General tags: long hair, breasts, smile, short hair, bangs, blue eyes, multiple girls, red eyes, gloves, jewelry, medium breasts, very long hair, blue hair, weapon, braid, white hair, red hair, multicolored hair, earrings, multiple boys, sword, dark skin, 3girls, armor, two-tone hair, dark-skinned female, thigh strap, heterochromia, crossed bangs, dragon, crown braid, split-color hair
#
# /content/LoRA/train_data/0127bdacdc2575b3389f34017e816bdc.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, blue eyes, dress, hair between eyes, bare shoulders, very long hair, closed mouth, collarbone, white hair, sleeveless, choker, white dress, english text, floating hair, sleeveless dress, arms behind back, cover, sundress
#
# /content/LoRA/train_data/01e8e5e6dcb2563fd1632bc33d6fc3e5.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, bangs, blue eyes, simple background, red eyes, gloves, hair between eyes, jewelry, very long hair, blue hair, braid, red hair, multicolored hair, armor, two-tone hair, heterochromia, tiara, crossed bangs
#
# /content/LoRA/train_data/02021a8067adda8ed384bc0c80d77b73.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, bangs, skirt, brown hair, shirt, hair ornament, long sleeves, bow, hair between eyes, school uniform, green eyes, jacket, full body, white shirt, pleated skirt, shoes, socks, hairclip, red bow, side ponytail, one side up, brown footwear, white socks, loafers
#
# /content/LoRA/train_data/027c1d95d00ecbbeee99aaaa8de03859.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, looking at viewer, smile, short hair, open mouth, bangs, simple background, shirt, hair ornament, bow, hair between eyes, twintails, jacket, white shirt, upper body, pink hair, teeth, hairclip, signature, bowtie, star (symbol), dated, orange eyes, pink background, short twintails, blue jacket, star hair ornament
#
# /content/LoRA/train_data/0320d717c5f2ae89e2e9d9b0879fd158.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, smile, bangs, white background, closed mouth, flower, lying, white flower, one eye covered, android, cable, mechanical parts, flower over eye
#
# /content/LoRA/train_data/058efb9dae3f90be00c9a31d4e7948d2.jpg:
#   Character tags:
#   General tags: long hair, breasts, short hair, bangs, blue eyes, multiple girls, red eyes, gloves, jewelry, medium breasts, very long hair, blue hair, weapon, braid, red hair, multicolored hair, earrings, multiple boys, sword, dark skin, 3girls, holding weapon, armor, two-tone hair, dark-skinned female, heterochromia, holding sword, cover, crossed bangs, split-color hair
#   4% 1/24 [00:05<02:15,  5.89s/it]
# /content/LoRA/train_data/07d79de8bcca0cc1ce7ad207db65ac43.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, bangs, blue eyes, shirt, black hair, hair ornament, blue hair, parted lips, sleeveless, hairclip, nail polish, fingernails, ring, x hair ornament, bandaid, hand on own face, head rest, green nails, bandaid on hand
#
# /content/LoRA/train_data/0d0e0fd732db60540af627a04579f980.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, blue eyes, holding, blue hair, jacket, upper body, parted lips, glasses, black jacket, blue background, phone, ring, goggles, semi-rimless eyewear, red-framed eyewear, under-rim eyewear, earphones, earbuds
#
# /content/LoRA/train_data/0d5bd960d4fafd88a438732f2585e675.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, 1boy, white background, yellow eyes, weapon, male focus, scarf, robot, colored sclera, science fiction, red scarf, bandana, black sclera, animification, humanoid robot, red bandana
#
# /content/LoRA/train_data/0dcfefee797f235f23121d6da8f00458.jpg:
#   Character tags: edelgard von hresvelg, claude von riegan, dimitri alexandre blaiddyd
#   General tags: 1girl, long hair, looking at viewer, smile, short hair, blue eyes, blonde hair, simple background, brown hair, gloves, long sleeves, ribbon, jewelry, closed mouth, green eyes, purple eyes, hair ribbon, braid, white hair, pantyhose, earrings, multiple boys, white gloves, dark skin, 2boys, grey background, cape, uniform, ascot, crossed arms, dark-skinned male, red cape, blue cape, garreg mach monastery uniform, yellow cape
#
# /content/LoRA/train_data/0eada6eafb9bbcf34bee71990853370b.jpg:
#   Character tags: usada pekora, sakura miko
#   General tags: long hair, breasts, looking at viewer, smile, open mouth, bangs, multiple girls, skirt, shirt, hair ornament, red eyes, dress, bow, ribbon, 2girls, animal ears, hair between eyes, twintails, closed mouth, green eyes, blue hair, white shirt, pink hair, braid, ahoge, white hair, short sleeves, :d, multicolored hair, shorts, teeth, alternate costume, puffy sleeves, virtual youtuber, white dress, rabbit ears, twin braids, two-tone hair, puffy short sleeves, animal ear fluff, symbol-shaped pupils, short shorts, upper teeth only, thick eyebrows, blue ribbon, blue shorts, short eyebrows, rabbit girl, food-themed hair ornament, confetti, carrot hair ornament
#
# /content/LoRA/train_data/0f7f5488cae8142fce388ba53a55f464.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, bangs, simple background, bare shoulders, closed mouth, yellow eyes, upper body, white hair, from side, profile, red background, multicolored eyes, colorful, abstract
#
# /content/LoRA/train_data/0fa53e7f207f6ddabb7d1817e0b40033.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, smile, open mouth, skirt, simple background, brown hair, hair ornament, brown eyes, jewelry, full body, dark skin, bracelet, dark-skinned female, yellow background, beads, very dark skin
#
# /content/LoRA/train_data/13d3803aa685351316bc7970f5272bc1.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, looking at viewer, smile, short hair, bangs, blue eyes, large breasts, red eyes, gloves, 1boy, jewelry, medium breasts, very long hair, blue hair, red hair, multicolored hair, earrings, two-tone hair, thigh strap, heterochromia, ring, fire, crossed bangs, crown braid, split-color hair
#   8% 2/24 [00:06<01:09,  3.18s/it]
# /content/LoRA/train_data/1aca689b23bdab8fefd9c2e251c6a335.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, bangs, twintails, closed mouth, blue hair, purple eyes, signature, grey background, profile, portrait, bandaid, close-up, bandaid on face, bandaid on nose, bandaid on cheek
#
# /content/LoRA/train_data/1d991d0c6d07c86e0c66fc44c2b4b47b.png:
#   Character tags:
#   General tags: solo, looking at viewer, smile, short hair, blonde hair, simple background, shirt, gloves, long sleeves, 1boy, white background, sitting, jacket, yellow eyes, white shirt, male focus, pants, white gloves, ascot
#
# /content/LoRA/train_data/1ed1e8776a31cd8ab388c2aeebd182d0.jpg:
#   Character tags:
#   General tags: solo, open mouth, 1boy, holding, yellow eyes, pink hair, braid, male focus, scarf, book, holding book, open book
#
# /content/LoRA/train_data/1ee87a7b1fd75487325ac2ec9cabe43b.jpg:
#   Character tags: marth (fire emblem)
#   General tags: solo, looking at viewer, smile, short hair, open mouth, blue eyes, gloves, 1boy, blue hair, short sleeves, male focus, black gloves, belt, fingerless gloves, cape, armor, tiara, shoulder armor, clenched hand, blue cape
#
# /content/LoRA/train_data/1fb2fbd2b8c58e1043395bfcfa823f34.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, looking at viewer, short hair, simple background, black hair, red eyes, gloves, white background, holding, standing, full body, weapon, boots, black gloves, holding weapon, armor, torn clothes, fur trim, polearm, spear, holding polearm
#
# /content/LoRA/train_data/2031b8da3ae7aaa43049f9d40082c029.jpg:
#   Character tags:
#   General tags: 1girl, looking at viewer, short hair, skirt, brown hair, hair ornament, white background, bow, animal ears, green eyes, tail, full body, short sleeves, shoes, shorts, socks, midriff, virtual youtuber, crop top, multiple views, white footwear, horse ears, horse girl, horse tail, reference sheet, color guide
#
# /content/LoRA/train_data/22cb3da6c136ecacf3ec5b291e2f6292.jpg:
#   Character tags: hakos baelz
#   General tags: 1girl, long hair, looking at viewer, smile, bangs, blue eyes, simple background, black hair, hair ornament, gloves, white background, navel, animal ears, twintails, closed mouth, standing, jacket, tail, full body, white hair, short sleeves, red hair, multicolored hair, shoes, shorts, alternate costume, black gloves, hairclip, midriff, belt, virtual youtuber, fingerless gloves, streaked hair, crop top, multiple views, chain, black shorts, piercing, sneakers, fishnets, asymmetrical legwear, cropped jacket, mouse ears, zoom layer, on head, hip vent, mouse tail, animal on head, mouse, asymmetrical sleeves, mouse girl, cheese
#
# /content/LoRA/train_data/27294e07cabdc5146ee2c2a379631a7d.png:
#   Character tags: wraith (apex legends)
#   General tags: breasts, blue eyes, multiple girls, skirt, black hair, gloves, holding, 2girls, brown eyes, medium breasts, jacket, weapon, red hair, dark skin, hair bun, holding weapon, official alternate costume, dark-skinned female, see-through, gun, double bun, mask, cover, white footwear, white jacket, robot, goggles, cover page, sneakers, holding gun, handgun, mouth mask, hair behind ear, open hand, animification
#  12% 3/24 [00:06<00:47,  2.28s/it]
# /content/LoRA/train_data/2bb49cc145e5f72b2ed6aab376bba1de.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, open mouth, bangs, blue eyes, blonde hair, long sleeves, navel, standing, jacket, full body, :d, boots, shoes, shorts, socks, fang, midriff, belt, black footwear, arm up, crop top, sleeves past wrists, short shorts, black shorts, white jacket, black background, bandaid, bandaid on leg, bandaid on knee, yellow socks
#
# /content/LoRA/train_data/2dbebf3aabe238428948169aea8de41d.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, bangs, blue eyes, skirt, shirt, hair ornament, red eyes, thighhighs, long sleeves, hair between eyes, bare shoulders, very long hair, closed mouth, standing, jacket, full body, white shirt, white hair, red hair, multicolored hair, pleated skirt, open clothes, shoes, shorts, sleeveless, socks, hairclip, off shoulder, open jacket, streaked hair, sleeveless shirt, headphones, outstretched arm, black background, bike shorts, single thighhigh, sneakers, asymmetrical legwear, uneven legwear, headphones around neck, shorts under skirt, single sock, asymmetrical footwear, mismatched footwear
#
# /content/LoRA/train_data/2f9f7e470bee034b51fbbe11ab475593.jpg:
#   Character tags: minato aqua, hoshimachi suisei, tokoyami towa
#   General tags: long hair, looking at viewer, smile, open mouth, bangs, blue eyes, multiple girls, skirt, hair ornament, bow, ribbon, hair between eyes, closed mouth, green eyes, blue hair, purple eyes, hair ribbon, pink hair, purple hair, ahoge, short sleeves, multicolored hair, frills, hairclip, fang, virtual youtuber, 3girls, star (symbol), arm up, two-tone hair, blue skirt, streaked hair, wrist cuffs, blue ribbon, colored inner hair, symbol in eye, star in eye
#
# /content/LoRA/train_data/304d02e03bae741922061dbe3e5589a6.png:
#   Character tags: sei shounagon (fate)
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, blush, smile, bangs, blonde hair, large breasts, long sleeves, bow, navel, holding, cleavage, bare shoulders, twintails, closed mouth, blue hair, standing, jacket, swimsuit, full body, yellow eyes, heart, sidelocks, bikini, red hair, multicolored hair, outdoors, open clothes, sky, choker, day, off shoulder, open jacket, tree, blue sky, thigh strap, sandals, sunglasses, animal print, eyewear on head, red jacket, palm tree, adjusting eyewear, heart-shaped eyewear, leopard print, inflatable toy, brown bikini
#
# /content/LoRA/train_data/324ec564e1d532f14f4cd3a6a3e6fca7.jpg:
#   Character tags:
#   General tags: looking at viewer, smile, simple background, gloves, 1boy, hat, white background, full body, male focus, boots, white gloves, black footwear, orange hair, multiple views, multicolored clothes, reference sheet
#
# /content/LoRA/train_data/36dc23269119c2db186313a2bdf34587.jpg:
#   Character tags:
#   General tags: long hair, looking at viewer, smile, short hair, open mouth, bangs, blue eyes, multiple girls, blonde hair, brown hair, shirt, black hair, hair ornament, red eyes, bow, holding, animal ears, twintails, brown eyes, green eyes, blue hair, standing, purple eyes, yellow eyes, white shirt, ponytail, pink hair, purple hair, braid, white hair, grey hair, red hair, multicolored hair, hairband, boots, shoes, belt, pants, pink eyes, orange hair, rabbit ears, side ponytail, streaked hair, fake animal ears, 6+girls, baseball cap, white pants, paint splatter, paint, graffiti
#
# /content/LoRA/train_data/370b3a41fddb4cd15d9a5aa50881f277.jpg:
#   Character tags:
#   General tags: solo, short hair, open mouth, hair ornament, red eyes, long sleeves, 1boy, holding, hair between eyes, blue hair, weapon, male focus, parted lips, hairclip, signature, holding weapon, armor, dated, ascot, blue background, bow (weapon), arrow (projectile), holding bow (weapon), white ascot, holding arrow
#
# /content/LoRA/train_data/38c43d0157ab2cab9a7b6bea0b6e82c7.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, bangs, gloves, green eyes, upper body, white hair, parted lips, english text, headphones, microphone
#  17% 4/24 [00:07<00:36,  1.83s/it]
# /content/LoRA/train_data/39f48f9b62c5a4d3717df213af39f1ae.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, bangs, skirt, blonde hair, large breasts, red eyes, long sleeves, jewelry, very long hair, standing, jacket, full body, pantyhose, hairband, open clothes, sleeveless, belt, necklace, sweater, open jacket, black pantyhose, turtleneck, black background, corset, grey skirt, white sweater
#
# /content/LoRA/train_data/3ea6107069638590363923b11e8d3843.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, looking at viewer, smile, open mouth, bangs, skirt, long sleeves, dress, cleavage, purple eyes, pink hair, flower, heart, pantyhose, multicolored hair, boots, frills, one eye closed, striped, puffy sleeves, pink eyes, black footwear, high heels, fingernails, fur trim, v, rose, blue background, ;d, juliet sleeves, red flower, vertical stripes, high heel boots, hair rings, blue footwear, striped pantyhose, v over eye, blue pantyhose
#
# /content/LoRA/train_data/3f3dd10944af7804f49ac0496045e40d.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, open mouth, bangs, brown hair, hair ornament, jewelry, green eyes, japanese clothes, hairclip, virtual youtuber, kimono, bracelet, sash, one side up, obi, waving, logo, open hand, orange kimono
#
# /content/LoRA/train_data/3fa220b52e10c388d4301bdce1b6aaa9.png:
#   Character tags:
#   General tags: 1girl, long hair, breasts, looking at viewer, smile, short hair, bangs, blue eyes, simple background, red eyes, thighhighs, 1boy, jewelry, medium breasts, very long hair, blue hair, weapon, braid, red hair, multicolored hair, sword, cape, holding weapon, armor, two-tone hair, thigh strap, heterochromia, tiara, green background, crossed bangs, crown braid, split-color hair
#
# /content/LoRA/train_data/3fd4fc23e19ebddeb8bd16b39533389f.jpg:
#   Character tags: kaguya luna
#   General tags: 1girl, solo, skirt, long sleeves, twintails, jewelry, jacket, white hair, pleated skirt, earrings, virtual youtuber, black skirt, from behind, nail polish, black jacket, v, red nails, facing away
#
# /content/LoRA/train_data/4002ddcf968786f5e4d5c89e6a2b2a0d.png:
#   Character tags:
#   General tags: 1girl, solo, short hair, bangs, blue eyes, hair ornament, thighhighs, hat, dress, closed mouth, school uniform, standing, full body, white hair, short sleeves, boots, serafuku, hairclip, striped, sailor collar, black footwear, white dress, hair over one eye, zettai ryouiki, neckerchief, black headwear, beret, standing on one leg, black background, wristband, striped thighhighs, sailor dress, black sailor collar, green neckerchief
#
# /content/LoRA/train_data/4053ac33e99e277ea1584bbe03f94b23.png:
#   Character tags: tokino sora
#   General tags: long hair, smile, open mouth, blue eyes, multiple girls, skirt, blonde hair, brown hair, hair ornament, green eyes, blue hair, grey hair, shorts, virtual youtuber, 3girls, star (symbol), arm up, high heels, blue skirt, pointing, blue footwear, star hair ornament, confetti, idol, stage, screen
#
# /content/LoRA/train_data/40e82b9d6eb02ada8c04de4e2d54a21f.jpg:
#   Character tags: suletta mercury, miorine rembran
#   General tags: long hair, open mouth, bangs, blue eyes, multiple girls, long sleeves, 2girls, hair between eyes, school uniform, jacket, ahoge, white hair, grey hair, pantyhose, red hair, hairband, boots, sky, shorts, black footwear, grey eyes, black pantyhose, thick eyebrows, black hairband, robot, mecha, low ponytail, v-fin, mobile suit, asticassia school uniform
#  21% 5/24 [00:07<00:29,  1.56s/it]
# /content/LoRA/train_data/424fef1cd1f46f3b7bb3895e6c43711c.jpg:
#   Character tags: makima (chainsaw man), power (chainsaw man)
#   General tags: long hair, breasts, looking at viewer, smile, bangs, multiple girls, blonde hair, large breasts, simple background, gloves, hat, dress, 2girls, hair between eyes, medium breasts, yellow eyes, braid, short sleeves, red hair, parted lips, horns, alternate costume, black gloves, elbow gloves, white dress, yuri, lips, orange eyes, symbol-shaped pupils, black background, demon horns, breast press, brown gloves, braided ponytail, nurse cap, nurse, ringed eyes, red horns, hand on another's chin, cross-shaped pupils
#
# /content/LoRA/train_data/425566c82b9c82ad9764bff05db11de1.jpg:
#   Character tags: marth (fire emblem)
#   General tags: solo, looking at viewer, blue eyes, simple background, gloves, 1boy, holding, blue hair, standing, full body, weapon, short sleeves, male focus, boots, belt, pants, sword, fingerless gloves, cape, holding weapon, armor, blue background, holding sword, tiara, blue theme, blue cape
#
# /content/LoRA/train_data/43bff1e0623a35dc507ea8b050758af9.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, bangs, blue eyes, skirt, simple background, red eyes, thighhighs, gloves, jewelry, medium breasts, very long hair, blue hair, full body, weapon, braid, red hair, multicolored hair, sword, cape, holding weapon, armor, two-tone hair, thigh strap, heterochromia, holding sword, tiara, crossed bangs, crown braid, split-color hair
#
# /content/LoRA/train_data/4428f4c1b15c7ff07f0e8dc2859f0ecf.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, blue eyes, dress, ribbon, holding, blue hair, flower, sleeveless, signature, white dress, grin, red ribbon, floating hair, sleeveless dress, blue background, multicolored eyes, holding flower, orange flower, orange ribbon
#
# /content/LoRA/train_data/44a7e4dc9ca141ebfbeac39e9a672f43.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, blue eyes, dress, ribbon, holding, blue hair, flower, sleeveless, hand up, signature, white dress, grin, red ribbon, floating hair, sleeveless dress, blue background, multicolored eyes, holding flower, orange flower, orange ribbon
#
# /content/LoRA/train_data/4629d28d8cdaa00d57e57f2d56527a90.jpg:
#   Character tags: hakos baelz
#   General tags: 1girl, solo, long hair, looking at viewer, smile, open mouth, bangs, blue eyes, shirt, black hair, hair ornament, gloves, holding, animal ears, twintails, jacket, tail, white shirt, white hair, red hair, multicolored hair, one eye closed, shoes, shorts, black gloves, fang, midriff, virtual youtuber, black footwear, collar, streaked hair, animal ear fluff, headphones, black shorts, ;d, sneakers, fishnets, multicolored clothes, spikes, asymmetrical legwear, mouse ears, mismatched legwear, mouse tail, headphones around neck, spiked collar, colorful, mouse girl, spray can
#
# /content/LoRA/train_data/46b1ed71fab764147d387c6e11419655.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, short hair, blue eyes, gloves, 1boy, weapon, white hair, male focus, sword, signature, armor, dated, facial hair, blue background, shoulder armor, beard, pauldrons, breastplate, mature male, mustache, old, old man
#
# /content/LoRA/train_data/484b5989f66e4bb5b9eb80ab33d94910.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, bangs, white background, holding, jewelry, blue hair, upper body, pink hair, multicolored hair, earrings, parted lips, hood, hoodie, hood down, multicolored eyes, blue hoodie
#  25% 6/24 [00:08<00:24,  1.37s/it]
# /content/LoRA/train_data/4b1d3e6981255f05705a78417eca745f.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, looking at viewer, smile, bangs, blue eyes, brown hair, dress, cleavage, bare shoulders, medium breasts, collarbone, parted lips, sleeveless, water, white dress, grin, hands up, bare arms, floating hair, sleeveless dress, feet out of frame, leg ribbon
#
# /content/LoRA/train_data/4cbb60318303a883cb4f25fec4875cce.jpg:
#   Character tags:
#   General tags: long hair, breasts, smile, multiple girls, simple background, red eyes, 2girls, cleavage, hair between eyes, medium breasts, closed mouth, armor, grin, sketch, black background, dual persona
#
# /content/LoRA/train_data/5315a07d2578d1330b5792a96be989ec.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, blonde hair, thighhighs, gloves, hat, bow, yellow eyes, braid, boots, shorts, sleeveless, black gloves, black thighhighs, twin braids, brown footwear, pink background, bike shorts, headwear removed, kicking
#
# /content/LoRA/train_data/544176d4ce458b6e21d295b60d836e76.jpg:
#   Character tags:
#   General tags: long hair, breasts, looking at viewer, smile, short hair, open mouth, bangs, blue eyes, multiple girls, blonde hair, large breasts, brown hair, black hair, red eyes, thighhighs, gloves, dress, holding, cleavage, twintails, jewelry, medium breasts, very long hair, green eyes, blue hair, purple eyes, yellow eyes, weapon, pink hair, purple hair, braid, white hair, red hair, multicolored hair, earrings, multiple boys, horns, pointy ears, sword, dark skin, fingerless gloves, cape, holding weapon, armor, hair over one eye, two-tone hair, thigh strap, 6+girls, heterochromia, holding sword, dark-skinned male, ring, tiara, 6+boys, crossed bangs, crown braid, split-color hair
#
# /content/LoRA/train_data/54a4b89b7117b88462c7535bf8ef6eb2.jpg:
#   Character tags: kureiji ollie, moona hoshinova
#   General tags: long hair, looking at viewer, smile, open mouth, multiple girls, skirt, blonde hair, brown hair, red eyes, hat, bow, green eyes, blue hair, purple eyes, yellow eyes, pink hair, purple hair, hair bow, grey hair, red hair, multicolored hair, one eye closed, tongue, midriff, virtual youtuber, tongue out, hair bun, grin, side ponytail, colored skin, 6+girls, heterochromia, claw pose, stitches, idol, grey skin, zombie, patchwork skin
#
# /content/LoRA/train_data/55687762af38561396b107f261426f6a.jpg:
#   Character tags: haruno sakura, uzumaki naruto, uchiha sasuke
#   General tags: 1girl, looking at viewer, smile, short hair, open mouth, blue eyes, blonde hair, black hair, green eyes, jacket, pink hair, :d, multiple boys, shorts, teeth, 2boys, grin, black eyes, facial mark, blue footwear, whisker markings, forehead protector, orange jacket
#
# /content/LoRA/train_data/5675d1bb209c25313a225fdf5789c32f.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, large breasts, hair ornament, navel, cleavage, bare shoulders, closed mouth, purple eyes, upper body, flower, white hair, horns, pointy ears, signature, dark skin, hair over one eye, dated, dark-skinned female, tassel, horn ornament
#
# /content/LoRA/train_data/583064c7aab43002d1ab1f858196fbc1.jpg:
#   Character tags: mori calliope, hakos baelz, irys (hololive)
#   General tags: long hair, breasts, looking at viewer, smile, open mouth, bangs, blue eyes, multiple girls, skirt, black hair, hair ornament, red eyes, thighhighs, hat, animal ears, cleavage, medium breasts, pink hair, white hair, red hair, multicolored hair, one eye closed, necktie, horns, shorts, pointy ears, virtual youtuber, 3girls, pink eyes, black footwear, high heels, streaked hair, v, thigh strap, mini hat, mouse ears, double v, mouse girl
#  29% 7/24 [00:08<00:21,  1.24s/it]
# /content/LoRA/train_data/5df840aa1db64471b94dab7700345840.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, simple background, thighhighs, gloves, dress, holding, bare shoulders, standing, purple eyes, full body, purple hair, flower, wings, elbow gloves, white gloves, cape, high heels, book, fur trim, rose, fishnets, holding book, green background, open book
#
# /content/LoRA/train_data/5e88945f24f53b2a2f3364323551d387.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, blush, smile, bangs, skirt, blonde hair, large breasts, shirt, hair ornament, thighhighs, long sleeves, bow, hair between eyes, twintails, jewelry, closed mouth, school uniform, standing, jacket, full body, yellow eyes, white shirt, pleated skirt, earrings, shoes, hairclip, collared shirt, black thighhighs, bowtie, red bow, zettai ryouiki, skindentation, brown footwear, scrunchie, loafers, green scrunchie
#
# /content/LoRA/train_data/6011db4d9f66f90271ddda8b0f0afa2f.jpg:
#   Character tags: kuzuha (nijisanji)
#   General tags: long hair, looking at viewer, smile, open mouth, bangs, blue eyes, shirt, red eyes, gloves, hair between eyes, jewelry, jacket, white shirt, upper body, ahoge, grey hair, male focus, earrings, multiple boys, necktie, teeth, pointy ears, collared shirt, virtual youtuber, white gloves, 2boys, nail polish, orange hair, mole, fingernails, fur trim, mole under eye, fangs, piercing, ring, white jacket, red necktie, ear piercing, red nails, long fingernails, sharp fingernails, vampire, multiple rings
#
# /content/LoRA/train_data/618a37360463bb4c10ab05f986404dea.jpg:
#   Character tags: tokino sora
#   General tags: long hair, smile, open mouth, blue eyes, multiple girls, skirt, blonde hair, brown hair, hair ornament, blue hair, grey hair, shorts, virtual youtuber, 3girls, star (symbol), arm up, high heels, pointing, star hair ornament, confetti, idol, stage, screen
#
# /content/LoRA/train_data/61f655f3583c13440be9bdd5b330ab51.png:
#   Character tags:
#   General tags: 1girl, solo, breasts, looking at viewer, smile, bangs, blue eyes, brown hair, dress, cleavage, bare shoulders, medium breasts, collarbone, parted lips, sleeveless, water, white dress, grin, hands up, bare arms, floating hair, sleeveless dress, feet out of frame, leg ribbon
#
# /content/LoRA/train_data/63d04311663c7e515c7c8fa7ba732157.png:
#   Character tags: sei shounagon (fate)
#   General tags: long hair, breasts, looking at viewer, blush, smile, short hair, bangs, multiple girls, large breasts, black hair, hat, dress, navel, 2girls, cleavage, bare shoulders, twintails, medium breasts, blue hair, jacket, swimsuit, yellow eyes, weapon, short sleeves, pantyhose, bikini, thighs, red hair, multicolored hair, one eye closed, open clothes, shorts, belt, sword, hair over one eye, black eyes, open jacket, wrist cuffs, grey eyes, short shorts, black headwear, thigh strap, headphones, white bikini, black shorts, eyepatch, katana, peaked cap, purple dress, dual persona, visor cap, headphones around neck, chewing gum
#
# /content/LoRA/train_data/6435a641cff43bc18eae967143fa1084.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, bangs, skirt, shirt, black hair, long sleeves, hat, animal ears, closed mouth, standing, jacket, full body, yellow eyes, white shirt, pleated skirt, socks, collared shirt, cat ears, hood, bracelet, blue skirt, hoodie, fake animal ears, black socks, baseball cap, animal hat, cat hat, fanny pack
#
# /content/LoRA/train_data/65581191f68ee220d37495cecbf416f8.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, bangs, blue eyes, long sleeves, hat, jewelry, blue hair, purple eyes, jacket, upper body, white hair, earrings, hand up, sleeves past wrists, bandaid, baseball cap, blue headwear, bandaid on face, bandaid on nose
#  33% 8/24 [00:09<00:18,  1.15s/it]
# /content/LoRA/train_data/65c677e206df1162c6a18c4be8893306.png:
#   Character tags: crypto (apex legends)
#   General tags: 1girl, looking at viewer, smile, blue eyes, blonde hair, shirt, black hair, gloves, hat, holding, jewelry, jacket, weapon, red hair, boots, parted lips, multiple boys, black gloves, pants, dark skin, 2boys, fingerless gloves, necklace, holding weapon, black eyes, vest, gun, black shirt, black headwear, bodysuit, copyright name, facial hair, black pants, dark-skinned male, white jacket, goggles, holding gun, rifle, green background, goggles on head, blue gloves, assault rifle, animification, green vest, shotgun
#
# /content/LoRA/train_data/68ecd5f6e636e57ebf4688b798fea396.jpg:
#   Character tags: watson amelia
#   General tags: 1girl, solo, looking at viewer, smile, short hair, bangs, blue eyes, skirt, blonde hair, simple background, shirt, long sleeves, white background, jewelry, full body, white shirt, pleated skirt, earrings, boots, necktie, glasses, virtual youtuber, black skirt, black footwear, grin, coat, sleeves past wrists, knee boots, sleeves past fingers, round eyewear, labcoat, monocle
#
# /content/LoRA/train_data/6bd2ba2c195f54976551e4b5c2ca059d.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, bangs, ribbon, hair between eyes, monochrome, flower, greyscale, black background, abstract
#
# /content/LoRA/train_data/6e3daf493d636f45e40007615d63fba3.png:
#   Character tags:
#   General tags: 1girl, solo, holding, yellow eyes, weapon, sword, hood, holding weapon, from side, leotard, holding sword, robot, yellow background, hood up, colored sclera, science fiction, android, black sclera, blue leotard, cable, animification
#
# /content/LoRA/train_data/6f456798b6a05ed9dff0113995fd2500.jpg:
#   Character tags: wraith (apex legends)
#   General tags: 1girl, looking at viewer, open mouth, bangs, blue eyes, black hair, gloves, holding, weapon, hair bun, scarf, holding weapon, gun, parted bangs, bodysuit, glowing, single hair bun, helmet, robot, goggles, holding gun, glowing eyes, red background, 1other, handgun, science fiction, black bodysuit, electricity, cable, open hand, animification, black scarf, revolver, ambiguous gender, humanoid robot
#
# /content/LoRA/train_data/6fd0bee5a200ad04c4748f8e14767107.png:
#   Character tags: wraith (apex legends)
#   General tags: 1girl, solo, breasts, looking at viewer, open mouth, bangs, blue eyes, black hair, holding, medium breasts, upper body, weapon, hair bun, scarf, holding weapon, official alternate costume, gun, bodysuit, single hair bun, helmet, holding gun, red background, handgun, black bodysuit, glass, animification, black scarf, broken glass
#
# /content/LoRA/train_data/70625d7ea4e2781628b900e5f4e59dd7.png:
#   Character tags:
#   General tags: long hair, breasts, looking at viewer, blush, smile, bangs, blue eyes, multiple girls, skirt, blonde hair, large breasts, simple background, shirt, gloves, long sleeves, 1boy, white background, dress, ribbon, 2girls, bare shoulders, brown eyes, sitting, very long hair, closed mouth, jacket, hair ribbon, yellow eyes, white shirt, braid, grey hair, pantyhose, hairband, boots, parted lips, sleeveless, black gloves, striped, puffy sleeves, pants, white gloves, hand up, hair bun, black footwear, black dress, high heels, red ribbon, parted bangs, ascot, sideboob, sleeveless dress, single hair bun, light brown hair, vertical stripes, red jacket, puffy long sleeves, high heel boots, striped skirt, white ascot, striped pants, vertical-striped skirt
#
# /content/LoRA/train_data/70c25a579467711d8450132cbefc3778.jpg:
#   Character tags: hakos baelz
#   General tags: 1girl, long hair, looking at viewer, smile, open mouth, bangs, blue eyes, simple background, black hair, hair ornament, thighhighs, white background, animal ears, hair between eyes, tail, full body, flower, white hair, :d, red hair, multicolored hair, detached sleeves, japanese clothes, fang, virtual youtuber, hair flower, wide sleeves, kimono, hair bun, streaked hair, sash, multiple views, mask, obi, floral print, sandals, ball, asymmetrical legwear, mouse ears, zoom layer, mask on head, mismatched legwear, mouse tail, mouse girl
#  38% 9/24 [00:09<00:16,  1.07s/it]
# /content/LoRA/train_data/7104537b5d5e12bb59d51c18ea99e480.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, bangs, blue eyes, dress, hair between eyes, bare shoulders, upper body, white hair, sleeveless, white dress, from side, english text, floating hair, sleeveless dress, cover, yellow background
#
# /content/LoRA/train_data/736a3f419001c8e1581df83d2e716a11.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, bangs, blue eyes, hair ornament, hair between eyes, bare shoulders, blue hair, upper body, flower, parted lips, hair flower, nail polish, hands up, petals, heterochromia, red flower, portrait, blue nails, green background, blue flower, multicolored eyes, green nails, multicolored nails, colorful
#
# /content/LoRA/train_data/753262faba4cee5003f3a1a6f2ebfab1.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, bangs, blue eyes, simple background, hair between eyes, blue hair, parted lips, tears, looking to the side, blue background, looking away, portrait
#
# /content/LoRA/train_data/753aabcd325c0868c2c0c5bc2f183924.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, blue eyes, shirt, black hair, hair ornament, twintails, upper body, braid, short sleeves, tongue, striped, tongue out, blunt bangs, nail polish, twin braids, hands up, bandaid, red background, :p, blue nails, striped shirt, overalls, hands on own face, green nails, hands on own cheeks, multicolored nails, bandaid on arm, nail art, bandaid on hand
#
# /content/LoRA/train_data/756a532e3ba955a0b3154c2b6449c5a0.jpg:
#   Character tags: marth (fire emblem)
#   General tags: long hair, breasts, looking at viewer, smile, short hair, bangs, blue eyes, multiple girls, red eyes, jewelry, medium breasts, very long hair, blue hair, weapon, purple hair, braid, red hair, multicolored hair, multiple boys, sword, 3girls, armor, two-tone hair, thigh strap, heterochromia, fire, tiara, crossed bangs, dragon, crown braid, split-color hair
#
# /content/LoRA/train_data/75a50489383bede30e23ffc916428027.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, bangs, skirt, simple background, shirt, black hair, white background, holding, very long hair, closed mouth, school uniform, standing, full body, ponytail, weapon, short sleeves, pleated skirt, shoes, serafuku, socks, sword, black skirt, sailor collar, black footwear, holding weapon, black eyes, neckerchief, hand on hip, grey eyes, black shirt, bandages, holding sword, katana, white socks, loafers, black sailor collar, black serafuku, absurdly long hair, blue neckerchief, loose socks
#
# /content/LoRA/train_data/7683b8e941724a4c30ff267f2b1ef951.png:
#   Character tags: sei shounagon (fate)
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, blush, smile, bangs, skirt, black hair, thighhighs, long sleeves, bow, navel, twintails, medium breasts, blue hair, jacket, swimsuit, yellow eyes, ass, hair bow, heart, bikini, thighs, red hair, multicolored hair, frills, one eye closed, open clothes, sky, day, black thighhighs, black skirt, water, off shoulder, grin, open jacket, blue sky, black jacket, v, thigh strap, underboob, black bikini, sunglasses, bikini top only, eyewear on head, w, heart-shaped eyewear
#
# /content/LoRA/train_data/77e4142775b240c8232e48d85c5efe7a.jpg:
#   Character tags:
#   General tags: long hair, looking at viewer, smile, short hair, open mouth, blue eyes, multiple girls, skirt, blonde hair, black hair, hair ornament, red eyes, twintails, school uniform, green eyes, purple eyes, jacket, yellow eyes, pink hair, flower, red hair, glasses, 6+girls, plaid skirt, blue jacket
#  42% 10/24 [00:10<00:14,  1.01s/it]
# /content/LoRA/train_data/78a064dc3b43b83f153d53c9870d3b13.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, open mouth, bangs, blue eyes, brown hair, black hair, hair ornament, long sleeves, navel, animal ears, hair between eyes, standing, jacket, full body, shoes, shorts, socks, hairclip, midriff, belt, virtual youtuber, hood, crop top, kneehighs, short shorts, hoodie, hood down, black background, sneakers, dog ears, drawstring, green shorts, green footwear
#
# /content/LoRA/train_data/7af385c43d78e6ba791ff3a6c3941007.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, open mouth, bangs, blonde hair, hair ornament, thighhighs, dress, bow, cleavage, green eyes, :d, detached sleeves, teeth, signature, white thighhighs, crown, yellow background, green bow, green background, butterfly hair ornament
#
# /content/LoRA/train_data/8119d07e4640869aeed7eba34ae60fa8.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, bangs, blue eyes, hair ornament, holding, jewelry, blue hair, collarbone, upper body, earrings, frills, parted lips, hairclip, wrist cuffs, maid, maid headdress, blue background, ring, bandaid, smoke, cigarette, smoking, yellow nails, holding cigarette
#
# /content/LoRA/train_data/81f30c9ff32935aebf548ead3809568d.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, shirt, black hair, hair between eyes, brown eyes, school uniform, blue hair, white shirt, upper body, flower, multicolored hair, teeth, serafuku, sailor collar, water, grin, neckerchief, blue sailor collar, cherry blossoms, portrait, red neckerchief
#
# /content/LoRA/train_data/8212989006b53b168a4a9edba6ca19c4.png:
#   Character tags: mejiro mcqueen (umamusume), tokai teio (umamusume)
#   General tags: long hair, looking at viewer, blush, smile, open mouth, bangs, blue eyes, multiple girls, skirt, brown hair, long sleeves, bow, ribbon, 2girls, animal ears, closed mouth, purple eyes, jacket, ponytail, purple hair, white hair, multicolored hair, pleated skirt, streaked hair, ascot, blue background, white skirt, horse ears, horse girl, index finger raised, ear ribbon, pink ascot
#
# /content/LoRA/train_data/824427808daf4ab9eea18e92e5260416.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, open mouth, bangs, simple background, shirt, hair ornament, twintails, jewelry, green eyes, upper body, flower, heart, red hair, earrings, necktie, hairclip, collared shirt, torn clothes, plaid, clothing cutout, piercing, cross, x hair ornament, ear piercing, bandaid, green background, bandaid on face, green necktie, bandaid on nose, safety pin
#
# /content/LoRA/train_data/82feb4fe786d2fc23b1f62781bc1b39e.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, bangs, blue eyes, skirt, red eyes, thighhighs, gloves, jewelry, medium breasts, very long hair, blue hair, full body, weapon, braid, red hair, multicolored hair, sword, cape, holding weapon, armor, two-tone hair, thigh strap, heterochromia, holding sword, tiara, crossed bangs, crown braid, split-color hair
#
# /content/LoRA/train_data/832e77a79ca0663dcb6a1068b211b3c9.png:
#   Character tags: hayami kanade
#   General tags: 1girl, solo, looking at viewer, smile, short hair, bangs, jewelry, green eyes, jacket, full body, grey hair, earrings, necktie, striped, pants, hand on hip, parted bangs, clothing cutout, formal, suit, grey pants, green necktie
#  46% 11/24 [00:10<00:12,  1.04it/s]
# /content/LoRA/train_data/86dfc914a20d91d16bf77dbc60d2c1b2.png:
#   Character tags: wattson (apex legends)
#   General tags: breasts, smile, blue eyes, multiple girls, blonde hair, 1boy, holding, 2girls, jacket, yellow eyes, weapon, one eye closed, hood, 2boys, scarf, holding weapon, leotard, gun, bodysuit, robot, holding gun, yellow background, blue headwear, hood up, colored sclera, science fiction, bandana, android, black sclera, blue gloves, electricity, blue leotard, cable, open hand, animification, submachine gun, white bodysuit, blue bodysuit, orange jacket, humanoid robot, ribbed bodysuit, red bandana
#
# /content/LoRA/train_data/879bf27990073895ec03eb5bed4f325a.png:
#   Character tags: souryuu asuka langley, ayanami rei
#   General tags: long hair, breasts, looking at viewer, short hair, bangs, blue eyes, multiple girls, red eyes, 2girls, hair between eyes, medium breasts, closed mouth, blue hair, lying, on back, orange hair, bodysuit, covered navel, eyepatch, skin tight, black bodysuit, plugsuit, white bodysuit, interface headset
#
# /content/LoRA/train_data/89d4baa10b5343800067e97601aaf51a.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, skirt, shirt, hair ornament, red eyes, long sleeves, bow, school uniform, blue hair, standing, jacket, full body, white shirt, pantyhose, pleated skirt, boots, open clothes, hairclip, collared shirt, belt, black footwear, red bow, open jacket, black pantyhose
#
# /content/LoRA/train_data/8a97f1306014ca0f6f930bc74e73e2a7.jpg:
#   Character tags: makima (chainsaw man), power (chainsaw man)
#   General tags: long hair, breasts, looking at viewer, smile, multiple girls, blonde hair, large breasts, thighhighs, gloves, hat, dress, 2girls, hair between eyes, yellow eyes, ass, braid, red hair, parted lips, horns, elbow gloves, yuri, lips, orange eyes, symbol-shaped pupils, demon horns, breast press, brown gloves, braided ponytail, nurse cap, nurse, ringed eyes, red horns, hand on another's chin, cross-shaped pupils
#
# /content/LoRA/train_data/8b928f263d1c5ae378606a624192b287.jpg:
#   Character tags: souryuu asuka langley, ayanami rei
#   General tags: long hair, breasts, looking at viewer, short hair, bangs, blue eyes, multiple girls, brown hair, red eyes, 2girls, hair between eyes, blue hair, upper body, lying, parted lips, orange hair, bodysuit, eyepatch, black bodysuit, plugsuit, white bodysuit, interface headset
#
# /content/LoRA/train_data/8bda5a4c86059e5380b964aa163b0937.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, open mouth, blue eyes, dress, ribbon, blue hair, flower, :d, barefoot, sleeveless, armpits, white dress, red ribbon, floating hair, sleeveless dress, white flower, red flower, blue flower, purple flower, picture frame, colorful, painting (object)
#
# /content/LoRA/train_data/8c1a134f47342bfcc965ec65f9a78687.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, bangs, shirt, black hair, brown eyes, white shirt, upper body, short sleeves, multicolored hair, indoors, hand up, signature, bag, grin, streaked hair, v, backpack, t-shirt, photo background, american flag
#
# /content/LoRA/train_data/8d086ebc7681ec938e0b37c237c1062d.jpg:
#   Character tags:
#   General tags: long hair, looking at viewer, smile, short hair, bangs, blue eyes, multiple girls, brown hair, black hair, hair ornament, red eyes, holding, hair between eyes, twintails, blue hair, purple eyes, jacket, braid, white hair, grey hair, multicolored hair, parted lips, one eye closed, glasses, teeth, pointy ears, hairclip, hair bun, grin, headphones, 6+girls, sunglasses, eyewear on head
#  50% 12/24 [00:11<00:11,  1.09it/s]
# /content/LoRA/train_data/8f11c26c9139f914b6a4f0a5e3a17dc1.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, open mouth, bangs, blue eyes, skirt, shirt, school uniform, blue hair, white shirt, short sleeves, pleated skirt, teeth, serafuku, sailor collar, grin, arm up, blue skirt, neckerchief, blue sailor collar, red neckerchief, multicolored eyes
#
# /content/LoRA/train_data/8f38596be8af5561daa7c597c88871f4.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, smile, short hair, blonde hair, hair ornament, long sleeves, 1boy, yellow eyes, male focus, signature, cape, hand on hip, ascot, blue pants
#
# /content/LoRA/train_data/907a3e1b1311d7f313b85a31311f1a02.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, smile, short hair, bangs, shirt, hair ornament, long sleeves, bow, hair between eyes, twintails, closed mouth, school uniform, jacket, yellow eyes, white shirt, upper body, pink hair, red hair, open clothes, hairclip, collared shirt, indoors, bowtie, star (symbol), red bow, sparkle, short twintails, blue jacket, hand on own chest, red bowtie, star hair ornament
#
# /content/LoRA/train_data/9127477e129d6232fff54c8c400f80c8.jpg:
#   Character tags: hatsune miku
#   General tags: 1girl, long hair, looking at viewer, smile, skirt, hair ornament, thighhighs, white background, dress, bare shoulders, twintails, very long hair, full body, detached sleeves, from behind, aqua eyes, aqua hair, multiple views, asymmetrical legwear, reference sheet, asymmetrical sleeves, asymmetrical footwear, mismatched footwear, color guide
#
# /content/LoRA/train_data/925af30b43a86c2575655eb1707ebce7.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, bangs, shirt, hair ornament, hair between eyes, bare shoulders, closed mouth, closed eyes, upper body, detached sleeves, hairclip, headphones, black background
#
# /content/LoRA/train_data/9356a1c218a323f93b5f89bc5544b6bd.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, smile, simple background, red eyes, 1boy, white background, holding, hair between eyes, jewelry, standing, full body, weapon, white hair, male focus, multicolored hair, boots, parted lips, choker, pants, black footwear, holding weapon, armor, grin, axe, holding axe, halberd
#
# /content/LoRA/train_data/9719e00aebadc31933d8047afd7bb649.png:
#   Character tags: wraith (apex legends)
# ...
#  79% 19/24 [00:15<00:04,  1.23it/s]
# /content/LoRA/train_data/d2659cefafc9518f99a57c1234675ae9.jpg:
#   Character tags: wraith (apex legends)
#   General tags: breasts, smile, short hair, bangs, blue eyes, multiple girls, black hair, gloves, holding, 2girls, brown eyes, medium breasts, weapon, grey hair, shorts, hair bun, scarf, holding weapon, vest, gun, black headwear, bodysuit, mask, floating hair, single hair bun, goggles, holding gun, red background, rifle, mouth mask, black bodysuit, hair behind ear, assault rifle, animification, green vest, sniper rifle, green shorts, orange bodysuit, broken glass, mechanical legs, cropped vest, jetpack, missile pod
#
# /content/LoRA/train_data/d3215e3bc2a3efb870a2a88615a53f78.png:
#   Character tags: usada pekora, sakura miko
#   General tags: long hair, breasts, looking at viewer, smile, open mouth, bangs, multiple girls, skirt, shirt, hair ornament, red eyes, dress, bow, ribbon, 2girls, animal ears, hair between eyes, twintails, closed mouth, green eyes, blue hair, white shirt, pink hair, braid, ahoge, white hair, short sleeves, :d, multicolored hair, shorts, teeth, alternate costume, puffy sleeves, virtual youtuber, white dress, rabbit ears, twin braids, two-tone hair, official alternate costume, puffy short sleeves, animal ear fluff, symbol-shaped pupils, short shorts, upper teeth only, thick eyebrows, blue ribbon, blue shorts, short eyebrows, rabbit girl, food-themed hair ornament, confetti, carrot hair ornament
#
# /content/LoRA/train_data/d36d4ac4fbbfde297ad1c534f94fdbd2.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, bangs, simple background, shirt, twintails, closed mouth, blue hair, white shirt, collared shirt, portrait, bandaid, close-up, multicolored eyes, bandaid on face, bandaid on nose, bandaid on cheek
#
# /content/LoRA/train_data/d6fa66f07406b0d9484ba3d6a035af93.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, bangs, simple background, pink hair, parted lips, glasses, pink eyes, nail polish, pink background, own hands together, portrait, close-up, multicolored eyes, round eyewear, tinted eyewear, yellow nails, pink-tinted eyewear
#
# /content/LoRA/train_data/d74fe4c78364a72f592f06fb4e68b730.jpg:
#   Character tags:
#   General tags: breasts, blue eyes, multiple girls, skirt, brown hair, black hair, gloves, holding, 2girls, brown eyes, medium breasts, jacket, weapon, red hair, dark skin, hair bun, holding weapon, dark-skinned female, gun, double bun, mask, copyright name, blue background, white jacket, white skirt, robot, goggles, holding gun, handgun, science fiction, mouth mask, hair behind ear, knee pads, open hand, animification, open hands, humanoid robot, drone
#
# /content/LoRA/train_data/d7668b80cdb88d0d664da048159fd027.png:
#   Character tags: kaguya luna
#   General tags: 1girl, solo, skirt, long sleeves, twintails, jewelry, jacket, white hair, pleated skirt, earrings, virtual youtuber, black skirt, from behind, nail polish, black jacket, v, red nails, facing away, photo background
#
# /content/LoRA/train_data/d7b4df62f9ad72a08b637134fe012f67.jpg:
#   Character tags: gotou hitori, ijichi nijika
#   General tags: long hair, looking at viewer, smile, short hair, open mouth, bangs, blue eyes, multiple girls, skirt, blonde hair, shirt, hair ornament, red eyes, long sleeves, bow, holding, hair between eyes, school uniform, blue hair, jacket, yellow eyes, white shirt, pink hair, red hair, pleated skirt, socks, red bow, side ponytail, 4girls, one side up, brown footwear, cover, black socks, loafers, instrument, track jacket, music, guitar, pink jacket, playing instrument, holding instrument, electric guitar, drum, bass guitar, cube hair ornament, drumsticks, drum set, gibson les paul
#
# /content/LoRA/train_data/db06bdc261fb375f85313e73cc040dda.png:
#   Character tags: hakos baelz
#   General tags: 1girl, solo, smile, shirt, black hair, hair ornament, red eyes, holding, animal ears, sitting, closed mouth, white shirt, braid, flower, white hair, short sleeves, red hair, multicolored hair, food, socks, hairclip, striped, virtual youtuber, bag, streaked hair, animal ear fluff, fruit, eating, knees up, plate, cake, strawberry, mouse ears, fork, food on face, holding plate, mouse, holding fork, cake slice, mouse girl, striped socks, strawberry shortcake
#  83% 20/24 [00:15<00:03,  1.25it/s]
# /content/LoRA/train_data/db90b0beaf0c454a2af2ba95da4829ec.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, bangs, simple background, long sleeves, white background, dress, hair between eyes, green eyes, full body, purple hair, frills, shoes, socks, floral print, frilled dress, purple dress, purple footwear
#
# /content/LoRA/train_data/df14ddd64446f9efb2189112a8775152.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, blue eyes, shirt, black hair, bow, closed mouth, jacket, white shirt, upper body, flower, collared shirt, bowtie, black bow, rose, blue background, formal, suit, blue flower, blue rose
#
# /content/LoRA/train_data/df7577668bdd388ba83baf2a6ef6b5b8.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, open mouth, bangs, skirt, simple background, shirt, red eyes, long sleeves, white background, cleavage, medium breasts, standing, jacket, full body, white shirt, red hair, pleated skirt, open clothes, shoes, socks, virtual youtuber, off shoulder, hair over one eye, arm up, open jacket, blue skirt, hand on hip, kneehighs, thigh strap, brown footwear, white socks, pointing, brown jacket, asymmetrical bangs
#
# /content/LoRA/train_data/e2661e026b49d4775e35a114bce30424.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, blush, smile, open mouth, bangs, brown hair, holding, closed eyes, :d, teeth, hands up, happy, portrait, close-up, confetti
#
# /content/LoRA/train_data/e2712eae7c35a04f39400388cca07a9a.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, skirt, brown hair, hair ornament, red eyes, cleavage, bare shoulders, jewelry, medium breasts, ponytail, frills, barefoot, teeth, signature, dark skin, grin, side ponytail, dated, dark-skinned female, anklet
#
# /content/LoRA/train_data/e35cbf3a7903ed5ae67007ed5883eb4d.jpg:
#   Character tags: hachimiya meguru, sakuragi mano, kazano hiori
#   General tags: long hair, looking at viewer, smile, open mouth, blue eyes, multiple girls, skirt, blonde hair, brown hair, black hair, hair ornament, gloves, ribbon, twintails, brown eyes, sitting, ponytail, boots, one eye closed, white gloves, 3girls, mole, grin, feathers, mole under mouth
#
# /content/LoRA/train_data/e42be3f555530d87bfa4e788bc608c88.jpg:
#   Character tags:
#   General tags: solo, 1boy, holding, yellow eyes, weapon, male focus, scarf, holding weapon, character name, gun, robot, holding gun, yellow background, science fiction, skull, red scarf, bandana, animification, submachine gun, humanoid robot, red bandana, holding skull
#
# /content/LoRA/train_data/e677a382e51443d187a369e444604ddb.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, smile, short hair, blue eyes, red eyes, gloves, 1boy, holding, blue hair, full body, weapon, male focus, red hair, multicolored hair, boots, sword, cape, holding weapon, armor, heterochromia, holding sword, red cape
#  88% 21/24 [00:16<00:02,  1.26it/s]
# /content/LoRA/train_data/e779d72e28bbb722bd045ff3dc0aeebf.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, bangs, blue eyes, skirt, shirt, holding, hair between eyes, closed mouth, school uniform, blue hair, white shirt, weapon, short sleeves, pleated skirt, serafuku, medium hair, sailor collar, arm up, blue skirt, neckerchief, knife, blue sailor collar, cherry blossoms, red neckerchief, stairs, midriff peek
#
# /content/LoRA/train_data/ecfa1c769facee1c3982bf6e45056934.jpg:
#   Character tags:
#   General tags: 1girl, long hair, looking at viewer, bangs, black hair, hair ornament, thighhighs, full body, boots, grey eyes, multiple views, multicolored clothes, asymmetrical legwear, reference sheet, asymmetrical footwear, variations, idol clothes
#
# /content/LoRA/train_data/edc368afe207cfcdecb3460556a7fbca.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, smile, short hair, bangs, brown hair, shirt, gloves, 1boy, holding, white shirt, upper body, flower, male focus, teeth, black gloves, belt, signature, dark skin, parted bangs, sash, fur trim, sparkle, rose, dark-skinned male, red flower, red background, circlet, red rose, holding flower
#
# /content/LoRA/train_data/ee8bb7e3e67f5aa3e19a0a542382a941.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, black hair, hair ornament, gloves, dress, bare shoulders, jewelry, upper body, braid, flower, parted lips, white gloves, hair flower, dark skin, twin braids, dark-skinned female, orange eyes, hands up, eyelashes, ring, plant, red flower, lace trim, lace, red background, one eye covered, multicolored eyes, yellow flower, colorful, orange flower, multiple rings, lace gloves
#
# /content/LoRA/train_data/eec436fe4ca410a76b306c120c7ff16a.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, skirt, long sleeves, hair between eyes, school uniform, standing, full body, grey hair, pleated skirt, shoes, serafuku, socks, dark skin, black skirt, sailor collar, black footwear, dark-skinned female, neckerchief, mask, bandages, black background, loafers, black serafuku, mask on head, loose socks
#
# /content/LoRA/train_data/ef90bcdfe0be9619ed0842f578ba8fed.png:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, bangs, blue eyes, hair ornament, holding, jewelry, blue hair, collarbone, upper body, earrings, frills, parted lips, nail polish, wrist cuffs, maid, maid headdress, blue background, ring, bandaid, smoke, cigarette, smoking, yellow nails, holding cigarette
#
# /content/LoRA/train_data/f00eed348049c5a2a76eea705fa49f95.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, smile, bangs, skirt, holding, very long hair, school uniform, monochrome, ponytail, weapon, short sleeves, greyscale, pleated skirt, serafuku, sword, sailor collar, holding weapon, grin, neckerchief, blood, holding sword, blood on face, evil smile
#
# /content/LoRA/train_data/f09c728694b9ef06a84bd3899616836a.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, bangs, simple background, white background, holding, jewelry, blue hair, upper body, pink hair, multicolored hair, earrings, parted lips, hood, hoodie, hood down, multicolored eyes, blue hoodie
#  92% 22/24 [00:17<00:01,  1.29it/s]
# /content/LoRA/train_data/f0ba3a702b0cf07b8f690ac9c28d1b22.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, bangs, simple background, shirt, twintails, closed mouth, blue hair, white shirt, collared shirt, grey background, portrait, bandaid, close-up, bandaid on face, bandaid on nose, bandaid on cheek
#
# /content/LoRA/train_data/f16ecdb16299fdb81698d606632cdaeb.png:
#   Character tags: wattson (apex legends), wraith (apex legends), crypto (apex legends)
#   General tags: looking at viewer, smile, blue eyes, multiple girls, blonde hair, brown hair, black hair, brown eyes, jewelry, yellow eyes, pink hair, grey hair, earrings, parted lips, multiple boys, dark skin, dark-skinned female, black headwear, 4girls, makeup, glowing, facial mark, piercing, eyepatch, dark-skinned male, 5girls, robot, goggles, glowing eyes, eyeshadow, goggles on head, one eye covered, bandana, animification, nose piercing, humanoid robot, lip piercing, red bandana
#
# /content/LoRA/train_data/f4503a618ece845654fa91d4ae7cfe6e.jpg:
#   Character tags:
#   General tags: 1girl, solo, holding, yellow eyes, weapon, sword, hood, holding weapon, from side, leotard, holding sword, robot, yellow background, hood up, colored sclera, science fiction, android, black sclera, blue leotard, cable, animification
#
# /content/LoRA/train_data/f7844043e2e3682dbb0523bbddf2fa3c.jpg:
#   Character tags: wraith (apex legends)
#   General tags: breasts, smile, short hair, blue eyes, multiple girls, black hair, gloves, 1boy, holding, 2girls, brown eyes, medium breasts, weapon, grey hair, shorts, black gloves, fingerless gloves, hair bun, scarf, holding weapon, vest, gun, black headwear, bodysuit, mask, floating hair, single hair bun, goggles, holding gun, red background, rifle, mouth mask, black bodysuit, hair behind ear, assault rifle, animification, green vest, sniper rifle, green shorts, orange bodysuit, broken glass, mechanical legs, cropped vest, jetpack, missile pod
#
# /content/LoRA/train_data/f7db6d3345cdcb7fdf059944965d0e99.jpg:
#   Character tags:
#   General tags: blue eyes, gloves, 1boy, hat, white background, male focus, boots, black gloves, virtual youtuber, white gloves, black footwear, orange hair, multiple views, red headwear, multicolored clothes, reference sheet, color guide
#
# /content/LoRA/train_data/f90b0da10afc1b99055ca4bdbe0226d4.png:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, bangs, blue eyes, hair ornament, gloves, dress, bare shoulders, blue hair, braid, flower, hair flower, dark skin, hair over one eye, dark-skinned female, orange eyes, torn clothes, ring, fishnets, yellow flower, colorful, abstract
#
# /content/LoRA/train_data/f97a087376b766ae0e4a692d855db230.jpg:
#   Character tags: marth (fire emblem)
#   General tags: long hair, breasts, looking at viewer, smile, short hair, bangs, blue eyes, multiple girls, blonde hair, red eyes, gloves, jewelry, medium breasts, very long hair, blue hair, weapon, braid, red hair, multicolored hair, multiple boys, sword, dark skin, 3girls, holding weapon, armor, two-tone hair, thigh strap, heterochromia, tiara, crossed bangs, dragon, crown braid, split-color hair
#
# /content/LoRA/train_data/fabefd87fc3cee5c6cfbbcb9badd7680.jpg:
#   Character tags: reisalin stout
#   General tags: 1girl, solo, breasts, looking at viewer, blush, smile, short hair, open mouth, bangs, simple background, brown hair, hair ornament, thighhighs, gloves, hat, white background, cleavage, brown eyes, jewelry, medium breasts, collarbone, thighs, one eye closed, shorts, teeth, hairclip, belt, necklace, star (symbol), white thighhighs, short shorts, beret, white headwear, thigh gap, ;d, single glove, red shorts, flask, star necklace
# 100% 24/24 [00:18<00:00,  1.32it/s]
#
# /content/LoRA/train_data/fb83816f32844eb5d689ac8800673b1c.jpg:
#   Character tags: wattson (apex legends)
#   General tags: 1girl, solo, breasts, looking at viewer, smile, bangs, blue eyes, blonde hair, gloves, holding, jacket, weapon, parted lips, one eye closed, shoes, hood, holding weapon, character name, gun, bodysuit, white footwear, holding gun, yellow background, hooded jacket, blue headwear, blue gloves, knee pads, animification, white bodysuit, blue bodysuit, orange jacket, lightning bolt symbol, energy gun, ribbed bodysuit, hooded bodysuit
#
# /content/LoRA/train_data/fc44d2725b55feca02fb57e055f664c2.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, bangs, large breasts, thighhighs, gloves, dress, cleavage, bare shoulders, pink hair, choker, elbow gloves, virtual youtuber, white gloves, signature, pink eyes, mole, mask, rose, pink background, fishnets, fishnet thighhighs
#
# /content/LoRA/train_data/fd4936dd9648378471a74554bb184373.jpg:
#   Character tags: hakos baelz, kaguya luna
#   General tags: long hair, breasts, looking at viewer, smile, open mouth, bangs, blue eyes, multiple girls, black hair, hair ornament, bow, holding, animal ears, twintails, closed mouth, blue hair, pink hair, white hair, :d, red hair, multicolored hair, one eye closed, teeth, sleeveless, hairclip, virtual youtuber, 3girls, blunt bangs, grin, sash, v, x hair ornament, sharp teeth, spikes, mouse ears, can, holding can, aqua bow, mouse girl, d-pad, d-pad hair ornament
# done!

# %%
# @title ### **3.2.3. Custom Caption/Tag**
import os

# %store -r

os.chdir(root_dir)

# @markdown Add or remove custom tags here.
extension   = ".txt"  # @param [".txt", ".caption"]
custom_tag  = ""  # @param {type:"string"}
# @markdown Use `sub_folder` option to specify a subfolder for multi-concept training.
# @markdown > Specify `--all` to process all subfolders/`recursive`
sub_folder  = "" #@param {type: "string"}
# @markdown Enable this to append custom tags at the end of lines.
append      = False  # @param {type:"boolean"}
# @markdown Enable this if you want to remove captions/tags instead.
remove_tag  = False  # @param {type:"boolean"}
recursive   = False

if sub_folder == "":
    image_dir = train_data_dir
elif sub_folder == "--all":
    image_dir = train_data_dir
    recursive = True
elif sub_folder.startswith("/content"):
    image_dir = sub_folder
else:
    image_dir = os.path.join(train_data_dir, sub_folder)
    os.makedirs(image_dir, exist_ok=True)

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

def process_tags(filename, custom_tag, append, remove_tag):
    contents = read_file(filename)
    tags = [tag.strip() for tag in contents.split(',')]
    custom_tags = [tag.strip() for tag in custom_tag.split(',')]

    for custom_tag in custom_tags:
        custom_tag = custom_tag.replace("_", " ")
        if remove_tag:
            while custom_tag in tags:
                tags.remove(custom_tag)
        else:
            if custom_tag not in tags:
                if append:
                    tags.append(custom_tag)
                else:
                    tags.insert(0, custom_tag)

    contents = ', '.join(tags)
    write_file(filename, contents)

def process_directory(image_dir, tag, append, remove_tag, recursive):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)

        if os.path.isdir(file_path) and recursive:
            process_directory(file_path, tag, append, remove_tag, recursive)
        elif filename.endswith(extension):
            process_tags(file_path, tag, append, remove_tag)

tag = custom_tag

if not any(
    [filename.endswith(extension) for filename in os.listdir(image_dir)]
):
    for filename in os.listdir(image_dir):
        if filename.endswith((".png", ".jpg", ".jpeg", ".webp", ".bmp")):
            open(
                os.path.join(image_dir, filename.split(".")[0] + extension),
                "w",
            ).close()

if custom_tag:
    process_directory(image_dir, tag, append, remove_tag, recursive)

# %%
# @title ## **3.4. Metadata Generator**
# %store -r

metadata_json     = os.path.join(training_dir, "meta_clean.json")
# @markdown Use `clean_caption` option to clean such as duplicate tags, `women` to `girl`, etc
clean_caption     = True #@param {type:"boolean"}
#@markdown Use the `recursive` option to process subfolders as well
recursive         = False #@param {type:"boolean"}

metadata_config = {
    "_train_data_dir": train_data_dir,
    "_out_json": metadata_json,
    "recursive": recursive,
    "full_path": recursive,
    "clean_caption": clean_caption
}


def generate_args(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "
    return args.strip()

merge_metadata_args = generate_args(metadata_config)

merge_metadata_command = f"python merge_all_to_metadata.py {merge_metadata_args}"

os.chdir(finetune_dir)
# !{merge_metadata_command}
# Out:
# Found 187 images.
# Creating a new metadata file
# Merging tags and captions into metadata json.
# 100% 187/187 [00:00<00:00, 16039.24it/s]
# All 187 images have captions
# All 187 images have tags
# Cleaning captions and tags.
# 100% 187/187 [00:00<00:00, 3203.52it/s]
# Writing metadata: /content/LoRA/meta_clean.json
# Done!

# %% [markdown]
# # **IV. Training**

# %%
import ast

# @title ## **4.1. LoRa: Low-Rank Adaptation Config**
# @markdown Kohya's `LoRA` renamed to `LoRA-LierLa` and Kohya's `LoCon` renamed to `LoRA-C3Lier`, read [official announcement](https://github.com/kohya-ss/sd-scripts/blob/849bc24d205a35fbe1b2a4063edd7172533c1c01/README.md#naming-of-lora).
network_category = "LoRA_LierLa"  # @param ["LoRA_LierLa", "LoRA_C3Lier", "DyLoRA_LierLa", "DyLoRA_C3Lier", "LoCon", "LoHa", "IA3", "LoKR", "DyLoRA_Lycoris"]

# @markdown | network_category | network_dim | network_alpha | conv_dim | conv_alpha | unit |
# @markdown | :---: | :---: | :---: | :---: | :---: | :---: |
# @markdown | LoRA-LierLa | 32 | 1 | - | - | - |
# @markdown | LoCon/LoRA-C3Lier | 16 | 8 | 8 | 1 | - |
# @markdown | LoHa | 8 | 4 | 4 | 1 | - |
# @markdown | Other Category | ? | ? | ? | ? | - |

# @markdown Specify `network_args` to add `optional` training args, like for specifying each 25 block weight, read [this](https://github.com/kohya-ss/sd-scripts/blob/main/train_network_README-ja.md#%E9%9A%8E%E5%B1%A4%E5%88%A5%E5%AD%A6%E7%BF%92%E7%8E%87)
network_args    = ""  # @param {'type':'string'}

# @markdown ### **Linear Layer Config**
# @markdown Used by all `network_category`. When in doubt, set `network_dim = network_alpha`
network_dim     = 128  # @param {'type':'number'}
network_alpha   = 128  # @param {'type':'number'}

# @markdown ### **Convolutional Layer Config**
# @markdown Only required if `network_category` is not `LoRA_LierLa`, as it involves training convolutional layers in addition to linear layers.
conv_dim        = 32  # @param {'type':'number'}
conv_alpha      = 16  # @param {'type':'number'}

# @markdown ### **DyLoRA Config**
# @markdown Only required if `network_category` is `DyLoRA_LierLa` and `DyLoRA_C3Lier`
unit = 4  # @param {'type':'number'}

if isinstance(network_args, str):
    network_args = network_args.strip()
    if network_args.startswith('[') and network_args.endswith(']'):
        try:
            network_args = ast.literal_eval(network_args)
        except (SyntaxError, ValueError) as e:
            print(f"Error parsing network_args: {e}\n")
            network_args = []
    elif len(network_args) > 0:
        print(f"WARNING! '{network_args}' is not a valid list! Put args like this: [\"args=1\", \"args=2\"]\n")
        network_args = []
    else:
        network_args = []
else:
    network_args = []

network_config = {
    "LoRA_LierLa": {
        "module": "networks.lora",
        "args"  : []
    },
    "LoRA_C3Lier": {
        "module": "networks.lora",
        "args"  : [
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "DyLoRA_LierLa": {
        "module": "networks.dylora",
        "args"  : [
            f"unit={unit}"
        ]
    },
    "DyLoRA_C3Lier": {
        "module": "networks.dylora",
        "args"  : [
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}",
            f"unit={unit}"
        ]
    },
    "LoCon": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=locon",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "LoHa": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=loha",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "IA3": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=ia3",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "LoKR": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=lokr",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "DyLoRA_Lycoris": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=dylora",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    }
}

network_module = network_config[network_category]["module"]
network_args.extend(network_config[network_category]["args"])

print(f"Selected configuration:")
print(f"\t- Network category: {network_category}")
print(f"\t- Network module: {network_module}")
print(f"\t- Linear dim: {network_dim}")
print(f"\t- Linear alpha: {network_alpha}")
print(f"\t- Network arguments: {network_args}")
# Out:
# Selected configuration:
# 	- Network category: LoRA_LierLa
# 	- Network module: networks.lora
# 	- Linear dim: 128
# 	- Linear alpha: 128
# 	- Network arguments: []

# %%
# @title ## **4.2. Optimizer Config**
# @markdown Use `Adafactor` optimizer. `RMSprop 8bit` or `Adagrad 8bit` may work. `AdamW 8bit` doesn't seem to work.
optimizer_type = "AdaFactor"  # @param ["AdamW", "AdamW8bit", "Lion8bit", "Lion", "SGDNesterov", "SGDNesterov8bit", "DAdaptation(DAdaptAdamPreprint)", "DAdaptAdaGrad", "DAdaptAdam", "DAdaptAdan", "DAdaptAdanIP", "DAdaptLion", "DAdaptSGD", "AdaFactor"]

# @markdown Specify `optimizer_args` to add `additional` args for optimizer, e.g: `["weight_decay=0.6"]`
optimizer_args = "[ \"scale_parameter=False\", \"relative_step=False\", \"warmup_init=False\" ]"  # @param {'type':'string'}

# @markdown ### **Learning Rate Config**
# @markdown Different `optimizer_type` and `network_category` for some condition requires different learning rate. It's recommended to set `text_encoder_lr = 1/2 * unet_lr`
learning_rate = 4e-7  # @param {'type':'number'}

# @markdown ### **LR Scheduler Config**
# @markdown `lr_scheduler` provides several methods to adjust the learning rate based on the number of epochs.
lr_scheduler = "constant_with_warmup"  # @param ["linear", "cosine", "cosine_with_restarts", "polynomial", "constant", "constant_with_warmup", "adafactor"] {allow-input: false}
lr_warmup_steps = 100  # @param {'type':'number'}

# @markdown Specify `lr_scheduler_num` with `num_cycles` value for `cosine_with_restarts` or `power` value for `polynomial`
lr_scheduler_num = 0  # @param {'type':'number'}

if isinstance(optimizer_args, str):
    optimizer_args = optimizer_args.strip()
    if optimizer_args.startswith('[') and optimizer_args.endswith(']'):
        try:
            optimizer_args = ast.literal_eval(optimizer_args)
        except (SyntaxError, ValueError) as e:
            print(f"Error parsing optimizer_args: {e}\n")
            optimizer_args = []
    elif len(optimizer_args) > 0:
        print(f"WARNING! '{optimizer_args}' is not a valid list! Put args like this: [\"args=1\", \"args=2\"]\n")
        optimizer_args = []
    else:
        optimizer_args = []
else:
    optimizer_args = []

print(f"Selected configuration:")
print(f"\t- Using {optimizer_type} as Optimizer")
print(f"\t- Optimizer arguments: {optimizer_args}")
print(f"\t- Learning rate: {learning_rate}")
print(f"\t- Learning rate warmup steps: {lr_warmup_steps}")
print(f"\t- Learning rate Scheduler: {lr_scheduler}")
if lr_scheduler == "cosine_with_restarts":
    print(f"\t- lr_scheduler_num_cycles: {lr_scheduler_num}")
if lr_scheduler == "polynomial":
    print(f"\t- lr_scheduler_power: {lr_scheduler_num}")
# Out:
# Selected configuration:
# 	- Using AdaFactor as Optimizer
# 	- Optimizer arguments: ['scale_parameter=False', 'relative_step=False', 'warmup_init=False']
# 	- Learning rate: 4e-07
# 	- Learning rate warmup steps: 100
# 	- Learning rate Scheduler: constant_with_warmup

# %%
# @title ## **4.3. Training Config**
import toml
import os
from subprocess import getoutput

# %store -r

# @markdown ### **Project Config**
project_name        = ""  # @param {type:"string"}
# @markdown Get your `wandb_api_key` [here](https://wandb.ai/settings) to logs with wandb.
wandb_api_key       = "" # @param {type:"string"}
in_json             = "/content/LoRA/meta_clean.json"  # @param {type:"string"}
# @markdown ### **Dataset Config**
num_repeats         = 1  # @param {type:"number"}
# @markdown Please refer to `3.2.3. Custom Caption/Tag (Optional)` if you want to append `activation_word` to captions/tags
resolution          = 1024  # @param {type:"slider", min:512, max:1024, step:128}
keep_tokens         = 0  # @param {type:"number"}
# @markdown ### **General Config**
num_epochs          = 10  # @param {type:"number"}
train_batch_size    = 4  # @param {type:"number"}
mixed_precision     = "fp16"  # @param ["no","fp16","bf16"] {allow-input: false}
seed                = -1  # @param {type:"number"}
# @markdown ### **Save Output Config**
save_precision      = "fp16"  # @param ["float", "fp16", "bf16"] {allow-input: false}
save_every_n_epochs = 1  # @param {type:"number"}
# @markdown ### **Sample Prompt Config**
positive_prompt     = ""
negative_prompt     = ""
caption_extension   = ".txt"  # @param ["none", ".txt", ".caption"]
quality_prompt      = "None"  # @param ["None", "Waifu Diffusion 1.5 Quality Prompt", "NovelAI Quality Prompt", "AbyssOrangeMix Quality Prompt"] {allow-input: false}
if quality_prompt  == "Waifu Diffusion 1.5 Quality Prompt":
    positive_prompt = "(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2), "
    negative_prompt = "lowres, ((bad anatomy)), ((bad hands)), missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor), "
if quality_prompt  == "NovelAI Quality Prompt":
    positive_prompt = "masterpiece, best quality, "
    negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, "
if quality_prompt  == "AbyssOrangeMix Quality Prompt":
    positive_prompt = "masterpiece, best quality, "
    negative_prompt = "(worst quality, low quality:1.4), "
custom_prompt       = "" # @param {type:"string"}
enable_sample     = True  # @param {type:"boolean"}
num_prompt          = 2  # @param {type:"number"}
# @markdown ### **Advanced Training Config**
# @markdown Gamma for reducing the weight of high-loss timesteps. Lower numbers have a stronger effect. The paper recommends `5`. Read the paper [here](https://arxiv.org/abs/2303.09556).
min_snr_gamma       = -1 #@param {type:"number"}
# @markdown Control and easily generating darker or light images by offset the noise when fine-tuning the model. Recommended value: `0.1`. Read [Diffusion With Offset Noise](https://www.crosslabs.org//blog/diffusion-with-offset-noise)
noise_offset        = 0.0357  # @param {type:"number"}
cache_text_encoder_outputs = True
logging_dir         = "/content/LoRA/logs"

os.chdir(repo_dir)

prompt_config = {
    "prompt": {
        "negative_prompt" : negative_prompt,
        "width"           : 512,
        "height"          : 768,
        "scale"           : 7,
        "sample_steps"    : 28,
        "subset"          : [],
    }
}

train_config = {
    "sdxl_arguments": {
        "cache_text_encoder_outputs" : cache_text_encoder_outputs,
        "no_half_vae"                : True,
        "cache_latents"              : True,
        "cache_latents_to_disk"      : True,
        "vae_batch_size"             : 4,
        "shuffle_caption"            : True if not cache_text_encoder_outputs else False,
    },
    "model_arguments": {
        "pretrained_model_name_or_path" : model_path,
        "vae"                           : vae_path,
    },
    "additional_network_arguments": {
        "no_metadata"                     : False,
        "network_module"                  : network_module,
        "network_dim"                     : network_dim,
        "network_alpha"                   : network_alpha,
        "network_args"                    : network_args,
        "network_train_unet_only"         : True,
        "training_comment"                : None,
    },
    "optimizer_arguments": {
        "min_snr_gamma"           : min_snr_gamma if not min_snr_gamma == -1 else None,
        "optimizer_type"          : optimizer_type,
        "learning_rate"           : learning_rate,
        "max_grad_norm"           : 1.0,
        "optimizer_args"          : optimizer_args,
        "lr_scheduler"            : lr_scheduler,
        "lr_warmup_steps"         : lr_warmup_steps,
        "lr_scheduler_num_cycles" : lr_scheduler_num if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power"      : lr_scheduler_num if lr_scheduler == "polynomial" else None,
        "lr_scheduler_type"       : None,
        "lr_scheduler_args"       : None,
    },
    "dataset_arguments": {
        "debug_dataset"                 : False,
        "in_json"                       : in_json,
        "train_data_dir"                : train_data_dir,
        "dataset_repeats"               : num_repeats,
        "keep_tokens"                   : keep_tokens,
        "resolution"                    : str(resolution) + ',' + str(resolution),
        "color_aug"                     : False,
        "face_crop_aug_range"           : None,
        "token_warmup_min"              : 1,
        "token_warmup_step"             : 0,
    },
    "training_arguments": {
        "output_dir"                    : output_dir,
        "output_name"                   : project_name if project_name else "last",
        "save_precision"                : save_precision,
        "save_every_n_epochs"           : save_every_n_epochs,
        "save_n_epoch_ratio"            : None,
        "save_last_n_epochs"            : None,
        "save_state"                    : None,
        "save_last_n_epochs_state"      : None,
        "resume"                        : None,
        "train_batch_size"              : train_batch_size,
        "max_token_length"              : 225,
        "mem_eff_attn"                  : False,
        "xformers"                      : True,
        "max_train_epochs"              : num_epochs,
        "max_data_loader_n_workers"     : 8,
        "persistent_data_loader_workers": True,
        "seed"                          : seed if seed > 0 else None,
        "gradient_checkpointing"        : None,
        "gradient_accumulation_steps"   : 1,
        "mixed_precision"               : mixed_precision,
        "noise_offset"                  : noise_offset if noise_offset > 0 else None,
        "lowram"                        : True if 'T4' in getoutput('nvidia-smi') else False,
    },
    "logging_arguments": {
        "log_with"          : "wandb" if wandb_api_key else "tensorboard",
        "log_tracker_name"  : project_name if wandb_api_key and not project_name == "last" else None,
        "logging_dir"       : logging_dir,
        "log_prefix"        : project_name if not wandb_api_key else None,
    },
    "sample_prompt_arguments": {
        "sample_every_n_steps"    : None,
        "sample_every_n_epochs"   : save_every_n_epochs if enable_sample else None,
        "sample_sampler"          : "k_dpm_2_a",
    },
    "saving_arguments": {
        "save_model_as": "safetensors"
    },
}

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

def prompt_convert(enable_sample, num_prompt, train_data_dir, prompt_config, custom_prompt):
    if enable_sample:
        search_pattern = os.path.join(train_data_dir, '**/*' + caption_extension)
        caption_files = glob.glob(search_pattern, recursive=True)

        if not caption_files:
            if not custom_prompt:
                custom_prompt = "masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt"
            new_prompt_config = prompt_config.copy()
            new_prompt_config['prompt']['subset'] = [
                {"prompt": positive_prompt + custom_prompt if positive_prompt else custom_prompt}
            ]
        else:
            selected_files = random.sample(caption_files, min(num_prompt, len(caption_files)))

            prompts = []
            for file in selected_files:
                with open(file, 'r') as f:
                    prompts.append(f.read().strip())

            new_prompt_config = prompt_config.copy()
            new_prompt_config['prompt']['subset'] = []

            for prompt in prompts:
                new_prompt = {
                    "prompt": positive_prompt + prompt if positive_prompt else prompt,
                }
                new_prompt_config['prompt']['subset'].append(new_prompt)

        return new_prompt_config
    else:
        return prompt_config

def eliminate_none_variable(config):
    for key in config:
        if isinstance(config[key], dict):
            for sub_key in config[key]:
                if config[key][sub_key] == "":
                    config[key][sub_key] = None
        elif config[key] == "":
            config[key] = None

    return config

prompt_config = prompt_convert(enable_sample, num_prompt, train_data_dir, prompt_config, custom_prompt)

config_path         = os.path.join(config_dir, "config_file.toml")
prompt_path         = os.path.join(config_dir, "sample_prompt.toml")

config_str          = toml.dumps(eliminate_none_variable(train_config))
prompt_str          = toml.dumps(eliminate_none_variable(prompt_config))

write_file(config_path, config_str)
write_file(prompt_path, prompt_str)

print(prompt_str)
print(config_str)

# %%
#@title ## **4.4. Start Training**
import os
import toml

#@markdown Check your config here if you want to edit something:
#@markdown - `sample_prompt` : /content/LoRA/config/sample_prompt.toml
#@markdown - `config_file` : /content/LoRA/config/config_file.toml


#@markdown You can import config from another session if you want.

sample_prompt   = "/content/LoRA/config/sample_prompt.toml" #@param {type:'string'}
config_file     = "/content/LoRA/config/config_file.toml" #@param {type:'string'}

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents

def train(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

accelerate_conf = {
    "config_file" : accelerate_config,
    "num_cpu_threads_per_process" : 1,
}

train_conf = {
    "sample_prompts"  : sample_prompt if os.path.exists(sample_prompt) else None,
    "config_file"     : config_file,
    "wandb_api_key"   : wandb_api_key if wandb_api_key else None,
}

accelerate_args = train(accelerate_conf)
train_args = train(train_conf)

final_args = f"accelerate launch {accelerate_args} sdxl_train_network.py {train_args}"

os.chdir(repo_dir)
# !{final_args}

# %% [markdown]
# # **VI. Deployment**

# %%
# @title ## **6.1. Huggingface Hub config**
from huggingface_hub import login
from huggingface_hub import HfApi
from huggingface_hub.utils import validate_repo_id, HfHubHTTPError

# @markdown Login to Huggingface Hub
# @markdown > Get **your** huggingface `WRITE` token [here](https://huggingface.co/settings/tokens)
write_token = "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"  # @param {type:"string"}
# @markdown Fill this if you want to upload to your organization, or just leave it empty.
orgs_name = ""  # @param{type:"string"}
# @markdown If your model/dataset repo does not exist, it will automatically create it.
model_name = "personal-backup"  # @param{type:"string"}
dataset_name = ""  # @param{type:"string"}
make_private = False  # @param{type:"boolean"}

def authenticate(write_token):
    login(write_token, add_to_git_credential=True)
    api = HfApi()
    return api.whoami(write_token), api

def create_repo(api, user, orgs_name, repo_name, repo_type, make_private=False):
    global model_repo
    global datasets_repo

    if orgs_name == "":
        repo_id = user["name"] + "/" + repo_name.strip()
    else:
        repo_id = orgs_name + "/" + repo_name.strip()

    try:
        validate_repo_id(repo_id)
        api.create_repo(repo_id=repo_id, repo_type=repo_type, private=make_private)
        print(f"{repo_type.capitalize()} repo '{repo_id}' didn't exist, creating repo")
    except HfHubHTTPError as e:
        print(f"{repo_type.capitalize()} repo '{repo_id}' exists, skipping create repo")

    if repo_type == "model":
        model_repo = repo_id
        print(f"{repo_type.capitalize()} repo '{repo_id}' link: https://huggingface.co/{repo_id}\n")
    else:
        datasets_repo = repo_id
        print(f"{repo_type.capitalize()} repo '{repo_id}' link: https://huggingface.co/datasets/{repo_id}\n")

user, api = authenticate(write_token)

if model_name:
    create_repo(api, user, orgs_name, model_name, "model", make_private)
if dataset_name:
    create_repo(api, user, orgs_name, dataset_name, "dataset", make_private)

# %%
# @title ## **6.2. Upload LoRA to Huggingface**
from huggingface_hub import HfApi
from pathlib import Path

# %store -r

api = HfApi()

# @markdown This will be uploaded to model repo
model_path = "/content/drive/MyDrive/sdxl"  # @param {type :"string"}
path_in_repo = "sdxl"  # @param {type :"string"}

# @markdown Now you can save your config file for future use
config_path = "/content/LoRA/config"  # @param {type :"string"}

# @markdown Other Information
commit_message = ""  # @param {type :"string"}

if not commit_message:
    commit_message = f"feat: upload {project_name} lora model"

def upload_to_hf(model_path, is_folder, is_config):
    path_obj = Path(model_path)
    trained_model = path_obj.parts[-1]

    if path_in_repo:
        trained_model = path_in_repo

    if is_config:
        trained_model = f"{project_name}_config"

    print(f"Uploading {trained_model} to https://huggingface.co/{model_repo}")
    print("Please wait...")

    if is_folder:
        api.upload_folder(
            folder_path=model_path,
            path_in_repo=trained_model,
            repo_id=model_repo,
            commit_message=commit_message,
            ignore_patterns=".ipynb_checkpoints",
        )
        print(f"Upload success, located at https://huggingface.co/{model_repo}/tree/main\n")
    else:
        api.upload_file(
            path_or_fileobj=model_path,
            path_in_repo=trained_model,
            repo_id=model_repo,
            commit_message=commit_message,
        )
        print(f"Upload success, located at https://huggingface.co/{model_repo}/blob/main/{trained_model}\n")

def upload():
    is_model_file = model_path.endswith((".ckpt", ".safetensors", ".pt"))
    upload_to_hf(model_path, not is_model_file, False)

    if config_path:
        upload_to_hf(config_path, True, True)

upload()

# %%
# @title ## **6.3. Upload Dataset to Huggingface**
from huggingface_hub import HfApi
from pathlib import Path
import shutil
import zipfile
import os

api = HfApi()

# @markdown This will be compressed to zip and  uploaded to datasets repo, leave it empty if not necessary
train_data_path = "/content/LoRA/train_data"  # @param {type :"string"}

# @markdown `Nerd stuff, only if you want to save training logs`
logs_path = "/content/LoRA/logs"  # @param {type :"string"}

tmp_dataset = f"/content/LoRA/{project_name}_dataset" if project_name else "/content/LoRA/tmp_dataset"
tmp_train_data = f"{tmp_dataset}/train_data"
dataset_zip = f"{tmp_dataset}.zip"

# @markdown Other Information
commit_message = ""  # @param {type :"string"}

if not commit_message:
    commit_message = f"feat: upload {project_name} dataset and logs"

os.makedirs(tmp_dataset, exist_ok=True)
os.makedirs(tmp_train_data, exist_ok=True)

def upload_dataset(dataset_path, is_zip):
    path_obj = Path(dataset_path)
    dataset_name = path_obj.parts[-1]

    print(f"Uploading {dataset_name} to https://huggingface.co/datasets/{datasets_repo}")
    print("Please wait...")

    if is_zip:
        api.upload_file(
            path_or_fileobj=dataset_path,
            path_in_repo=dataset_name,
            repo_id=datasets_repo,
            repo_type="dataset",
            commit_message=commit_message,
        )
        print(f"Upload success, located at https://huggingface.co/datasets/{datasets_repo}/blob/main/{dataset_name}\n")
    else:
        api.upload_folder(
            folder_path=dataset_path,
            path_in_repo=dataset_name,
            repo_id=datasets_repo,
            repo_type="dataset",
            commit_message=commit_message,
            ignore_patterns=".ipynb_checkpoints",
        )
        print(f"Upload success, located at https://huggingface.co/datasets/{datasets_repo}/tree/main/{dataset_name}\n")

def zip_file(folder_path):
    zip_path = f"{folder_path}.zip"
    with zipfile.ZipFile(zip_path, "w") as zip_file:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                zip_file.write(os.path.join(root, file))

def move(src_path, dst_path, move_metadata):
    metadata_files = [
        "meta_cap.json",
        "meta_cap_dd.json",
        "meta_lat.json",
        "meta_clean.json",
        "meta_final.json",
    ]

    if os.path.exists(src_path):
        shutil.move(src_path, dst_path)

    if move_metadata:
        parent_meta_path = os.path.dirname(src_path)

        for filename in os.listdir(parent_meta_path):
            file_path = os.path.join(parent_meta_path, filename)
            if filename in metadata_files:
                shutil.move(file_path, dst_path)

def upload():
    if train_data_path:
        move(train_data_path, tmp_train_data, False)
        zip_file(tmp_dataset)
        upload_dataset(dataset_zip, True)
        os.remove(dataset_zip)
    if logs_path:
        upload_dataset(logs_path, False)

upload()
