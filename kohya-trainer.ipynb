# %% [markdown]
# <a href="https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/dev/kohya-trainer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kohya Trainer V11 - VRAM 12GB

# %% [markdown]
# This notebook has been adapted for use in Google Colab based on [kohya-ss/sd-scripts](https://github.com/kohya-ss/sd-scripts). </br>
# This notebook was adapted by [Linaqruf](https://github.com/Linaqruf)</br>
# You can find the latest update to the notebook [here](https://github.com/Linaqruf/kohya-trainer/blob/main/kohya-trainer.ipynb).

# %% [markdown]
# # I. Install Kohya Trainer

# %%
#@title ## 1.1. Clone Kohya Trainer
#@markdown Clone Kohya Trainer from GitHub and check for updates. Use textbox below if you want to checkout other branch or old commit. Leave it empty to stay the HEAD on main.

import os
# %store -r

# Check GPU Availability
# !nvidia-smi

# Define path
root_dir = "/content"
# %store root_dir
repo_dir = str(root_dir)+"/kohya-trainer"
# %store repo_dir
tools_dir = str(root_dir)+"/kohya-trainer/tools"
# %store tools_dir 
finetune_dir = str(root_dir)+"/kohya-trainer/finetune"
# %store finetune_dir

# Define identifier
branch = "dev" #@param {type: "string"}
repo_url = "https://github.com/Linaqruf/kohya-trainer"

# %cd {root_dir}

def clone_repo():
  # Check if the directory already exists
  if os.path.isdir(repo_dir):
    # %cd {repo_dir}
    print("This folder already exists, will do a !git pull instead\n")
    if branch != "":
      # !git pull origin {branch} 
    else:
      # !git pull
  else:
    # !git clone {repo_url}

def checkout_repo(branch_or_commit):
  # %cd {repo_dir}
  # !git checkout {branch_or_commit}

# Clone or update the Kohya Trainer repository
clone_repo()

# Checkout to the specified branch or commit
if branch != "":
  checkout_repo(branch)
# Out:
# Wed Jan 18 12:12:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Stored 'root_dir' (str)
# Stored 'repo_dir' (str)
# Stored 'tools_dir' (str)
# Stored 'finetune_dir' (str)
# Cloning into 'kohya-trainer'...
# remote: Enumerating objects: 847, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 847 (delta 195), reused 116 (delta 110), pack-reused 586
# Receiving objects: 100% (847/847), 2.63 MiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (506/506), done.
# /content/kohya-trainer
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %%
#@title ## 1.2. Installing Dependencies

import os
# %store -r

#@markdown This will install required Python packages

# Define variable
accelerate_config = str(repo_dir)+"/accelerate_config/config.yaml"
# %store accelerate_config
Install_xformers = True #@param {'type':'boolean'}

# %cd {repo_dir}

def install_dependencies():
  # !pip -qqqq install --upgrade -r requirements.txt
  # !pip -qqqq install --upgrade gallery-dl
  # !pip -qqqq install --upgrade --no-cache-dir gdown
  # !apt -qqqq install liblz4-tool aria2

  if Install_xformers:
    # !pip -qqqq install -U -I --no-deps https://github.com/camenduru/stable-diffusion-webui-colab/releases/download/0.0.15/xformers-0.0.15.dev0+189828c.d20221207-cp38-cp38-linux_x86_64.whl
  else:
    pass

  from accelerate.utils import write_basic_config
  if not os.path.exists(accelerate_config):
    write_basic_config(save_location = accelerate_config) # Write a config file
  else:
    pass

# Install dependencies
install_dependencies()

#@markdown After Accelerate updated its version to 0.15.0, you can't manually input the config using
#@markdown `!accelerate config` in Google Colab. Instead, a `config.yaml` file will be generated by
#@markdown the `write_basic_config()` function. You can find the file [here](/content/kohya-trainer/accelerate_config/config.yaml) after installation.
#@markdown if you want to modify it.
# Out:
# Stored 'accelerate_config' (str)
# /content/kohya-trainer
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.5/191.5 KB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 KB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.1/503.1 KB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 110.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 79.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 KB 28.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 100.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 KB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 106.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.5 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done
#   Building wheel for library (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.7/573.7 KB 10.8 MB/s eta 0:00:00
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 129501 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) ...
# Selecting previously unselected package lz4.
# Preparing to unpack .../lz4_1.9.2-2ubuntu0.20.04.1_amd64.deb ...
# Unpacking lz4 (1.9.2-2ubuntu0.20.04.1) ...
# Selecting previously unselected package liblz4-tool.
# Preparing to unpack .../liblz4-tool_1.9.2-2ubuntu0.20.04.1_all.deb ...
# Unpacking liblz4-tool (1.9.2-2ubuntu0.20.04.1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# Setting up lz4 (1.9.2-2ubuntu0.20.04.1) ...
# Setting up liblz4-tool (1.9.2-2ubuntu0.20.04.1) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.9/102.9 MB 10.9 MB/s eta 0:00:00

# %% [markdown]
# ## 1.3. Sign-in to Cloud Service

# %%
#@title ### 1.3.1. Login to Huggingface hub
from huggingface_hub import login
# %store -r

#@markdown 1. Of course, you need a Huggingface account first.
#@markdown 2. To create a huggingface token, go to [this link](https://huggingface.co/settings/tokens), then `create new token` or copy available token with the `Write` role.

write_token = "your-write-token-here" #@param {type:"string"}
login(write_token, add_to_git_credential=True)

# %store write_token

# %%
#@title ### 1.3.2. Mount Drive
from google.colab import drive

mount_drive = True #@param {type: "boolean"}

if mount_drive:
  drive.mount('/content/drive')

# %% [markdown]
# # II. Pretrained Model Selection

# %%
#@title ## 2.1. Download Available Model 
import os
# %store -r

# %cd {root_dir}

installModels = []
installv2Models = []

#@markdown ### Available Model
#@markdown Select one of available model to download:

#@markdown ### SD1.x model
modelUrl = ["", \
            "https://huggingface.co/Linaqruf/personal_backup/resolve/main/animeckpt/model-pruned.ckpt", \
            "https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/Anything-v3.0-pruned.ckpt", \
            "https://huggingface.co/Linaqruf/anything-v3-better-vae/resolve/main/any-v3-fp32-better-vae.ckpt", \
            "https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt", \
            "https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.ckpt", \
            "https://huggingface.co/Rasgeath/self_made_sauce/resolve/main/Kani-anime-pruned.ckpt", \
            "https://huggingface.co/hesw23168/SD-Elysium-Model/resolve/main/Elysium_Anime_V2.ckpt", \
            "https://huggingface.co/prompthero/openjourney-v2/resolve/main/openjourney-v2.ckpt", \
            "https://huggingface.co/dreamlike-art/dreamlike-diffusion-1.0/resolve/main/dreamlike-diffusion-1.0.ckpt", \
            "https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt"]
modelList = ["", \
             "Animefull-final-pruned", \
             "Anything-v3-pruned", \
             "Anything-v3-better-vae", \
             "Anything-v4-pruned", \
             "Anything-v4-5-pruned", \
             "Kani-anime-pruned", \
             "Elysium-anime-V2", \
             "OpenJourney-V2", \
             "Dreamlike-diffusion-V1-0", \
             "Stable-Diffusion-v1-5"]
modelName = "Anything-v3-better-vae" #@param ["", "Animefull-final-pruned", "Anything-v3-pruned", "Anything-v3-better-vae", "Anything-v4-pruned", "Anything-v4-5-pruned", "Kani-anime-pruned", "Elysium-anime-V2", "OpenJourney-V2", "Dreamlike-diffusion-V1-0", "Stable-Diffusion-v1-5"]

#@markdown ### SD2.x model
v2ModelUrl = ["", \
              "https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.ckpt", \
              "https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt", \
              "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e1.ckpt", \
              "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e2.ckpt"]
v2ModelList = ["", \
              "stable-diffusion-2-1-base", \
              "stable-diffusion-2-1-768v", \
              "waifu-diffusion-1-4-anime-e1", \
              "waifu-diffusion-1-4-anime-e2"]
v2ModelName = "" #@param ["", "stable-diffusion-2-1-base", "stable-diffusion-2-1-768v", "waifu-diffusion-1-4-anime-e1", "waifu-diffusion-1-4-anime-e2"]

# Check if user has selected a model
if modelName != "":
  # Map selected model to URL
  installModels.append((modelName, modelUrl[modelList.index(modelName)]))

# Check if user has selected a model
if v2ModelName != "":
  # Map selected model to URL
  installv2Models.append((v2ModelName, v2ModelUrl[v2ModelList.index(v2ModelName)]))

def install(checkpoint_name, url):
  hf_token = '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' 
  user_header = f"\"Authorization: Bearer {hf_token}\""
  # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {root_dir}/pre_trained_model -o {checkpoint_name}.ckpt "{url}"

def install_checkpoint():
  # Iterate through list of models to install
  for model in installModels:
    # Call install function for each model
    install(model[0], model[1])

  # Iterate through list of models to install
  for v2model in installv2Models:
    # Call install function for each v2model
    install(v2model[0], v2model[1])

install_checkpoint()
# Out:
# /content
#  *** Download Progress Summary as of Wed Jan 18 12:14:19 2023 ***
# =
# [#acc6c7 2.1GiB/3.9GiB(53%) CN:16 DL:199MiB ETA:9s]
# FILE: /content/pre_trained_model/Anything-v3-better-vae.ckpt
# -
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# acc6c7|OK  |   193MiB/s|/content/pre_trained_model/Anything-v3-better-vae.ckpt
#
# Status Legend:
# (OK):download completed.

# %%
#@title ## 2.2. Download Custom Model

import os
# %store -r

# %cd {root_dir}

#@markdown ### Custom model
modelUrl = "" #@param {'type': 'string'}
dst = str(root_dir)+"/pre_trained_model"

if not os.path.exists(dst):
    os.makedirs(dst)

def install(url):

  if url.startswith("https://drive.google.com"):
    # %cd {dst}
    # !gdown --fuzzy {url}
  elif url.startswith("https://huggingface.co/"):
    if '/blob/' in url:
      url = url.replace('/blob/', '/resolve/')
    #@markdown Change this part with your own huggingface token if you need to download your private model
    hf_token = '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' #@param {type:"string"}
    user_header = f"\"Authorization: Bearer {hf_token}\""
    # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {dst} -Z {url}
  else:
    # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {dst} -Z {url}

install(modelUrl)

# %%
#@title ## 2.3. Download Available VAE
# %store -r 

# %cd {root_dir}

installVae = []
#@markdown ### Available VAE
#@markdown Select one of the VAEs to download, select `none` for not download VAE:
vaeUrl = ["", \
          "https://huggingface.co/Linaqruf/personal_backup/resolve/main/animevae/animevae.pt", \
          "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt", \
          "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt"]
vaeList = ["none", \
           "anime.vae.pt", \
           "waifudiffusion.vae.pt", \
           "stablediffusion.vae.pt"]
vaeName = "anime.vae.pt" #@param ["none", "anime.vae.pt", "waifudiffusion.vae.pt", "stablediffusion.vae.pt"]

installVae.append((vaeName, vaeUrl[vaeList.index(vaeName)]))

def install(vae_name, url):
  hf_token = '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'
  user_header = f"\"Authorization: Bearer {hf_token}\""
  # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -o vae/{vae_name} "{url}"

def install_vae():
  if vaeName != "none":
    for vae in installVae:
      install(vae[0], vae[1])
  else:
    pass

install_vae()

# %% [markdown]
# # III. Data Acquisition
#
# You can either upload your dataset to this notebook or use the image scraper below to bulk download images from Danbooru.
#
# If you want to use your own dataset, you can upload to colab `local files`.

# %%
#@title ## 3.1. Define Train Data Directory
#@markdown Define where your train data will be located. This cell will also create a folder based on your input. 
#@markdown This folder will be used as the target folder for scraping, tagging, bucketing, and training in the next cell.

import os
# %store -r

train_data_dir = "/content/fine_tune/train_data" #@param {'type' : 'string'}
# %store train_data_dir

if not os.path.exists(train_data_dir):
    os.makedirs(train_data_dir)
else:
    print(f"{train_data_dir} already exists\n")

print(f"Your train data directory : {train_data_dir}")
# Out:
# Stored 'train_data_dir' (str)
# Your train data directory : /content/fine_tune/train_data

# %%
#@title ## 3.2. Clone Dataset Repository (Optional)
#@markdown *Optional but can be useful for resume training process, because you will need that `last-state` folder*
# %store -r

# %cd {root_dir}

#@markdown ### Define Parameters
repository_url = "https://huggingface.co/datasets/Linaqruf/hitokomoru-tag-v2"  #@param {'type': 'string'}

#@markdown ### Leave it empty if your datasets is on `main` branch
branch = "" #@param {'type': 'string'}

# !git lfs install
if branch != "":
  # !git clone --branch {branch} {repository_url}
else:
  # !git clone {repository_url}

# %%
#@title ## 3.3. Download dataset (.zip)
import os
import shutil
from pathlib import Path
# %store -r

#@markdown ### Define download parameter
zipfile_url = "https://huggingface.co/datasets/Linaqruf/anijourneydb/resolve/main/anijourneydbv1_512.zip" #@param {'type': 'string'}
zipfile_path = str(root_dir)+"/train_data.zip"

dirname = os.path.dirname(zipfile_path)
basename = os.path.basename(zipfile_path)

try:
  if zipfile_url.startswith("https://drive.google.com"):
    # !gdown --fuzzy  {zipfile_url}
  elif zipfile_url.startswith("magnet:?"):
    # !aria2c --summary-interval=10 -c -x 10 -k 1M -s 10 {zipfile_url}
  elif zipfile_url.startswith("https://huggingface.co/"):
    if '/blob/' in zipfile_url:
      zipfile_url = zipfile_url.replace('/blob/', '/resolve/')

    #@markdown Change this part with your own huggingface token if you need to download your private model
    hf_token = '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' #@param {type:"string"}
    user_header = f"\"Authorization: Bearer {hf_token}\""
    # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {dirname} -o {basename} {zipfile_url}
  else:
    # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {dirname} -o {basename} {zipfile_url}

except Exception as e:
  print("An error occurred while downloading the file:", e)

#@markdown Tick this if you want to extract all files directly to `train_data_dir`, and automatically delete the zip to save the memory
auto_unzip_and_delete = True #@param{'type':'boolean'}

if auto_unzip_and_delete:
  # !unzip -j {zipfile_path} -d {train_data_dir}

  # directory to check for files
  # JSON files to move
  files_to_move = ("meta_cap.json", \
                   "meta_cap_dd.json", \
                   "meta_lat.json", \
                   "meta_clean.json")

  # check each file in the directory
  for filename in os.listdir(train_data_dir):
      # get the full file path
      file_path = os.path.join(train_data_dir, filename)
      if filename in files_to_move:
          # move the file to the parent directory
          shutil.move(file_path, os.path.dirname(train_data_dir))
  
  path_obj = Path(zipfile_path)
  zipfile_name = path_obj.parts[-1]
  
  if os.path.isdir(zipfile_path):
    print("\nThis zipfile doesn't exist or has been deleted \n")
  else:
    os.remove(zipfile_path)
    print(f"\n{zipfile_name} has been deleted")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/fine_tune/train_data/hito_komoru-014.jpg
#   inflating: /content/fine_tune/train_data/tarte-159.npz
#   inflating: /content/fine_tune/train_data/tarte-090.caption
#  extracting: /content/fine_tune/train_data/mogoon-130.caption
#   inflating: /content/fine_tune/train_data/tarte-432.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-306.txt
#   inflating: /content/fine_tune/train_data/tarte-426.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-197.txt
#   inflating: /content/fine_tune/train_data/tarte-476.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-044.png
#  extracting: /content/fine_tune/train_data/mikapikazo-278.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-058.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-537.caption
#  extracting: /content/fine_tune/train_data/tarte-334.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-019.txt
#   inflating: /content/fine_tune/train_data/tarte-482.npz
#   inflating: /content/fine_tune/train_data/tarte-325.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-061.caption
#   inflating: /content/fine_tune/train_data/tarte-076.caption
#   inflating: /content/fine_tune/train_data/tarte-217.caption
#  extracting: /content/fine_tune/train_data/hito_komoru-122.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-250.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-151.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-046.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-206.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-073.png
#   inflating: /content/fine_tune/train_data/user_efde2828-010.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-072.txt
#  extracting: /content/fine_tune/train_data/mikapikazo-343.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-442.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-122.png
#   inflating: /content/fine_tune/train_data/mikapikazo-018.png
#   inflating: /content/fine_tune/train_data/user_efde2828-080.png
#   inflating: /content/fine_tune/train_data/user_efde2828-477.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-141.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-143.png
#  extracting: /content/fine_tune/train_data/mikapikazo-246.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-512.npz
#   inflating: /content/fine_tune/train_data/tarte-346.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-033.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-496.txt
#  extracting: /content/fine_tune/train_data/user_efde2828-541.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-152.png
#   inflating: /content/fine_tune/train_data/user_efde2828-197.npz
#  extracting: /content/fine_tune/train_data/torinoaqua-087.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-093.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-143.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-114.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-388.caption
#   inflating: /content/fine_tune/train_data/tarte-110.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-155.npz
#   inflating: /content/fine_tune/train_data/tarte-022.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-039.png
#   inflating: /content/fine_tune/train_data/tarte-377.npz
#   inflating: /content/fine_tune/train_data/tarte-638.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-100.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-112.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-341.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-053.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-147.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-260.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-493.npz
#   inflating: /content/fine_tune/train_data/tarte-252.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-054.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-373.txt
#   inflating: /content/fine_tune/train_data/tarte-154.txt
#   inflating: /content/fine_tune/train_data/tarte-404.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-132.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-250.caption
#   inflating: /content/fine_tune/train_data/mogoon-102.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-068.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-379.npz
#   inflating: /content/fine_tune/train_data/tarte-498.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-046.npz
#   inflating: /content/fine_tune/train_data/tarte-161.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-106.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-477.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-537.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-257.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-159.txt
#   inflating: /content/fine_tune/train_data/tarte-029.png
#   inflating: /content/fine_tune/train_data/tarte-370.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-011.txt
#   inflating: /content/fine_tune/train_data/tarte-164.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-279.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-004.npz
#   inflating: /content/fine_tune/train_data/tarte-313.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-360.txt
#   inflating: /content/fine_tune/train_data/tarte-154.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-397.npz
#   inflating: /content/fine_tune/train_data/tarte-007.png
#   inflating: /content/fine_tune/train_data/user_efde2828-266.txt
#   inflating: /content/fine_tune/train_data/tarte-615.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-094.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-040.png
#   inflating: /content/fine_tune/train_data/torinoaqua-061.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-310.txt
#   inflating: /content/fine_tune/train_data/tarte-163.npz
#   inflating: /content/fine_tune/train_data/tarte-103.png
#   inflating: /content/fine_tune/train_data/tarte-167.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-186.png
#  extracting: /content/fine_tune/train_data/user_efde2828-274.caption
#   inflating: /content/fine_tune/train_data/mogoon-089.txt
#   inflating: /content/fine_tune/train_data/mogoon-125.npz
#   inflating: /content/fine_tune/train_data/tarte-165.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-376.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-079.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-051.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-146.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-076.png
#   inflating: /content/fine_tune/train_data/tarte-360.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-210.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-137.txt
#   inflating: /content/fine_tune/train_data/mogoon-111.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-051.txt
#   inflating: /content/fine_tune/train_data/tarte-229.npz
#   inflating: /content/fine_tune/train_data/tarte-151.png
#   inflating: /content/fine_tune/train_data/user_efde2828-403.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-242.png
#   inflating: /content/fine_tune/train_data/user_efde2828-136.txt
#   inflating: /content/fine_tune/train_data/mogoon-025.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-177.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-084.jpg
#   inflating: /content/fine_tune/train_data/tarte-330.jpg
#   inflating: /content/fine_tune/train_data/tarte-556.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-118.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-181.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-161.npz
#   inflating: /content/fine_tune/train_data/tarte-467.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-035.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-019.caption
#  extracting: /content/fine_tune/train_data/tarte-438.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-057.png
#   inflating: /content/fine_tune/train_data/tarte-194.png
#   inflating: /content/fine_tune/train_data/tarte-301.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-162.png
#   inflating: /content/fine_tune/train_data/user_efde2828-066.caption
#   inflating: /content/fine_tune/train_data/tarte-384.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-379.npz
#   inflating: /content/fine_tune/train_data/tarte-277.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-064.png
#   inflating: /content/fine_tune/train_data/mikapikazo-282.png
#   inflating: /content/fine_tune/train_data/tarte-365.jpg
#   inflating: /content/fine_tune/train_data/tarte-230.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-109.npz
#   inflating: /content/fine_tune/train_data/tarte-575.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-055.txt
#   inflating: /content/fine_tune/train_data/tarte-583.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-077.npz
#   inflating: /content/fine_tune/train_data/tarte-596.caption
#   inflating: /content/fine_tune/train_data/tarte-616.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-047.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-130.png
#   inflating: /content/fine_tune/train_data/tarte-313.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-253.jpg
#   inflating: /content/fine_tune/train_data/tarte-209.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-552.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-154.npz
#   inflating: /content/fine_tune/train_data/tarte-292.npz
#   inflating: /content/fine_tune/train_data/tarte-388.txt
#   inflating: /content/fine_tune/train_data/tarte-499.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-502.jpg
#   inflating: /content/fine_tune/train_data/tarte-181.txt
#   inflating: /content/fine_tune/train_data/tarte-283.npz
#  extracting: /content/fine_tune/train_data/tarte-513.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-297.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-245.png
#   inflating: /content/fine_tune/train_data/tarte-261.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-365.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-129.png
#   inflating: /content/fine_tune/train_data/tarte-648.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-514.npz
#   inflating: /content/fine_tune/train_data/tarte-119.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-289.caption
#   inflating: /content/fine_tune/train_data/tarte-334.npz
#   inflating: /content/fine_tune/train_data/mogoon-075.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-444.npz
#   inflating: /content/fine_tune/train_data/mogoon-070.caption
#   inflating: /content/fine_tune/train_data/mogoon-047.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-414.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-326.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-460.jpg
#   inflating: /content/fine_tune/train_data/hito_komoru-012.npz
#   inflating: /content/fine_tune/train_data/tarte-650.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-050.png
#   inflating: /content/fine_tune/train_data/user_efde2828-280.caption
#  extracting: /content/fine_tune/train_data/mikapikazo-349.caption
#   inflating: /content/fine_tune/train_data/tarte-435.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-110.caption
#   inflating: /content/fine_tune/train_data/tarte-462.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-127.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-197.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-001.npz
#   inflating: /content/fine_tune/train_data/tarte-468.txt
#   inflating: /content/fine_tune/train_data/tarte-593.npz
#   inflating: /content/fine_tune/train_data/tarte-174.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-068.npz
#   inflating: /content/fine_tune/train_data/tarte-064.npz
#  extracting: /content/fine_tune/train_data/torinoaqua-052.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-382.png
#   inflating: /content/fine_tune/train_data/mogoon-017.jpg
#   inflating: /content/fine_tune/train_data/tarte-112.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-030.caption
#   inflating: /content/fine_tune/train_data/mogoon-100.txt
#   inflating: /content/fine_tune/train_data/tarte-225.txt
#   inflating: /content/fine_tune/train_data/tarte-255.txt
#   inflating: /content/fine_tune/train_data/tarte-153.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-032.txt
#   inflating: /content/fine_tune/train_data/tarte-539.npz
#   inflating: /content/fine_tune/train_data/tarte-196.npz
#   inflating: /content/fine_tune/train_data/tarte-076.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-460.npz
#   inflating: /content/fine_tune/train_data/mogoon-004.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-017.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-099.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-010.png
#  extracting: /content/fine_tune/train_data/user_efde2828-235.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-038.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-103.png
#   inflating: /content/fine_tune/train_data/mikapikazo-193.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-273.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-341.jpg
#   inflating: /content/fine_tune/train_data/mogoon-078.caption
#   inflating: /content/fine_tune/train_data/tarte-013.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-185.txt
#   inflating: /content/fine_tune/train_data/tarte-588.txt
#   inflating: /content/fine_tune/train_data/tarte-096.png
#  extracting: /content/fine_tune/train_data/tarte-190.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-020.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-021.jpg
#   inflating: /content/fine_tune/train_data/mogoon-115.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-086.jpg
#   inflating: /content/fine_tune/train_data/tarte-129.caption
#   inflating: /content/fine_tune/train_data/tarte-209.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-163.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-104.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-110.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-086.txt
#  extracting: /content/fine_tune/train_data/mikapikazo-061.caption
#   inflating: /content/fine_tune/train_data/tarte-391.txt
#   inflating: /content/fine_tune/train_data/mogoon-024.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-251.png
#   inflating: /content/fine_tune/train_data/hito_komoru-009.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-554.npz
#   inflating: /content/fine_tune/train_data/tarte-666.caption
#   inflating: /content/fine_tune/train_data/tarte-591.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-232.txt
#   inflating: /content/fine_tune/train_data/mogoon-040.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-398.png
#   inflating: /content/fine_tune/train_data/tarte-502.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-154.jpg
#   inflating: /content/fine_tune/train_data/tarte-354.caption
#   inflating: /content/fine_tune/train_data/mogoon-092.txt
#   inflating: /content/fine_tune/train_data/tarte-213.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-205.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-020.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-273.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-395.txt
#   inflating: /content/fine_tune/train_data/mogoon-081.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-176.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-383.png
#   inflating: /content/fine_tune/train_data/mikapikazo-007.png
#   inflating: /content/fine_tune/train_data/hito_komoru-069.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-082.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-163.png
#   inflating: /content/fine_tune/train_data/mikapikazo-058.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-054.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-204.png
#   inflating: /content/fine_tune/train_data/mikapikazo-228.png
#   inflating: /content/fine_tune/train_data/tarte-512.txt
#   inflating: /content/fine_tune/train_data/mogoon-046.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-174.npz
#  extracting: /content/fine_tune/train_data/tarte-006.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-073.jpg
#   inflating: /content/fine_tune/train_data/tarte-453.jpg
#   inflating: /content/fine_tune/train_data/tarte-277.jpg
#   inflating: /content/fine_tune/train_data/tarte-123.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-023.png
#   inflating: /content/fine_tune/train_data/mikapikazo-049.txt
#  extracting: /content/fine_tune/train_data/tarte-031.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-028.npz
#   inflating: /content/fine_tune/train_data/tarte-401.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-424.txt
#   inflating: /content/fine_tune/train_data/tarte-069.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-054.png
#   inflating: /content/fine_tune/train_data/tarte-204.caption
#   inflating: /content/fine_tune/train_data/tarte-406.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-244.npz
#   inflating: /content/fine_tune/train_data/tarte-387.txt
#  extracting: /content/fine_tune/train_data/mogoon-106.caption
#   inflating: /content/fine_tune/train_data/tarte-275.jpg
#   inflating: /content/fine_tune/train_data/tarte-046.png
#  extracting: /content/fine_tune/train_data/user_efde2828-221.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-057.npz
#  extracting: /content/fine_tune/train_data/tarte-463.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-018.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-081.png
#   inflating: /content/fine_tune/train_data/hito_komoru-086.npz
#   inflating: /content/fine_tune/train_data/tarte-003.png
#   inflating: /content/fine_tune/train_data/tarte-163.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-117.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-004.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-073.txt
#   inflating: /content/fine_tune/train_data/tarte-579.npz
#   inflating: /content/fine_tune/train_data/tarte-004.txt
#   inflating: /content/fine_tune/train_data/tarte-202.txt
#   inflating: /content/fine_tune/train_data/tarte-087.png
#   inflating: /content/fine_tune/train_data/torinoaqua-135.jpg
#   inflating: /content/fine_tune/train_data/tarte-044.png
#   inflating: /content/fine_tune/train_data/tarte-490.jpg
#   inflating: /content/fine_tune/train_data/hito_komoru-124.txt
#  extracting: /content/fine_tune/train_data/tarte-527.caption
#   inflating: /content/fine_tune/train_data/tarte-100.npz
#   inflating: /content/fine_tune/train_data/tarte-669.caption
#  extracting: /content/fine_tune/train_data/tarte-392.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-333.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-297.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-066.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-382.png
#   inflating: /content/fine_tune/train_data/torinoaqua-059.npz
#   inflating: /content/fine_tune/train_data/tarte-180.png
#   inflating: /content/fine_tune/train_data/mikapikazo-084.png
#   inflating: /content/fine_tune/train_data/mikapikazo-141.npz
#  extracting: /content/fine_tune/train_data/tarte-311.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-008.npz
#   inflating: /content/fine_tune/train_data/tarte-280.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-323.npz
#   inflating: /content/fine_tune/train_data/tarte-626.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-509.jpg
#   inflating: /content/fine_tune/train_data/tarte-051.png
#   inflating: /content/fine_tune/train_data/user_efde2828-413.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-221.npz
#   inflating: /content/fine_tune/train_data/tarte-651.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-376.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-057.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-120.jpg
#   inflating: /content/fine_tune/train_data/tarte-409.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-227.caption
#   inflating: /content/fine_tune/train_data/mogoon-050.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-421.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-219.npz
#   inflating: /content/fine_tune/train_data/tarte-231.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-379.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-194.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-186.caption
#   inflating: /content/fine_tune/train_data/tarte-030.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-207.png
#   inflating: /content/fine_tune/train_data/user_efde2828-076.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-049.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-430.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-014.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-153.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-376.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-062.txt
#   inflating: /content/fine_tune/train_data/mogoon-035.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-080.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-357.caption
#   inflating: /content/fine_tune/train_data/tarte-434.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-563.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-006.npz
#   inflating: /content/fine_tune/train_data/mogoon-018.npz
#   inflating: /content/fine_tune/train_data/mogoon-137.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-270.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-038.txt
#   inflating: /content/fine_tune/train_data/tarte-142.caption
#   inflating: /content/fine_tune/train_data/tarte-506.jpg
#   inflating: /content/fine_tune/train_data/tarte-272.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-409.caption
#   inflating: /content/fine_tune/train_data/mogoon-016.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-056.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-099.txt
#   inflating: /content/fine_tune/train_data/tarte-223.txt
#   inflating: /content/fine_tune/train_data/tarte-628.caption
#   inflating: /content/fine_tune/train_data/tarte-459.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-189.png
#   inflating: /content/fine_tune/train_data/user_efde2828-523.jpg
#   inflating: /content/fine_tune/train_data/tarte-022.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-127.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-360.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-120.txt
#  extracting: /content/fine_tune/train_data/tarte-353.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-336.png
#  extracting: /content/fine_tune/train_data/tarte-046.caption
#   inflating: /content/fine_tune/train_data/tarte-054.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-341.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-030.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-380.png
#   inflating: /content/fine_tune/train_data/mikapikazo-047.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-142.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-169.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-101.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-056.png
#   inflating: /content/fine_tune/train_data/user_efde2828-300.png
#   inflating: /content/fine_tune/train_data/mikapikazo-177.png
#   inflating: /content/fine_tune/train_data/torinoaqua-157.jpg
#   inflating: /content/fine_tune/train_data/tarte-144.png
#   inflating: /content/fine_tune/train_data/tarte-493.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-236.txt
#   inflating: /content/fine_tune/train_data/tarte-347.jpg
#  extracting: /content/fine_tune/train_data/user_efde2828-512.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-122.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-563.caption
#   inflating: /content/fine_tune/train_data/mogoon-110.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-116.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-101.npz
#   inflating: /content/fine_tune/train_data/mogoon-104.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-459.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-507.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-126.png
#   inflating: /content/fine_tune/train_data/mikapikazo-067.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-064.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-155.npz
#   inflating: /content/fine_tune/train_data/tarte-408.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-045.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-102.npz
#   inflating: /content/fine_tune/train_data/tarte-621.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-013.png
#   inflating: /content/fine_tune/train_data/hito_komoru-009.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-166.caption
#   inflating: /content/fine_tune/train_data/tarte-296.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-284.caption
#   inflating: /content/fine_tune/train_data/tarte-095.png
#   inflating: /content/fine_tune/train_data/hito_komoru-126.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-155.txt
#   inflating: /content/fine_tune/train_data/tarte-556.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-107.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-276.caption
#  extracting: /content/fine_tune/train_data/tarte-662.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-262.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-254.png
#  extracting: /content/fine_tune/train_data/mikapikazo-036.caption
#   inflating: /content/fine_tune/train_data/tarte-544.caption
#   inflating: /content/fine_tune/train_data/tarte-577.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-182.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-115.caption
#  extracting: /content/fine_tune/train_data/tarte-318.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-074.png
#   inflating: /content/fine_tune/train_data/mikapikazo-048.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-470.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-082.png
#   inflating: /content/fine_tune/train_data/mogoon-019.npz
#  extracting: /content/fine_tune/train_data/tarte-246.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-348.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-052.jpg
#   inflating: /content/fine_tune/train_data/tarte-278.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-082.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-044.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-084.npz
#   inflating: /content/fine_tune/train_data/tarte-251.npz
#   inflating: /content/fine_tune/train_data/mogoon-074.npz
#  extracting: /content/fine_tune/train_data/mogoon-022.caption
#   inflating: /content/fine_tune/train_data/mogoon-008.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-302.caption
#   inflating: /content/fine_tune/train_data/mogoon-048.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-083.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-218.txt
#  extracting: /content/fine_tune/train_data/hito_komoru-061.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-070.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-117.png
#   inflating: /content/fine_tune/train_data/tarte-048.png
#   inflating: /content/fine_tune/train_data/mogoon-032.txt
#   inflating: /content/fine_tune/train_data/tarte-105.txt
#   inflating: /content/fine_tune/train_data/tarte-610.jpg
#   inflating: /content/fine_tune/train_data/tarte-417.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-143.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-110.caption
#  extracting: /content/fine_tune/train_data/mikapikazo-043.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-184.png
#   inflating: /content/fine_tune/train_data/hito_komoru-011.jpg
#   inflating: /content/fine_tune/train_data/tarte-321.npz
#   inflating: /content/fine_tune/train_data/tarte-326.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-574.jpg
#  extracting: /content/fine_tune/train_data/mikapikazo-197.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-029.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-048.caption
#   inflating: /content/fine_tune/train_data/tarte-043.png
#   inflating: /content/fine_tune/train_data/tarte-503.caption
#   inflating: /content/fine_tune/train_data/mogoon-036.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-286.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-092.png
#   inflating: /content/fine_tune/train_data/user_efde2828-513.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-118.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-564.npz
#   inflating: /content/fine_tune/train_data/mogoon-022.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-024.npz
#   inflating: /content/fine_tune/train_data/tarte-586.caption
#   inflating: /content/fine_tune/train_data/tarte-489.npz
#  extracting: /content/fine_tune/train_data/tarte-118.caption
#   inflating: /content/fine_tune/train_data/tarte-670.txt
#   inflating: /content/fine_tune/train_data/tarte-482.txt
#   inflating: /content/fine_tune/train_data/tarte-473.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-041.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-570.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-074.npz
#   inflating: /content/fine_tune/train_data/tarte-275.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-321.caption
#   inflating: /content/fine_tune/train_data/tarte-323.jpg
#   inflating: /content/fine_tune/train_data/tarte-493.jpg
#   inflating: /content/fine_tune/train_data/tarte-427.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-462.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-091.png
#   inflating: /content/fine_tune/train_data/user_efde2828-461.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-443.caption
#   inflating: /content/fine_tune/train_data/tarte-307.txt
#   inflating: /content/fine_tune/train_data/mogoon-097.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-450.txt
#   inflating: /content/fine_tune/train_data/tarte-432.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-054.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-495.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-428.jpg
#  extracting: /content/fine_tune/train_data/tarte-585.caption
#   inflating: /content/fine_tune/train_data/tarte-114.png
#   inflating: /content/fine_tune/train_data/mogoon-042.jpg
#   inflating: /content/fine_tune/train_data/tarte-146.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-263.caption
#   inflating: /content/fine_tune/train_data/tarte-131.txt
#   inflating: /content/fine_tune/train_data/tarte-668.txt
#   inflating: /content/fine_tune/train_data/tarte-415.npz
#   inflating: /content/fine_tune/train_data/tarte-223.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-095.txt
#   inflating: /content/fine_tune/train_data/tarte-653.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-213.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-033.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-270.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-053.jpg
#   inflating: /content/fine_tune/train_data/tarte-551.jpg
#   inflating: /content/fine_tune/train_data/mogoon-026.txt
#  extracting: /content/fine_tune/train_data/torinoaqua-037.caption
#  extracting: /content/fine_tune/train_data/hito_komoru-007.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-008.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-201.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-405.jpg
#   inflating: /content/fine_tune/train_data/tarte-454.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-107.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-577.npz
#   inflating: /content/fine_tune/train_data/tarte-444.npz
#   inflating: /content/fine_tune/train_data/mogoon-019.txt
#   inflating: /content/fine_tune/train_data/tarte-646.jpg
#   inflating: /content/fine_tune/train_data/tarte-132.png
#   inflating: /content/fine_tune/train_data/torinoaqua-154.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-349.png
#   inflating: /content/fine_tune/train_data/tarte-077.npz
#   inflating: /content/fine_tune/train_data/mogoon-044.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-357.png
#   inflating: /content/fine_tune/train_data/torinoaqua-068.txt
#   inflating: /content/fine_tune/train_data/tarte-605.npz
#   inflating: /content/fine_tune/train_data/mogoon-074.txt
#   inflating: /content/fine_tune/train_data/tarte-202.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-543.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-133.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-228.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-190.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-459.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-064.caption
#   inflating: /content/fine_tune/train_data/tarte-230.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-104.png
#   inflating: /content/fine_tune/train_data/tarte-601.jpg
#   inflating: /content/fine_tune/train_data/mogoon-110.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-076.png
#   inflating: /content/fine_tune/train_data/tarte-484.txt
#  extracting: /content/fine_tune/train_data/hito_komoru-107.caption
#  extracting: /content/fine_tune/train_data/mikapikazo-203.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-430.txt
#   inflating: /content/fine_tune/train_data/mogoon-029.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-041.npz
#   inflating: /content/fine_tune/train_data/tarte-314.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-092.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-265.png
#   inflating: /content/fine_tune/train_data/user_efde2828-373.png
#   inflating: /content/fine_tune/train_data/user_efde2828-364.txt
#   inflating: /content/fine_tune/train_data/tarte-411.txt
#   inflating: /content/fine_tune/train_data/tarte-526.txt
#   inflating: /content/fine_tune/train_data/tarte-266.npz
#   inflating: /content/fine_tune/train_data/tarte-457.jpg
#  extracting: /content/fine_tune/train_data/mikapikazo-218.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-432.npz
#  extracting: /content/fine_tune/train_data/torinoaqua-114.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-435.caption
#   inflating: /content/fine_tune/train_data/tarte-252.npz
#   inflating: /content/fine_tune/train_data/tarte-071.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-114.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-075.txt
#   inflating: /content/fine_tune/train_data/mogoon-092.jpg
#   inflating: /content/fine_tune/train_data/tarte-418.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-009.txt
#   inflating: /content/fine_tune/train_data/tarte-079.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-061.npz
#   inflating: /content/fine_tune/train_data/tarte-542.npz
#   inflating: /content/fine_tune/train_data/mogoon-122.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-054.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-479.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-505.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-103.txt
#   inflating: /content/fine_tune/train_data/tarte-077.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-036.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-142.npz
#   inflating: /content/fine_tune/train_data/tarte-643.npz
#   inflating: /content/fine_tune/train_data/tarte-067.npz
#   inflating: /content/fine_tune/train_data/tarte-156.png
#   inflating: /content/fine_tune/train_data/user_efde2828-112.npz
#   inflating: /content/fine_tune/train_data/tarte-369.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-369.png
#   inflating: /content/fine_tune/train_data/mikapikazo-374.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-133.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-254.caption
#  extracting: /content/fine_tune/train_data/mikapikazo-236.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-281.npz
#   inflating: /content/fine_tune/train_data/tarte-412.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-269.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-240.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-387.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-179.png
#   inflating: /content/fine_tune/train_data/user_efde2828-415.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-500.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-001.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-005.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-302.png
#   inflating: /content/fine_tune/train_data/mikapikazo-256.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-023.caption
#   inflating: /content/fine_tune/train_data/tarte-552.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-138.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-039.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-122.txt
#  extracting: /content/fine_tune/train_data/user_efde2828-134.caption
#   inflating: /content/fine_tune/train_data/tarte-160.png
#   inflating: /content/fine_tune/train_data/mikapikazo-101.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-037.npz
#   inflating: /content/fine_tune/train_data/tarte-080.txt
#   inflating: /content/fine_tune/train_data/tarte-160.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-115.jpg
#   inflating: /content/fine_tune/train_data/tarte-468.npz
#   inflating: /content/fine_tune/train_data/tarte-284.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-018.npz
#   inflating: /content/fine_tune/train_data/tarte-169.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-070.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-097.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-247.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-578.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-404.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-183.png
#   inflating: /content/fine_tune/train_data/hito_komoru-104.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-507.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-041.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-024.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-026.caption
#   inflating: /content/fine_tune/train_data/tarte-016.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-359.png
#   inflating: /content/fine_tune/train_data/mogoon-100.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-201.npz
#   inflating: /content/fine_tune/train_data/tarte-061.png
#   inflating: /content/fine_tune/train_data/tarte-144.npz
#  extracting: /content/fine_tune/train_data/mikapikazo-163.caption
#   inflating: /content/fine_tune/train_data/mogoon-105.npz
#   inflating: /content/fine_tune/train_data/tarte-466.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-307.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-175.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-225.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-518.txt
#  extracting: /content/fine_tune/train_data/user_efde2828-176.caption
#   inflating: /content/fine_tune/train_data/tarte-506.npz
#   inflating: /content/fine_tune/train_data/tarte-095.txt
#   inflating: /content/fine_tune/train_data/tarte-514.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-050.txt
#   inflating: /content/fine_tune/train_data/tarte-594.npz
#   inflating: /content/fine_tune/train_data/tarte-655.jpg
#   inflating: /content/fine_tune/train_data/mogoon-068.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-149.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-309.txt
#   inflating: /content/fine_tune/train_data/tarte-546.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-049.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-469.caption
#   inflating: /content/fine_tune/train_data/mogoon-113.npz
#   inflating: /content/fine_tune/train_data/tarte-116.txt
#   inflating: /content/fine_tune/train_data/tarte-164.npz
#  extracting: /content/fine_tune/train_data/tarte-242.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-014.txt
#   inflating: /content/fine_tune/train_data/mogoon-033.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-344.jpg
#   inflating: /content/fine_tune/train_data/tarte-106.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-224.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-048.png
#   inflating: /content/fine_tune/train_data/mikapikazo-331.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-287.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-041.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-463.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-073.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-043.png
#  extracting: /content/fine_tune/train_data/tarte-569.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-224.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-162.caption
#   inflating: /content/fine_tune/train_data/tarte-150.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-572.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-127.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-444.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-368.txt
#   inflating: /content/fine_tune/train_data/tarte-440.jpg
#   inflating: /content/fine_tune/train_data/tarte-015.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-138.png
#  extracting: /content/fine_tune/train_data/user_efde2828-473.caption
#  extracting: /content/fine_tune/train_data/tarte-434.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-250.png
#   inflating: /content/fine_tune/train_data/mikapikazo-271.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-244.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-100.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-015.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-232.npz
#   inflating: /content/fine_tune/train_data/tarte-670.caption
#   inflating: /content/fine_tune/train_data/mogoon-030.npz
#   inflating: /content/fine_tune/train_data/tarte-485.caption
#   inflating: /content/fine_tune/train_data/tarte-155.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-046.caption
#   inflating: /content/fine_tune/train_data/mogoon-011.npz
#   inflating: /content/fine_tune/train_data/tarte-187.npz
#  extracting: /content/fine_tune/train_data/torinoaqua-145.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-131.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-148.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-259.npz
#   inflating: /content/fine_tune/train_data/mogoon-026.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-107.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-039.txt
#   inflating: /content/fine_tune/train_data/tarte-607.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-016.caption
#   inflating: /content/fine_tune/train_data/tarte-614.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-269.caption
#   inflating: /content/fine_tune/train_data/mogoon-099.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-012.jpg
#   inflating: /content/fine_tune/train_data/tarte-485.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-083.caption
#   inflating: /content/fine_tune/train_data/tarte-404.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-029.caption
#   inflating: /content/fine_tune/train_data/tarte-353.jpg
#  extracting: /content/fine_tune/train_data/hito_komoru-104.caption
#   inflating: /content/fine_tune/train_data/mogoon-093.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-317.txt
#  extracting: /content/fine_tune/train_data/tarte-097.txt
#   inflating: /content/fine_tune/train_data/tarte-548.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-078.caption
#   inflating: /content/fine_tune/train_data/tarte-042.png
#   inflating: /content/fine_tune/train_data/tarte-236.npz
#   inflating: /content/fine_tune/train_data/mogoon-020.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-170.txt
#   inflating: /content/fine_tune/train_data/tarte-089.png
#  extracting: /content/fine_tune/train_data/user_efde2828-424.caption
#   inflating: /content/fine_tune/train_data/tarte-540.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-131.png
#   inflating: /content/fine_tune/train_data/tarte-535.jpg
#   inflating: /content/fine_tune/train_data/tarte-617.npz
#   inflating: /content/fine_tune/train_data/tarte-200.caption
#   inflating: /content/fine_tune/train_data/tarte-447.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-023.txt
# ...
#   inflating: /content/fine_tune/train_data/user_efde2828-536.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-161.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-531.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-149.png
#   inflating: /content/fine_tune/train_data/hito_komoru-015.caption
#  extracting: /content/fine_tune/train_data/tarte-405.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-339.caption
#   inflating: /content/fine_tune/train_data/tarte-486.npz
#   inflating: /content/fine_tune/train_data/tarte-479.caption
#   inflating: /content/fine_tune/train_data/tarte-570.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-536.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-117.png
#   inflating: /content/fine_tune/train_data/tarte-140.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-143.jpg
#   inflating: /content/fine_tune/train_data/tarte-179.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-033.txt
#   inflating: /content/fine_tune/train_data/tarte-232.jpg
#   inflating: /content/fine_tune/train_data/tarte-638.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-159.png
#   inflating: /content/fine_tune/train_data/mikapikazo-125.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-103.npz
#   inflating: /content/fine_tune/train_data/tarte-045.png
#   inflating: /content/fine_tune/train_data/tarte-217.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-286.png
#   inflating: /content/fine_tune/train_data/user_efde2828-529.txt
#   inflating: /content/fine_tune/train_data/tarte-560.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-359.npz
#  extracting: /content/fine_tune/train_data/hito_komoru-038.caption
#  extracting: /content/fine_tune/train_data/tarte-026.caption
#   inflating: /content/fine_tune/train_data/tarte-033.npz
#  extracting: /content/fine_tune/train_data/tarte-647.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-073.txt
#   inflating: /content/fine_tune/train_data/tarte-495.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-379.caption
#   inflating: /content/fine_tune/train_data/mogoon-004.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-088.npz
#   inflating: /content/fine_tune/train_data/mogoon-126.jpg
#   inflating: /content/fine_tune/train_data/hito_komoru-032.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-221.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-109.npz
#   inflating: /content/fine_tune/train_data/tarte-644.txt
#  extracting: /content/fine_tune/train_data/user_efde2828-277.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-361.png
#   inflating: /content/fine_tune/train_data/user_efde2828-517.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-203.npz
#   inflating: /content/fine_tune/train_data/tarte-210.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-570.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-021.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-552.npz
#   inflating: /content/fine_tune/train_data/tarte-251.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-112.png
#   inflating: /content/fine_tune/train_data/mikapikazo-167.npz
#   inflating: /content/fine_tune/train_data/tarte-239.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-100.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-071.txt
#   inflating: /content/fine_tune/train_data/tarte-145.png
#   inflating: /content/fine_tune/train_data/tarte-536.caption
#   inflating: /content/fine_tune/train_data/tarte-658.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-064.npz
#   inflating: /content/fine_tune/train_data/tarte-041.png
#   inflating: /content/fine_tune/train_data/user_efde2828-556.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-458.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-146.txt
#   inflating: /content/fine_tune/train_data/tarte-240.jpg
#   inflating: /content/fine_tune/train_data/tarte-121.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-092.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-188.npz
#   inflating: /content/fine_tune/train_data/tarte-037.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-101.png
#  extracting: /content/fine_tune/train_data/tarte-506.caption
#   inflating: /content/fine_tune/train_data/tarte-152.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-174.png
#   inflating: /content/fine_tune/train_data/mikapikazo-247.txt
#   inflating: /content/fine_tune/train_data/tarte-238.npz
#   inflating: /content/fine_tune/train_data/tarte-084.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-011.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-003.npz
#   inflating: /content/fine_tune/train_data/mogoon-015.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-218.jpg
#   inflating: /content/fine_tune/train_data/tarte-626.npz
#   inflating: /content/fine_tune/train_data/tarte-059.png
#   inflating: /content/fine_tune/train_data/mikapikazo-092.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-087.png
#   inflating: /content/fine_tune/train_data/mogoon-107.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-368.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-322.png
#   inflating: /content/fine_tune/train_data/hito_komoru-062.png
#   inflating: /content/fine_tune/train_data/user_efde2828-139.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-400.caption
#   inflating: /content/fine_tune/train_data/tarte-304.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-029.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-035.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-109.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-013.txt
#   inflating: /content/fine_tune/train_data/tarte-516.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-087.txt
#   inflating: /content/fine_tune/train_data/tarte-333.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-358.caption
#   inflating: /content/fine_tune/train_data/tarte-256.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-125.png
#   inflating: /content/fine_tune/train_data/mikapikazo-144.txt
#   inflating: /content/fine_tune/train_data/tarte-340.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-024.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-374.txt
#   inflating: /content/fine_tune/train_data/tarte-254.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-217.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-263.txt
#   inflating: /content/fine_tune/train_data/tarte-411.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-080.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-076.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-144.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-432.jpg
#   inflating: /content/fine_tune/train_data/hito_komoru-085.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-179.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-488.npz
#   inflating: /content/fine_tune/train_data/mogoon-005.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-364.png
#   inflating: /content/fine_tune/train_data/user_efde2828-054.png
#   inflating: /content/fine_tune/train_data/torinoaqua-008.txt
#   inflating: /content/fine_tune/train_data/tarte-437.caption
#  extracting: /content/fine_tune/train_data/user_efde2828-540.caption
#   inflating: /content/fine_tune/train_data/tarte-452.npz
#   inflating: /content/fine_tune/train_data/tarte-025.png
#   inflating: /content/fine_tune/train_data/user_efde2828-208.png
#   inflating: /content/fine_tune/train_data/tarte-321.txt
#   inflating: /content/fine_tune/train_data/tarte-516.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-047.npz
#   inflating: /content/fine_tune/train_data/tarte-562.caption
#   inflating: /content/fine_tune/train_data/tarte-581.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-487.jpg
#   inflating: /content/fine_tune/train_data/torinoaqua-018.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-187.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-551.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-310.png
#   inflating: /content/fine_tune/train_data/tarte-232.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-530.jpg
#   inflating: /content/fine_tune/train_data/mogoon-066.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-089.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-052.png
#   inflating: /content/fine_tune/train_data/tarte-166.png
#   inflating: /content/fine_tune/train_data/tarte-033.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-301.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-474.jpg
#   inflating: /content/fine_tune/train_data/tarte-298.jpg
#   inflating: /content/fine_tune/train_data/tarte-656.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-471.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-043.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-300.npz
#   inflating: /content/fine_tune/train_data/mogoon-008.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-022.jpg
#   inflating: /content/fine_tune/train_data/tarte-173.png
#   inflating: /content/fine_tune/train_data/mikapikazo-350.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-212.png
#   inflating: /content/fine_tune/train_data/mikapikazo-162.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-063.npz
#  extracting: /content/fine_tune/train_data/tarte-025.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-059.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-008.npz
#   inflating: /content/fine_tune/train_data/tarte-491.npz
#   inflating: /content/fine_tune/train_data/tarte-247.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-517.jpg
#   inflating: /content/fine_tune/train_data/tarte-109.txt
#   inflating: /content/fine_tune/train_data/tarte-302.txt
#   inflating: /content/fine_tune/train_data/tarte-103.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-169.png
#   inflating: /content/fine_tune/train_data/tarte-222.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-253.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-122.txt
#   inflating: /content/fine_tune/train_data/torinoaqua-156.jpg
#   inflating: /content/fine_tune/train_data/mogoon-070.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-574.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-455.caption
#   inflating: /content/fine_tune/train_data/tarte-551.txt
#   inflating: /content/fine_tune/train_data/tarte-214.npz
#   inflating: /content/fine_tune/train_data/tarte-479.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-469.txt
#   inflating: /content/fine_tune/train_data/tarte-350.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-093.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-038.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-128.npz
#   inflating: /content/fine_tune/train_data/mogoon-096.txt
#   inflating: /content/fine_tune/train_data/mikapikazo-344.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-038.caption
#   inflating: /content/fine_tune/train_data/mogoon-048.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-465.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-119.png
#   inflating: /content/fine_tune/train_data/user_efde2828-064.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-113.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-380.npz
#   inflating: /content/fine_tune/train_data/tarte-519.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-106.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-127.txt
#   inflating: /content/fine_tune/train_data/hito_komoru-096.png
#   inflating: /content/fine_tune/train_data/user_efde2828-465.npz
#   inflating: /content/fine_tune/train_data/tarte-146.npz
#  extracting: /content/fine_tune/train_data/user_efde2828-561.caption
#   inflating: /content/fine_tune/train_data/tarte-225.jpg
#   inflating: /content/fine_tune/train_data/hito_komoru-048.npz
#  extracting: /content/fine_tune/train_data/mikapikazo-265.caption
#   inflating: /content/fine_tune/train_data/tarte-500.jpg
#  extracting: /content/fine_tune/train_data/tarte-292.caption
#   inflating: /content/fine_tune/train_data/tarte-148.npz
#   inflating: /content/fine_tune/train_data/tarte-510.jpg
#   inflating: /content/fine_tune/train_data/mikapikazo-032.txt
#   inflating: /content/fine_tune/train_data/mogoon-052.npz
#  extracting: /content/fine_tune/train_data/mikapikazo-248.caption
#   inflating: /content/fine_tune/train_data/tarte-179.png
#   inflating: /content/fine_tune/train_data/tarte-603.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-070.txt
#   inflating: /content/fine_tune/train_data/tarte-422.jpg
#   inflating: /content/fine_tune/train_data/mogoon-097.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-484.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-192.png
#   inflating: /content/fine_tune/train_data/user_efde2828-406.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-281.caption
#   inflating: /content/fine_tune/train_data/torinoaqua-135.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-069.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-263.npz
#   inflating: /content/fine_tune/train_data/torinoaqua-026.jpg
#  extracting: /content/fine_tune/train_data/tarte-151.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-284.png
#   inflating: /content/fine_tune/train_data/mikapikazo-200.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-520.caption
#  extracting: /content/fine_tune/train_data/tarte-499.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-289.jpg
#   inflating: /content/fine_tune/train_data/mogoon-127.txt
#   inflating: /content/fine_tune/train_data/tarte-075.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-516.jpg
#   inflating: /content/fine_tune/train_data/tarte-263.jpg
#   inflating: /content/fine_tune/train_data/tarte-011.txt
#   inflating: /content/fine_tune/train_data/user_efde2828-427.caption
#   inflating: /content/fine_tune/train_data/tarte-564.jpg
#   inflating: /content/fine_tune/train_data/tarte-662.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-159.npz
#   inflating: /content/fine_tune/train_data/tarte-265.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-391.npz
#   inflating: /content/fine_tune/train_data/tarte-309.npz
#   inflating: /content/fine_tune/train_data/hito_komoru-118.txt
#   inflating: /content/fine_tune/train_data/tarte-423.jpg
#   inflating: /content/fine_tune/train_data/user_efde2828-181.npz
#   inflating: /content/fine_tune/train_data/mikapikazo-122.caption
#   inflating: /content/fine_tune/train_data/hito_komoru-040.npz
#   inflating: /content/fine_tune/train_data/tarte-392.txt
#  extracting: /content/fine_tune/train_data/user_efde2828-445.caption
#   inflating: /content/fine_tune/train_data/user_efde2828-434.txt
#   inflating: /content/fine_tune/train_data/tarte-288.npz
#   inflating: /content/fine_tune/train_data/user_efde2828-171.png
#  extracting: /content/fine_tune/train_data/tarte-612.caption
#   inflating: /content/fine_tune/train_data/mikapikazo-031.txt
#  extracting: /content/fine_tune/train_data/tarte-484.caption
#
# train_data.zip has been deleted

# %%
#@title ### 3.3.1. Unzip dataset (.zip)
import shutil
import os
import zipfile
from pathlib import Path

#@markdown ### Define unzip parameter
zipfile_src = '/content/train_data.zip' #@param{'type':'string'}
zipfile_dst = '/content/fine_tune/train_data' #@param{'type':'string'}

#@markdown ### Delete zipfile after unzip process done
delete_zipfile = True #@param{'type':'boolean'}

try:   
  # !unzip -j {zipfile_src} -d {zipfile_dst}

except Exception as e:
  print("An error occurred while unzipping the file:", e)

# directory to check for files
  # JSON files to move
files_to_move = ("meta_cap.json", \
                 "meta_cap_dd.json", \
                 "meta_lat.json", \
                 "meta_clean.json")

  # check each file in the directory
for filename in os.listdir(zipfile_dst):
  # get the full file path
  file_path = os.path.join(zipfile_dst, filename)
  if filename in files_to_move:
    # move the file to the parent director
    shutil.move(file_path, os.path.dirname(zipfile_dst))
  
if delete_zipfile:
  path_obj = Path(zipfile_src)
  zipfile_name = path_obj.parts[-1]
  
  if os.path.isdir(zipfile_src):
    print("\nThis zipfile doesn't exist or has been deleted \n")
  else:
    os.remove(zipfile_src)
    print(f"\n{zipfile_name} has been deleted")

# %%
#@title ## 3.4. Simple Booru Scraper
#@markdown Use gallery-dl to scrape images from a booru site using the specified tags
import os
import html
# %store -r 

# %cd {root_dir}

# Set configuration options
booru = "Gelbooru" #@param ["", "Danbooru", "Gelbooru"]
tag1 = "hito_komoru" #@param {type: "string"}
tag2 = "" #@param {type: "string"}
download_tags = False #@param {type: "boolean"}
# Construct the search query
if tag2 != "":
  tags = tag1 + "+" + tag2
else:
  tags = tag1

if download_tags == True:
  write_tags = "--write-tags"
else:
  write_tags = ""

# Scrape images from the specified booru site using the given tags
if booru.lower() == "danbooru":
  # !gallery-dl "https://danbooru.donmai.us/posts?tags={tags}" {write_tags} -D {train_data_dir}
elif booru.lower() == "gelbooru":
  # !gallery-dl "https://gelbooru.com/index.php?page=post&s=list&tags={tags}" {write_tags} -D {train_data_dir}
else:
  print(f"Unknown booru site: {booru}")

if download_tags == True: 
  # Get a list of all the .txt files in the folder
  files = [f for f in os.listdir(train_data_dir) if f.endswith(".txt")]

  # Loop through each file
  for file in files:
      file_path = os.path.join(train_data_dir, file)

      # Read the contents of the file
      with open(file_path, "r") as f:
          contents = f.read()

      # Decode HTML entities and replace _ with a space
      contents = html.unescape(contents)
      contents = contents.replace("_", " ")

      # Split the contents on newline characters and join with commas
      contents = ", ".join(contents.split("\n"))

      # Write the modified contents back to the file
      with open(file_path, "w") as f:
          f.write(contents)

# %% [markdown]
# # IV. Data Preprocessing

# %%
#@title ## 4.1. Data Cleaning
#@markdown This will delete unnecessary files and unsupported media like `.mp4`, `.webm`, and `.gif`
# %store -r

import os

# %cd {root_dir}

test = os.listdir(train_data_dir)

#@markdown I recommend to `keep_metadata` especially if you're doing resume training and you have metadata and bucket latents file from previous training like `.npz`, `.txt`, `.caption`, and `json`.
keep_metadata = True #@param {'type':'boolean'}

# List of supported file types
if keep_metadata == True:
  supported_types = [".png", ".jpg", ".jpeg", ".webp", ".bmp", ".caption", ".npz", ".txt", ".json"]
else:
  supported_types = [".png", ".jpg", ".jpeg", ".webp", ".bmp"]

# Iterate over all files in the directory
for item in test:
    # Extract the file extension from the file name
    file_ext = os.path.splitext(item)[1]
    # If the file extension is not in the list of supported types, delete the file
    if file_ext not in supported_types:
        # Print a message indicating the name of the file being deleted
        print(f"Deleting file {item} from {train_data_dir}")
        # Delete the file
        os.remove(os.path.join(train_data_dir, item))

# %%
#@title ## 4.2. Data Annotation
# %store -r
# %cd {finetune_dir}

#@markdown We're using [BLIP](https://huggingface.co/spaces/Salesforce/BLIP) for image captioning and [Waifu Diffusion 1.4 Tagger](https://huggingface.co/spaces/SmilingWolf/wd-v1-4-tags) for image tagging like danbooru.

#@markdown Tick this if you want to label your dataset with natural language like this: <br>
#@markdown `a girl with long hair holding a cellphone`

Start_BLIP_Captioning = True #@param {type:"boolean"}

#@markdown or Tick this if you want to label your dataset with danbooru tag like this: <br>
#@markdown `1girl, solo, looking_at_viewer, short_hair, bangs, simple_background, shirt, black_hair, white_background, closed_mouth, choker, hair_over_one_eye, head_tilt, grey_eyes, black_shirt, floating_hair, black_choker, eyes_visible_through_hair, portrait`

Start_WD_1_4_Tagger = True #@param {type:"boolean"}

#@markdown or you can use them both

batch_size = 8

if Start_BLIP_Captioning == True:
  # !python make_captions.py \
    {train_data_dir} \
    --batch_size {batch_size} \
    --caption_extension .caption
else:
  pass

if Start_WD_1_4_Tagger == True:
  # !python tag_images_by_wd14_tagger.py \
    {train_data_dir} \
    --batch_size {batch_size} \
    --caption_extension .txt
else:
  pass

# %%
#@title ### 4.2.1. Append Custom Tag (Optional)
import os
# %store -r

# %cd {root_dir}

def clone_random_repo():
  # Check if the directory already exists
  if os.path.isdir(str(root_dir)+"/cafe-aesthetic-scorer/"):
    # %cd {root_dir}/cafe-aesthetic-scorer/
    print("This folder already exists, will do a !git pull instead\n")
    # !git pull
  else:
    # !git clone https://github.com/Linaqruf/cafe-aesthetic-scorer/

clone_random_repo()

# %cd {root_dir}/cafe-aesthetic-scorer/
#@markdown If you want to append custom tag, you can do that here. This cell will add custom tag at the beginning of lines
custom_tag = "masterpiece" #@param {type:"string"}
caption_extension = "txt" #@param ["txt","caption"]
#@markdown Tick this if you want to append custom tag at the end of lines instead
append = False #@param {type: "boolean"}

if append:
  append_tag = "--append"
else:
  append_tag = ""

# !python custom_tagger.py \
  {train_data_dir} \
  {caption_extension} \
  {custom_tag} \
  {append_tag}

# %%
#@title ## 4.3. Create JSON file for Finetuning
import os
# %store -r

# Change the working directory
# %cd {finetune_dir}

#@markdown ### Define Parameter
meta_clean = "/content/fine_tune/meta_clean.json" #@param {type:"string"}
#@markdown This cell will merge all dataset label from captioning, tagging, and custom tagging into one JSON file, and later it will be used as input JSON for bucketing section.

parent_folder = os.path.dirname(meta_clean)
meta_cap_dd = f"{parent_folder}/meta_cap_dd.json"
meta_cap = f"{parent_folder}/meta_cap.json"

# Check if directory exists
if not os.path.exists(parent_folder):
  # Create directory if it doesn't exist
  os.makedirs(parent_folder)

# Check if the train_data_dir exists and is a directory
if os.path.isdir(train_data_dir):
  # Check if there are any .caption files in the train_data_dir
  if any(file.endswith('.caption') for file in os.listdir(train_data_dir)):
    # Create meta_cap.json from captions
    # !python merge_captions_to_metadata.py \
      {train_data_dir} \
      {meta_cap}

  # Check if there are any .txtn files in the train_data_dir
  if any(file.endswith('.txt') for file in os.listdir(train_data_dir)):
    # Create meta_cap_dd.json from tags
    # !python merge_dd_tags_to_metadata.py \
      {train_data_dir} \
      {meta_cap_dd}
else:
  print("train_data_dir does not exist or is not a directory.")

# Merge meta_cap.json to meta_cap_dd.json
if os.path.exists(meta_cap) and os.path.exists(meta_cap_dd):
  # !python merge_dd_tags_to_metadata.py \
    {train_data_dir} \
    --in_json {meta_cap} \
    {meta_cap_dd}

# Clean meta_cap_dd.json and store it to meta_clean.json
if os.path.exists(meta_cap_dd):
  # Clean captions and tags in meta_cap_dd.json and store the result in meta_clean.json
  # !python clean_captions_and_tags.py \
    {meta_cap_dd} \
    {meta_clean}
elif os.path.exists(meta_cap):
  # If meta_cap_dd.json does not exist, clean meta_cap.json and store the result in meta_clean.json
  # !python clean_captions_and_tags.py \
    {meta_cap} \
    {meta_clean}

# %%
#@title ## 4.4. Aspect Ratio Bucketing and Cache Latents
# %store -r

# Change the working directory
# %cd {finetune_dir}

#@markdown ### Define parameters
V2 = False #@param{type:"boolean"}
model_dir = "/content/pre_trained_model/Anything-v3-better-vae.ckpt" #@param {'type' : 'string'} 
input_json = "/content/fine_tune/meta_clean.json" #@param {'type' : 'string'} 
output_json = "/content/fine_tune/meta_lat.json"#@param {'type' : 'string'} 
batch_size = 4 #@param {'type':'integer'}
max_resolution = "512,512" #@param ["512,512", "640,640", "768,768"] {allow-input: false}
mixed_precision = "no" #@param ["no", "fp16", "bf16"] {allow-input: false}
flip_aug = True #@param{type:"boolean"}

if V2:
  SDV2 = "--v2"
else:
  SDV2 = ""

if flip_aug:
  flip_latents = "--v2"
else:
  flip_latents = "--flip_aug"

# Run script to prepare buckets and latents
# !python prepare_buckets_latents.py \
  {train_data_dir} \
  {input_json} \
  {output_json} \
  {model_dir} \
  {SDV2} \
  {flip_latents} \
  --batch_size {batch_size} \
  --max_resolution {max_resolution} \
  --mixed_precision {mixed_precision}

# %% [markdown]
# # V. Training Model

# %%
#@title ## 5.1. Define Important folder
import os
# %store -r

v2 = False #@param {type:"boolean"}
v_parameterization = False #@param {type:"boolean"}
pretrained_model_name_or_path = "/content/pre_trained_model/Anything-v3-better-vae.ckpt" #@param {type:"string"}
vae = ""  #@param {type:"string"}
train_data_dir = "/content/fine_tune/train_data"  #@param {type:"string"}
# %store train_data_dir
in_json = "/content/fine_tune/meta_lat.json" #@param {type:"string"}
output_dir = "/content/fine_tune/output" #@param {type:"string"}
resume_path = "" #@param {type:"string"}
output_name = "hito_komoru" #@param {type:"string"}

#@markdown This will ignore `output_dir` defined above, and changed to `/content/drive/MyDrive/fine_tune/output` by default
output_to_drive = False #@param {'type':'boolean'}

if output_to_drive:
  output_dir = "/content/drive/MyDrive/fine_tune/output"

  if not os.path.exists("/content/drive"):
    drive.mount('/content/drive')  

# Check if directory exists
if not os.path.exists(output_dir):
  # Create directory if it doesn't exist
  os.makedirs(output_dir)

#V2 Inference
inference_url = "https://raw.githubusercontent.com/Stability-AI/stablediffusion/main/configs/stable-diffusion/"

if v2 and not v_parameterization:
  inference_url += "v2-inference.yaml"
if v2 and v_parameterization:
  inference_url += "v2-inference-v.yaml"

try:
  if v2:
    # !wget {inference_url} -O {output_dir}/{output_name}.yaml
    print("File successfully downloaded")
except:
  print("There was an error downloading the file. Please check the URL and try again.")
# Out:
# Stored 'train_data_dir' (str)

# %%
# %store -r

#@title ## 5.2. Start Fine-Tuning
mixed_precision = "fp16" #@param ["no","fp16","bf16"] {allow-input: false}
save_precision = "float" #@param ["float", "fp16", "bf16"] {allow-input: false}
save_every_n_epochs = 0 #@param {type:"number"}
save_last_n_epochs = 0 #@param {type:"number"}
save_state = True #@param {type:"boolean"}
save_model_as = "ckpt" #@param ["ckpt", "safetensors", "diffusers", "diffusers_safetensors"] {allow-input: false}
resolution = "512" #@param {type:"string"}
train_text_encoder = False #@param {'type':'boolean'}
train_batch_size = 1 #@param {type:"number"}
max_token_length = 225 #@param {type:"number"}
use_8bit_adam = True #@param {type:"boolean"}
keep_tokens = 0 #@param {type:"number"}
learning_rate = 2e-6 #@param {type:"number"}
lr_scheduler = "constant" #@param  ["linear", "cosine", "cosine_with_restarts", "polynomial", "constant", "constant_with_warmup"] {allow-input: false}
lr_warmup_steps = "0" #@param {type:"string"}
dataset_repeats = 1 #@param {type:"number"}
max_train_steps = 5000 #@param {type:"number"}
seed = 1123 #@param {type:"number"}
gradient_checkpointing = False #@param {type:"boolean"}
clip_skip = 2 #@param {type:"number"}
debug_dataset = False #@param {type:"boolean"}
logging_dir = "/content/fine_tune/logs" #@param {type:"string"}
additional_argument = "" #@param {type:"string"}

sh_cmd=f"""
accelerate launch --config_file={accelerate_config} --num_cpu_threads_per_process 8 /content/kohya-trainer/fine_tune.py \
  {"--v2" if v2 else ""} \
  {"--v_parameterization" if v2 and v_parameterization else ""} \
  --pretrained_model_name_or_path={pretrained_model_name_or_path} \
  {"--vae=" + vae if vae else ""} \
  --train_data_dir={train_data_dir} \
  --in_json={in_json} \
  --output_dir={output_dir} \
  {"--resume=" + resume_path if resume_path else ""} \
  {"--output_name=" + output_name if output_name else ""} \
  --mixed_precision={mixed_precision} \
  --save_precision={save_precision} \
  {"--save_every_n_epochs=" + save_every_n_epochs if save_every_n_epochs != 0 else ""} \
  {"--save_last_n_epochs=" + save_every_n_epochs if save_last_n_epochs != 0 else ""} \
  {"--save_state" if save_state else ""} \
  --save_model_as={save_model_as} \
  --resolution={resolution} \
  --train_batch_size={train_batch_size} \
  --max_token_length={max_token_length} \
  {"--train_text_encoder" if train_text_encoder else ""} \
  {"--use_8bit_adam" if use_8bit_adam else ""} \
  --shuffle_caption \
  {"--keep_tokens=" + keep_tokens if keep_tokens else ""} \
  --xformers \
  --learning_rate={learning_rate} \
  --lr_scheduler={lr_scheduler} \
  --lr_warmup_steps={lr_warmup_steps} \
  --dataset_repeats={dataset_repeats} \
  --max_train_steps={max_train_steps} \
  {"--seed=" + format(seed) if seed else ""} \
  {"--gradient_checkpointing" if gradient_checkpointing else ""} \
  {"--gradient_accumulation_steps=" + format(1) } \
  {"--clip_skip=" + clip_skip if v2=="" else ""} \
  {"--debug_dataset" if debug_dataset else ""} \
  --logging_dir={logging_dir} \
  --log_prefix={output_name} \
  {additional_argument}
  """

f = open("/content/start.sh", "w")
f.write(sh_cmd)
f.close()
# !chmod +x /content/start.sh
# !/content/start.sh
# Out:
# 2023-01-18 12:18:21.583973: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-18 12:18:23.583691: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-18 12:18:23.583910: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-18 12:18:23.583933: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-01-18 12:18:27.760913: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-18 12:18:28.438975: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-18 12:18:28.439078: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-18 12:18:28.439099: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# prepare tokenizer
# update token length: 225
# loading existing metadata: /content/fine_tune/meta_lat.json
# metadata has bucket info, enable bucketing / メタデータにbucket情報があるためbucketを有効にします
# using bucket info in metadata / メタデータ内のbucket情報を使います
# loading image sizes.
# 100% 1999/1999 [00:00<00:00, 3082505.04it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (256, 832), count: 1
# bucket 1: resolution (256, 960), count: 4
# bucket 2: resolution (320, 704), count: 113
# bucket 3: resolution (320, 768), count: 24
# bucket 4: resolution (384, 640), count: 682
# bucket 5: resolution (448, 576), count: 307
# bucket 6: resolution (512, 512), count: 222
# bucket 7: resolution (576, 448), count: 66
# bucket 8: resolution (640, 384), count: 440
# bucket 9: resolution (704, 320), count: 135
# bucket 10: resolution (768, 320), count: 1
# bucket 11: resolution (1024, 256), count: 4
# mean ar error (without repeats): 0.0
# prepare accelerator
# Using accelerator 0.15.0 or above.
# load StableDiffusion checkpoint
# loading u-net: <All keys matched successfully>
# loading vae: <All keys matched successfully>
# Downloading: 100% 4.52k/4.52k [00:00<00:00, 4.79MB/s]
# Downloading: 100% 1.71G/1.71G [00:21<00:00, 79.6MB/s]
# Some weights of the model checkpoint at openai/clip-vit-large-patch14 were not used when initializing CLIPTextModel: ['vision_model.encoder.layers.8.self_attn.k_proj.weight', 'vision_model.encoder.layers.20.layer_norm1.weight', 'vision_model.encoder.layers.19.layer_norm1.weight', 'vision_model.encoder.layers.8.self_attn.out_proj.bias', 'vision_model.encoder.layers.21.mlp.fc2.bias', 'vision_model.encoder.layers.23.self_attn.q_proj.bias', 'vision_model.encoder.layers.13.self_attn.q_proj.weight', 'vision_model.encoder.layers.10.mlp.fc1.bias', 'vision_model.encoder.layers.4.layer_norm2.bias', 'vision_model.encoder.layers.2.layer_norm2.weight', 'vision_model.encoder.layers.7.self_attn.q_proj.bias', 'vision_model.encoder.layers.0.self_attn.q_proj.weight', 'vision_model.encoder.layers.18.mlp.fc1.bias', 'vision_model.encoder.layers.13.self_attn.q_proj.bias', 'vision_model.encoder.layers.13.mlp.fc2.weight', 'vision_model.encoder.layers.3.layer_norm2.bias', 'vision_model.encoder.layers.14.mlp.fc2.weight', 'vision_model.encoder.layers.0.layer_norm1.weight', 'vision_model.encoder.layers.10.layer_norm2.weight', 'vision_model.encoder.layers.5.mlp.fc2.bias', 'vision_model.encoder.layers.13.mlp.fc1.bias', 'vision_model.encoder.layers.12.mlp.fc2.weight', 'vision_model.encoder.layers.1.layer_norm2.weight', 'vision_model.encoder.layers.18.mlp.fc2.weight', 'vision_model.encoder.layers.3.self_attn.out_proj.weight', 'vision_model.encoder.layers.7.self_attn.out_proj.bias', 'vision_model.encoder.layers.13.self_attn.out_proj.weight', 'vision_model.encoder.layers.5.self_attn.out_proj.weight', 'vision_model.encoder.layers.17.layer_norm2.bias', 'vision_model.encoder.layers.17.self_attn.out_proj.bias', 'vision_model.encoder.layers.4.mlp.fc2.bias', 'vision_model.encoder.layers.5.self_attn.q_proj.weight', 'vision_model.encoder.layers.0.self_attn.v_proj.bias', 'vision_model.encoder.layers.11.self_attn.k_proj.weight', 'vision_model.encoder.layers.6.layer_norm1.weight', 'vision_model.encoder.layers.3.self_attn.k_proj.bias', 'vision_model.encoder.layers.18.layer_norm2.weight', 'vision_model.encoder.layers.23.self_attn.out_proj.weight', 'vision_model.encoder.layers.11.self_attn.v_proj.bias', 'vision_model.encoder.layers.21.self_attn.out_proj.bias', 'vision_model.encoder.layers.20.self_attn.k_proj.weight', 'vision_model.encoder.layers.7.mlp.fc2.weight', 'vision_model.encoder.layers.7.layer_norm1.bias', 'vision_model.encoder.layers.12.self_attn.out_proj.bias', 'vision_model.encoder.layers.6.self_attn.q_proj.weight', 'vision_model.encoder.layers.21.mlp.fc2.weight', 'vision_model.encoder.layers.8.mlp.fc1.bias', 'vision_model.encoder.layers.0.self_attn.v_proj.weight', 'vision_model.encoder.layers.10.self_attn.v_proj.bias', 'vision_model.encoder.layers.7.self_attn.k_proj.bias', 'vision_model.embeddings.position_embedding.weight', 'vision_model.encoder.layers.14.mlp.fc2.bias', 'vision_model.encoder.layers.3.self_attn.q_proj.weight', 'vision_model.encoder.layers.16.self_attn.q_proj.bias', 'vision_model.encoder.layers.22.mlp.fc2.bias', 'vision_model.encoder.layers.19.self_attn.v_proj.weight', 'vision_model.encoder.layers.17.layer_norm2.weight', 'vision_model.encoder.layers.17.mlp.fc2.bias', 'vision_model.encoder.layers.10.self_attn.v_proj.weight', 'vision_model.encoder.layers.17.mlp.fc1.weight', 'vision_model.encoder.layers.21.mlp.fc1.weight', 'vision_model.encoder.layers.17.self_attn.k_proj.weight', 'vision_model.encoder.layers.9.layer_norm1.bias', 'vision_model.encoder.layers.13.layer_norm2.weight', 'vision_model.encoder.layers.5.mlp.fc1.bias', 'vision_model.encoder.layers.23.mlp.fc1.bias', 'vision_model.encoder.layers.10.layer_norm1.weight', 'vision_model.encoder.layers.18.self_attn.k_proj.weight', 'vision_model.encoder.layers.14.self_attn.q_proj.weight', 'vision_model.encoder.layers.18.self_attn.out_proj.weight', 'vision_model.encoder.layers.3.self_attn.q_proj.bias', 'vision_model.encoder.layers.11.self_attn.q_proj.bias', 'vision_model.encoder.layers.15.mlp.fc2.bias' ...
# - This IS expected if you are initializing CLIPTextModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CLIPTextModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# loading text encoder: <All keys matched successfully>
# Disable Diffusers' xformers
# Replace CrossAttention.forward to use xformers
# prepare optimizer, data loader etc.
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 112
# CUDA SETUP: Loading binary /usr/local/lib/python3.8/dist-packages/bitsandbytes/libbitsandbytes_cuda112.so...
# use 8-bit Adam optimizer
# running training / 学習開始
#   num examples / サンプル数: 1999
#   num batches per epoch / 1epochのバッチ数: 1999
#   num epochs / epoch数: 3
#   batch size per device / バッチサイズ: 1
#   total train batch size (with parallel & distributed & accumulation) / 総バッチサイズ（並列学習、勾配合計含む）: 1
#   gradient ccumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 5000
# steps:   0% 0/5000 [00:00<?, ?it/s]epoch 1/3
# Traceback (most recent call last):
#   File "/usr/local/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/accelerate/commands/accelerate_cli.py", line 45, in main
#     args.func(args)
#   File "/usr/local/lib/python3.8/dist-packages/accelerate/commands/launch.py", line 1104, in launch_command
#     simple_launcher(args)
#   File "/usr/local/lib/python3.8/dist-packages/accelerate/commands/launch.py", line 567, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# subprocess.CalledProcessError: Command '['/usr/bin/python3', '/content/kohya-trainer/fine_tune.py', '--pretrained_model_name_or_path=/content/pre_trained_model/Anything-v3-better-vae.ckpt', '--train_data_dir=/content/fine_tune/train_data', '--in_json=/content/fine_tune/meta_lat.json', '--output_dir=/content/fine_tune/output', '--output_name=hito_komoru', '--mixed_precision=fp16', '--save_precision=float', '--save_state', '--save_model_as=ckpt', '--resolution=512', '--train_batch_size=1', '--max_token_length=225', '--use_8bit_adam', '--shuffle_caption', '--xformers', '--learning_rate=2e-06', '--lr_scheduler=constant', '--lr_warmup_steps=0', '--dataset_repeats=1', '--max_train_steps=5000', '--seed=1123', '--gradient_accumulation_steps=1', '--logging_dir=/content/fine_tune/logs', '--log_prefix=hito_komoru']' died with <Signals.SIGKILL: 9>.

# %% [markdown]
# # VI. Testing

# %%
#@title ## 6.1. Inference
# %store -r

V2 = "V2_base" #@param ["none", "V2_base", "V2_768_v"] {allow-input: false}
prompt = "masterpiece, best quality, high quality, 1girl, solo, sitting, confident expression, long blonde hair, blue eyes, formal dress, jewelry, make-up, luxury, close-up, face, upper body." #@param {type: "string"}
negative = "worst quality, low quality, medium quality, deleted, lowres, comic, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, jpeg artifacts, signature, watermark, username, blurry" #@param {type: "string"}
model = "/content/fine_tune/output/last.ckpt" #@param {type: "string"}
vae = "" #@param {type: "string"}
output_folder = "/content/tmp" #@param {type: "string"}
scale = 7 #@param {type: "slider", min: 1, max: 40}
sampler = "ddim" #@param ["ddim", "pndm", "lms", "euler", "euler_a", "heun", "dpm_2", "dpm_2_a", "dpmsolver","dpmsolver++", "dpmsingle", "k_lms", "k_euler", "k_euler_a", "k_dpm_2", "k_dpm_2_a"]
steps = 28 #@param {type: "slider", min: 1, max: 100}
precision = "fp16" #@param ["fp16", "bf16"] {allow-input: false}
width = 512 #@param {type: "integer"}
height = 768 #@param {type: "integer"}
images_per_prompt = 4 #@param {type: "integer"}
batch_size = 4 #@param {type: "integer"}
clip_skip = 2 #@param {type: "slider", min: 1, max: 40}
seed = -1 #@param {type: "integer"}

if vae == "":
  load_vae =""
else:
  load_vae ="--vae " + str(vae)

if V2 == "V2_base":
  v2_model = "--v2"
  v2_768v_model= ""
elif V2 == "V2_768_v":
  v2_model = "--v2"
  v2_768v_model = "--v2_parameterization"
else:
  v2_model = ""
  v2_768v_model = ""

if V2 == "none":
  penultimate_layer = "--clip_skip" + "=" + "{}".format(clip_skip)
else:
  penultimate_layer = ""

if seed <= 0:
  seed_number = ""
else:
  seed_number = "--seed" + "=" + "{}".format(seed)

# %cd {repo_dir}
# !python gen_img_diffusers.py \
  {v2_model} \
  {v2_768v_model} \
  --ckpt {model} \
  --outdir {output_folder} \
  --xformers \
  {load_vae} \
  --{precision} \
  --W {width} \
  --H {height} \
  {seed_number} \
  --scale {scale} \
  --sampler {sampler} \
  --steps {steps} \
  --max_embeddings_multiples 3 \
  --batch_size {batch_size} \
  --images_per_prompt {images_per_prompt} \
  {penultimate_layer} \
  --prompt "{prompt} --n {negative}"

# %%
#@title ## 6.2. Visualize loss graph (Optional)
training_logs_path = "/content/fine_tune/training_logs" #@param {type : "string"}

# %cd {repo_dir}
# %load_ext tensorboard
# %tensorboard --logdir {training_logs_path}

# %% [markdown]
# # VII. Extras

# %%
#@title ## 7.1. Convert Diffusers to `.ckpt/.safetensors`
# %store -r
# %cd {tools_dir}


#@markdown ## Define model path
weight = "/content/fine_tune/output/last.ckpt" #@param {'type': 'string'}
weight_dir = os.path.dirname(weight)
base_name = os.path.splitext(os.path.basename(weight))[0]

convert = "ckpt_safetensors_to_diffusers" #@param ["diffusers_to_ckpt_safetensors", "ckpt_safetensors_to_diffusers"] {'allow-input': false}
#@markdown ___
#@markdown ## Conversion Config
#@markdown ___
#@markdown ### Diffusers to `.ckpt/.safetensors`
use_safetensors = False #@param {'type': 'boolean'}

save_precision = "--float" #@param ["--fp16","--bf16","--float"] {'allow-input': false}

#@markdown ### `.ckpt/.safetensors` to Diffusers
#@markdown is your model v1 or v2 based Stable Diffusion Model
version = "--v1" #@param ["--v1","--v2"] {'allow-input': false}
diffusers = os.path.join(weight_dir, base_name)

#@markdown Additional file for diffusers
feature_extractor = True #@param {'type': 'boolean'}
safety_checker = True #@param {'type': 'boolean'}

if use_safetensors:
    checkpoint = str(diffusers)+".safetensors"
else:
    checkpoint = str(diffusers)+".ckpt"

if version == "--v1":
  reference_model = "runwayml/stable-diffusion-v1-5"
elif version == "--v2":
  reference_model = "stabilityai/stable-diffusion-2-1"

if convert == "diffusers_to_ckpt_safetensors":
    if not weight.endswith(".ckpt") or weight.endswith(".safetensors"):
        # !python convert_diffusers20_original_sd.py \
            "{weight}" \
            "{checkpoint}"" \
            {save_precision}

else:    
    # !python convert_diffusers20_original_sd.py \
        "{weight}" \
        "{diffusers}" \
        {version} \
        --reference_model {reference_model} 

    url1 = "https://huggingface.co/CompVis/stable-diffusion-safety-checker/resolve/main/preprocessor_config.json"
    url2 = "https://huggingface.co/CompVis/stable-diffusion-safety-checker/resolve/main/config.json"
    url3 = "https://huggingface.co/CompVis/stable-diffusion-safety-checker/resolve/main/pytorch_model.bin"

    if feature_extractor == True:
      if not os.path.exists(str(diffusers)+'/feature_extractor'):
        os.makedirs(str(diffusers)+'/feature_extractor')
      
      # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d '{diffusers}/feature_extractor' -Z {url1}

    if safety_checker == True:
      if not os.path.exists(str(diffusers)+'/safety_checker'):
        os.makedirs(str(diffusers)+'/safety_checker')
      
      # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d '{diffusers}/safety_checker' -Z {url2}
      # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d '{diffusers}/safety_checker' -Z {url3}

# %%
import os
# %store -r
#@title ## 7.2. Model Pruner

# %cd {toolsdir}

if os.path.exists('prune.py'):
  pass
else:
  # Add a comment to explain what the code is doing
  # Download the pruning script if it doesn't already exist
  # !wget https://raw.githubusercontent.com/lopho/stable-diffusion-prune/main/prune.py

#@markdown Convert to Float16
fp16 = False #@param {'type':'boolean'}
#@markdown Use EMA for weights
ema = False #@param {'type':'boolean'}
#@markdown Strip CLIP weights
no_clip = False #@param {'type':'boolean'}
#@markdown Strip VAE weights
no_vae = False #@param {'type':'boolean'}
#@markdown Strip depth model weights
no_depth = False #@param {'type':'boolean'}
#@markdown Strip UNet weights
no_unet = False #@param {'type':'boolean'}
#@markdown You need to input model ends with `.ckpt`, because `.safetensors` model won't work.

input = "/content/fine_tune/output/last.ckpt" #@param {'type' : 'string'}


# Notify the user that the model is being loaded
print(f"Loading model from {input}")

input_path = os.path.dirname(input)
base_name = os.path.basename(input)
output_name = base_name.split('.')[0]
# Notify the user of the arguments being used
if fp16:
    print("Converting to float16")
    output_name += '-fp16'
if ema:
    print("Using EMA for weights")
    output_name += '-ema'
if no_clip:
    print("Stripping CLIP weights")
    output_name += '-no-clip'
if no_vae:
    print("Stripping VAE weights")
    output_name += '-no-vae'
if no_depth:
    print("Stripping depth model weights")
    output_name += '-no-depth'
if no_unet:
    print("Stripping UNet weights")
    output_name += '-no-unet'
output_name += '-pruned'
output_path = os.path.join(input_path, output_name + '.ckpt')

# !python3 prune.py "{input}" \
  "{output_path}" \
  {'--fp16' if fp16 else ''} \
  {'--ema' if ema else ''} \
  {'--no-clip' if no_clip else ''} \
  {'--no-vae' if no_vae else ''} \
  {'--no-depth' if no_depth else ''} \
  {'--no-unet' if no_unet else ''}

# Notify the user of the output file location
print(f"Saving pruned model to {output_path}")

# %%
#@title ## 7.3. Compressing model or dataset
import os
import zipfile
import shutil

zip_module = "zipfile" #@param ["zipfile", "shutil", "pyminizip", "zip"]
directory_to_zip = '/content/fine_tune/train_data' #@param {type: "string"}
output_filename = '/content/train_data.zip' #@param {type: "string"}
password = "" #@param {type: "string"}

if zip_module == "zipfile":
    with zipfile.ZipFile(output_filename, 'w') as zip:
        for directory_to_zip, dirs, files in os.walk(directory_to_zip):
            for file in files:
                zip.write(os.path.join(directory_to_zip, file))
elif zip_module == "shutil":
    shutil.make_archive(output_filename, 'zip', directory_to_zip)
elif zip_module == "pyminizip":
    # !pip install pyminizip
    import pyminizip
    for root, dirs, files in os.walk(directory_to_zip):
        for file in files:
            pyminizip.compress(os.path.join(root, file), "", os.path.join("*",output_filename), password, 5)
elif zip_module == "zip":
    # !zip -rv -q -j {output_filename} {directory_to_zip}

# %% [markdown]
# # VIII. Deployment

# %%
#@title ## 8.1. Define your Huggingface Repo

from huggingface_hub import HfApi
from huggingface_hub.utils import validate_repo_id, HfHubHTTPError
# %store -r

api = HfApi()
user = api.whoami(write_token)

#@markdown #### If your model/dataset repo didn't exist, it will automatically create your repo.
model_name = "your-model-name" #@param{type:"string"}
dataset_name = "your-dataset-name" #@param{type:"string"}
make_this_model_private = True #@param{type:"boolean"}
clone_with_git = True #@param{type:"boolean"}

model_repo = user['name']+"/"+model_name.strip()
datasets_repo = user['name']+"/"+dataset_name.strip()

validate_repo_id(model_repo)
validate_repo_id(datasets_repo)

if make_this_model_private:
  private_repo = True
else:
  private_repo = False

if model_name != "":
  try:
      api.create_repo(repo_id=model_repo, 
                      private=private_repo)
      print("Model Repo didn't exists, creating repo")
      print("Model Repo: ",model_repo,"created!\n")

  except HfHubHTTPError as e:
      print(f"Model Repo: {model_repo} exists, skipping create repo\n")

if dataset_name != "":
  try:
      api.create_repo(repo_id=datasets_repo,
                      repo_type="dataset",
                      private=private_repo)
      print("Dataset Repo didn't exists, creating repo")
      print("Dataset Repo",datasets_repo,"created!\n")

  except HfHubHTTPError as e:
      print(f"Dataset repo: {datasets_repo} exists, skipping create repo\n")

if clone_with_git:
  # !git lfs uninstall

  if model_name != "":
    # !git clone https://huggingface.co/{model_repo} /content/{model_name}
  
  if dataset_name != "":
    # !git clone https://huggingface.co/datasets/{datasets_repo} /content/{dataset_name}

# %% [markdown]
# ## 8.2. Upload to Huggingface

# %%
#@title ### 8.2.1. Commit using Git 
# %cd {root_dir}

#@markdown Tick which repo you want to commit
commit_model = True #@param {'type': 'boolean'}
commit_dataset = True #@param {'type': 'boolean'}

#@markdown Set **git commit identity**
email = "your-email" #@param {'type': 'string'}
name = "your-username" #@param {'type': 'string'}
#@markdown Set **commit message**
commit_m = "feat: upload prototype model" #@param {'type': 'string'}

# !git lfs install

# !git config --global user.email "{email}"
# !git config --global user.name "{name}"

if commit_model:
  # %cd {root_dir}/{model_name}
  # !huggingface-cli lfs-enable-largefiles .
  # !git add .
  # !git lfs help smudge
  # !git commit -m "{commit_m}"
  # !git push

if commit_dataset:
  # %cd {root_dir}/{dataset_name}
  # !huggingface-cli lfs-enable-largefiles .
  # !git add .
  # !git lfs help smudge
  # !git commit -m "{commit_m}"
  # !git push

# %%
#@title ### 8.2.2. Quick Upload to Huggingface
from huggingface_hub import HfApi
from pathlib import Path

api = HfApi()

#@markdown #### This will be uploaded to model repo
model_path = "/content/fine_tune/output/last.ckpt" #@param {type :"string"}

is_diffusers_model = False #@param {type:"boolean"}

#@markdown #### This will be uploaded to datasets repo, leave it empty if not necessary
last_state_path = "/content/fine_tune/output/last-state" #@param {type :"string"}
train_data_path = "/content/fine_tune/output/train_data" #@param {type :"string"}
meta_lat_path = "/content/fine_tune/output/meta_lat_json" #@param {type :"string"}

#@markdown ##### `Nerd stuff, only if you want to save training logs`
logs_path = "/content/fine_tune/training_logs" #@param {type :"string"}

#@markdown #### Other Information
commit_message = "feat: upload a model and dataset" #@param {type :"string"}

if model_path != "":
  path_obj = Path(model_path)
  trained_model = path_obj.parts[-1]

  if model_path.endswith(".ckpt") or model_path.endswith(".safetensors") or model_path.endswith(".pt"):
    print(f"Uploading {trained_model} to https://huggingface.co/"+model_repo)
    print(f"Please wait...")

    api.upload_file(
        path_or_fileobj=model_path,
        path_in_repo=trained_model,
        repo_id=model_repo,
        commit_message=commit_message,
    )
    
    print(f"Upload success, located at https://huggingface.co/"+model_repo+"/blob/main/"+trained_model+"\n")
  
  elif is_diffusers_model == True:
    print(f"Uploading {trained_model} to https://huggingface.co/"+model_repo)
    print(f"Please wait...")

    api.upload_folder(
        folder_path=model_path,
        repo_id=model_repo,
        commit_message=commit_message,
        ignore_patterns=".ipynb_checkpoints"
    )
    print(f"Upload success, located at https://huggingface.co/"+model_repo+"/tree/main\n")
  
  else:
    print(f"Uploading {trained_model} to https://huggingface.co/"+model_repo)
    print(f"Please wait...")

    api.upload_folder(
        folder_path=model_path,
        path_in_repo=trained_model,
        repo_id=model_repo,
        commit_message=commit_message,
        ignore_patterns=".ipynb_checkpoints"
    )
    print(f"Upload success, located at https://huggingface.co/"+model_repo+"/tree/main/"+trained_model+"\n")
if last_state_path != "":
  path_obj = Path(last_state_path)
  last_state_folder = path_obj.parts[-1]

  print(f"Uploading {last_state_folder} to https://huggingface.co/datasets/"+datasets_repo)
  print(f"Please wait...")

  api.upload_folder(
      folder_path=last_state_path,
      path_in_repo=last_state_folder,
      repo_id=datasets_repo,
      repo_type="dataset",
      commit_message=commit_message,
      ignore_patterns=".ipynb_checkpoints",
  )
  print(f"Upload success, located at https://huggingface.co/datasets/"+datasets_repo+"/tree/main/"+last_state_folder+"\n")


if train_data_path != "":
  path_obj = Path(train_data_path)
  train_data_folder = path_obj.parts[-1]

  print(f"Uploading {train_data_folder} to https://huggingface.co/datasets/"+datasets_repo)
  print(f"Please wait...")

  api.upload_folder(
      folder_path=train_data_path,
      path_in_repo=train_data_folder,
      repo_id=datasets_repo,
      repo_type="dataset",
      commit_message=commit_message,
      ignore_patterns=".ipynb_checkpoints",
  )
  print(f"Upload success, located at https://huggingface.co/datasets/"+datasets_repo+"/tree/main/"+train_data_folder+"\n")

if meta_lat_path != "":
  path_obj = Path(meta_lat_path)
  meta_lat_file = path_obj.parts[-1]

  print(f"Uploading {meta_lat_file} to https://huggingface.co/datasets/"+datasets_repo)
  print(f"Please wait...")

  api.upload_file(
      path_or_fileobj=meta_lat_path,
      path_in_repo=meta_lat_file,
      repo_id=datasets_repo,
      repo_type="dataset",
      commit_message=commit_message,
  )
  print(f"Upload success, located at https://huggingface.co/datasets/"+datasets_repo+"/blob/main/"+meta_lat_file+"\n")

if logs_path != "":
  path_obj = Path(logs_path)
  logs_folder = path_obj.parts[-1]

  print(f"Uploading {logs_folder} to https://huggingface.co/datasets/"+datasets_repo)
  print(f"Please wait...")

  api.upload_folder(
      folder_path=logs_path,
      path_in_repo=logs_folder,
      repo_id=datasets_repo,
      repo_type="dataset",
      commit_message=commit_message,
      ignore_patterns=".ipynb_checkpoints",
  )
  print(f"Upload success, located at https://huggingface.co/datasets/"+datasets_repo+"/tree/main/"+logs_folder+"\n")
